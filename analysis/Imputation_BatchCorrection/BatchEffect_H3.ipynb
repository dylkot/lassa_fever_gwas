# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.stats.multitest import fdrcorrection

def save_df_to_npz(obj, filename):
    np.savez_compressed(filename, data=obj.values, index=obj.index.values, columns=obj.columns.values)

def load_df_from_npz(filename):
    with np.load(filename, allow_pickle=True) as f:
        obj = pd.DataFrame(**f)
    return obj

# %% [markdown]
# ## First we do an explicit analysis of replicate samples across and within the two arrays to find variants that are frequently discrepant between the two batches

# %% [markdown]
# ## Output subset of samples with duplicates as a VCF

# %%
postpostfn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/ExpectedDuplicates/Post2016_DuplicateSelection_Merged_Complete_20190822.tsv'
postpost = pd.read_csv(postpostfn, sep='\t')

# %%
prepostreps = pd.read_csv('gs://popgen-gwas/data/metadata/Annotated_GenotypedData/ExpectedDuplicates/Pre_To_Post_Duplicate_Mapping_20190822.tsv', sep='\t')
prepostreps['Post_ID'].head()
# Out:
# 0      WG0284565-DNA_C12_G-7167
# 1       WG0284572-DNA_E05_S-107
# 2      WG0284580-DNA_H09_G-7895
# 3    WG0284582-DNA_A02_F-SL-71C
# 4    WG0284582-DNA_A03_SM-72YJL
# Name: Post_ID, dtype: object

# %%
postrepsamples = list(set(postpost['IID']).union(prepostreps['Post_ID']))

# %%
a = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy'

# %%
phenofn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/preANDpost2016_Merged_Complete_Metadata_WithAge_20210818.tsv'

# %%
metadata = pd.read_csv(phenofn, sep='\t')
metadata.index = metadata['Full_IID']

# %%
cmd = 'cp {a}.fam {a}.orig.fam'.format(a=a)
print(cmd)
# !{cmd}
fam = pd.read_csv(a+'.fam', sep='\t', header=None)
fam.index = fam[1]
fam[4] = metadata.loc[fam.index, 'sex'].replace({np.nan:0, 'M':1, 'F':2})
fam.to_csv(a+'.fam', sep='\t', header=False, index=False)
fam.head()
# Out:
# cp ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.fam ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.orig.fam
#                               0                             1  2  3  4  5
# 1
# WG0284565-DNA_A03_G-5686      0      WG0284565-DNA_A03_G-5686  0  0  2 -9
# WG0341167-DNA_A03_1079-LV-18  0  WG0341167-DNA_A03_1079-LV-18  0  0  1 -9
# WG0284565-DNA_B02_G-5585      0      WG0284565-DNA_B02_G-5585  0  0  2 -9
# WG0341167-DNA_A04_0406-LV-18  0  WG0341167-DNA_A04_0406-LV-18  0  0  1 -9
# WG0284565-DNA_B03_G-4468      0      WG0284565-DNA_B03_G-4468  0  0  1 -9

# %%
fam[1].isin(postrepsamples).value_counts()
# Out:
# False    2102
# True      739
# Name: 1, dtype: int64

# %%
repsamplesfn = a+'.HasReplicateSamples.tsv'
print(repsamplesfn)
fam.loc[fam[1].isin(postrepsamples), [0,1]].to_csv(repsamplesfn, sep='\t', header=None, index=False)
# Out:
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.tsv

# %%
cmd = 'plink --bfile {a} --recode vcf-iid --out {a}.HasReplicateSamples --keep-allele-order --keep {a}.HasReplicateSamples.tsv'.format(a=a)
print(cmd)
# !{cmd}
# Out:
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy --recode vcf-iid --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples --keep-allele-order --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.tsv
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#   --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.tsv
#   --keep-allele-order
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples
#   --recode vcf-iid
#
# 64423 MB RAM detected; reserving 32211 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2841 people (1453 males, 1388 females) loaded from .fam.
# --keep: 739 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 739 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 20614 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995042.
# 1993285 variants and 739 people pass filters and QC.
# Note: No phenotypes present.
# --recode vcf-iid to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.vcf
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %% [markdown]
# ## Evaluate batch effect between the 2 H3 batches

# %%
repvcffn = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.vcf'
repvcf = pd.read_csv(repvcffn, sep='\t', skiprows=30)
print('a')
repvcf.index = repvcf['ID']
repvcf = repvcf.iloc[:,9:]
print('b')
repvcf = repvcf.replace({'1/1':2, '0/0':0, '0/1':1, './.':-1})
print('c')
repvcf.head()
# Out:
# a
# b
# c
#               WG0341167-DNA_A04_0406-LV-18  WG0284565-DNA_B03_G-4468  \
# ID
# 1:54676:A:G                              2                         2
# 1:108310:A:G                             0                         0
# 1:256586:A:C                             0                         0
# 1:534247:A:G                             0                         0
# 1:723918:A:G                             0                         0
#
#               WG0284565-DNA_B12_G-7174  WG0341167-DNA_A10_0205-LV-18  \
# ID
# 1:54676:A:G                          2                             2
# 1:108310:A:G                         0                             0
# 1:256586:A:C                         1                             0
# 1:534247:A:G                         0                             0
# 1:723918:A:G                         1                             0
#
#               WG0284565-DNA_C12_G-7167  WG0341167-DNA_A11_0221-LV-18  \
# ID
# 1:54676:A:G                          2                             2
# 1:108310:A:G                         0                             0
# 1:256586:A:C                         0                             0
# 1:534247:A:G                         0                             0
# 1:723918:A:G                         0                             0
#
#               WG0284565-DNA_D02_G-4899  WG0284565-DNA_E12_G-7127  \
# ID
# 1:54676:A:G                          2                         2
# 1:108310:A:G                         0                         0
# 1:256586:A:C                         0                         0
# 1:534247:A:G                         0                         0
# 1:723918:A:G                         1                         0
#
#               WG0341167-DNA_B10_0651-LV-18  WG0284565-DNA_G03_G-5527  ...  \
# ID                                                                    ...
# 1:54676:A:G                              2                         2  ...
# 1:108310:A:G                             0                         0  ...
# 1:256586:A:C                             1                         0  ...
# 1:534247:A:G                             1                         0  ...
# 1:723918:A:G                             1                         0  ...
#
#               WG0284587-DNA_H08_G-7823  WG0284565-DNA_A02_G-5231  \
# ID
# 1:54676:A:G                          2                         2
# 1:108310:A:G                         0                         0
# 1:256586:A:C                         0                         0
# 1:534247:A:G                         1                         1
# 1:723918:A:G                         0                         0
#
#               WG0284565-DNA_A11_G-5135  WG0284565-DNA_F04_G-4007  \
# ID
# 1:54676:A:G                          2                         2
# 1:108310:A:G                         0                         0
# 1:256586:A:C                         1                         0
# 1:534247:A:G                         0                         0
# 1:723918:A:G                         0                         1
#
#               WG0284565-DNA_H08_G-5932  WG0284569-DNA_F05_S-275  \
# ID
# 1:54676:A:G                          2                        2
# 1:108310:A:G                         0                       -1
# 1:256586:A:C                         0                        0
# 1:534247:A:G                         0                        0
# 1:723918:A:G                         0                        0
#
#               WG0284572-DNA_A10_S-079  WG0284579-DNA_D04_C-284-1  \
# ID
# 1:54676:A:G                         2                          2
# 1:108310:A:G                        0                          0
# 1:256586:A:C                        0                          0
# 1:534247:A:G                        0                          0
# 1:723918:A:G                        0                          0
#
#               WG0284584-DNA_A03_C-016-1  WG0284584-DNA_G01_G-5748
# ID
# 1:54676:A:G                           2                         2
# 1:108310:A:G                          0                         0
# 1:256586:A:C                          1                         1
# 1:534247:A:G                          0                         0
# 1:723918:A:G                          0                         0
#
# [5 rows x 739 columns]

# %%
outfn = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.vcf.npz'

# %%
save_df_to_npz(repvcf, outfn)

# %%
! ls ../../data/tmp/plink/H3/*.vcf
# Out:
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.HasReplicateSamples.vcf

# %%
! gsutil ls gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/*.vcf
# Out:
# gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.TopA1.NoMulti.NoSexDisc.mDupVars.vcf

# %%
repvcf = load_df_from_npz(outfn)

# %%
b1 = '../../data/tmp/plink/H3/USA_H3Africa_Broad_Barnes_2018.11_Batch1_Final_TopStrand'
b2 = '../../data/tmp/plink/H3/Broad_Barnes_H3Africa_2019.04'

# %%
b1samps = list(pd.read_csv(b1+'.fam', sep=' ', header=None)[1])
b2samps = list(pd.read_csv(b2+'.fam', sep=' ', header=None)[1])
merged_dict = dict(zip(b1samps, ['B1']*len(b1samps)))
print(len(merged_dict))
merged_dict.update(dict(zip(b2samps, ['B2']*len(b2samps))))
print(len(b1samps), len(b2samps), len(merged_dict))
# Out:
# 1598
# 1598 1440 3038

# %%
dupgroups = []
for dp in postpost['Duplicate_Pair'].unique():
    items = dp.split('---')
    b1 = []
    b2 = []
    for i in items:
        if i in repvcf.columns:
            if i in b1samps:
                b1.append(i)
            elif i in b2samps:
                b2.append(i)
    dupgroups.append([b1, b2])

# %%
cols = ['B1_AllRep_Concordance', 'B1_Dedup_Concordance', 'B1_AllRep_Total', 'B1_Dedup_Total',
        'B2_AllRep_Concordance', 'B2_Dedup_Concordance', 'B2_AllRep_Total', 'B2_Dedup_Total',
        'Between_AllRep_Concordance', 'Between_Dedup_Concordance', 'Between_AllRep_Total', 'Between_Dedup_Total']
results = pd.DataFrame(0, index=repvcf.index, columns=cols)
results.head()

disc = np.zeros(results.shape[0])
counter = pd.Series(disc, index=results.index)
discrepancy = pd.Series(disc, index=results.index)
for (b1, b2) in dupgroups:
    if len(b1) > 1:
        counter_new = counter.copy()
        discrepancy_new = discrepancy.copy()
        for i in range(len(b1)-1):
            for j in range(i+1, len(b1)):
                nonnull = (repvcf[b1[i]] != -1) & (repvcf[b1[j]] != -1)
                counter_new += nonnull
                discrepancy_new += ((repvcf[b1[i]] != repvcf[b1[j]]) & nonnull)
        results['B1_AllRep_Total'] += counter_new
        results['B1_AllRep_Concordance'] += discrepancy_new
        ind = counter_new > 0
        results.loc[ind, 'B1_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
        results.loc[ind, 'B1_Dedup_Total'] += 1
        
    if len(b2) > 1:
        counter_new = counter.copy()
        discrepancy_new = discrepancy.copy()
        for i in range(len(b2)-1):
            for j in range(i+1, len(b2)):
                nonnull = (repvcf[b2[i]] != -1) & (repvcf[b2[j]] != -1)
                counter_new += nonnull
                discrepancy_new += ((repvcf[b2[i]] != repvcf[b2[j]]) & nonnull)
        results['B2_AllRep_Total'] += counter_new
        results['B2_AllRep_Concordance'] += discrepancy_new
        ind = counter_new > 0
        results.loc[ind, 'B2_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
        results.loc[ind, 'B2_Dedup_Total'] += 1        
        
        
    if (len(b1) > 0) and (len(b2) > 0) :
        counter_new = counter.copy()
        discrepancy_new = discrepancy.copy()
        for i in range(len(b1)):
            for j in range(len(b2)):
                nonnull = (repvcf[b1[i]] != -1) & (repvcf[b2[j]] != -1)
                counter_new += nonnull
                discrepancy_new += ((repvcf[b1[i]] != repvcf[b2[j]]) & nonnull)
        results['Between_AllRep_Total'] += counter_new
        results['Between_AllRep_Concordance'] += discrepancy_new
        ind = counter_new > 0
        results.loc[ind, 'Between_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
        results.loc[ind, 'Between_Dedup_Total'] += 1

# %%
x = (results['B1_AllRep_Concordance'] + results['B2_AllRep_Concordance']) / (results['B1_AllRep_Total'] + results['B2_AllRep_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = results['Between_AllRep_Concordance'] / results['Between_AllRep_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind])
plt.plot([0,.6], [0,.6], color='r')

plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('All replicates')
# Out:
# Text(0.5, 1.0, 'All replicates')

# %%
x = (results['B1_Dedup_Concordance'] + results['B2_Dedup_Concordance']) / (results['B1_Dedup_Total'] + results['B2_Dedup_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = results['Between_Dedup_Concordance'] / results['Between_Dedup_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind])
plt.plot([0,.6], [0,.6], color='r')
plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('Deduplicated replicates')
# Out:
# Text(0.5, 1.0, 'Deduplicated replicates')

# %%
results.head()
# Out:
#               B1_AllRep_Concordance  B1_Dedup_Concordance  B1_AllRep_Total  \
# 1:54676:A:G                     0.0                   0.0            100.0
# 1:108310:A:G                    0.0                   0.0             95.0
# 1:256586:A:C                    0.0                   0.0            100.0
# 1:534247:A:G                    0.0                   0.0             99.0
# 1:723918:A:G                    0.0                   0.0            100.0
#
#               B1_Dedup_Total  B2_AllRep_Concordance  B2_Dedup_Concordance  \
# 1:54676:A:G               71                    0.0                   0.0
# 1:108310:A:G              68                    0.0                   0.0
# 1:256586:A:C              71                    0.0                   0.0
# 1:534247:A:G              70                    0.0                   0.0
# 1:723918:A:G              71                    0.0                   0.0
#
#               B2_AllRep_Total  B2_Dedup_Total  Between_AllRep_Concordance  \
# 1:54676:A:G             205.0             124                         0.0
# 1:108310:A:G            212.0             124                         0.0
# 1:256586:A:C            207.0             124                         0.0
# 1:534247:A:G            213.0             125                         0.0
# 1:723918:A:G            214.0             126                         0.0
#
#               Between_Dedup_Concordance  Between_AllRep_Total  \
# 1:54676:A:G                         0.0                  66.0
# 1:108310:A:G                        0.0                  62.0
# 1:256586:A:C                        0.0                  65.0
# 1:534247:A:G                        0.0                  65.0
# 1:723918:A:G                        0.0                  66.0
#
#               Between_Dedup_Total
# 1:54676:A:G                    49
# 1:108310:A:G                   45
# 1:256586:A:C                   48
# 1:534247:A:G                   48
# 1:723918:A:G                   49

# %%
resultsfn = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.DuplicateDiscrepancyCounts.tsv'
results.to_csv(resultsfn, sep='\t')

# %%
resultsfn = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.DuplicateDiscrepancyCounts.tsv'

results = pd.read_csv(resultsfn, sep='\t', index_col=0)
results.head()
# Out:
#               B1_AllRep_Concordance  B1_Dedup_Concordance  B1_AllRep_Total  \
# 1:54676:A:G                     0.0                   0.0            100.0
# 1:108310:A:G                    0.0                   0.0             95.0
# 1:256586:A:C                    0.0                   0.0            100.0
# 1:534247:A:G                    0.0                   0.0             99.0
# 1:723918:A:G                    0.0                   0.0            100.0
#
#               B1_Dedup_Total  B2_AllRep_Concordance  B2_Dedup_Concordance  \
# 1:54676:A:G               71                    0.0                   0.0
# 1:108310:A:G              68                    0.0                   0.0
# 1:256586:A:C              71                    0.0                   0.0
# 1:534247:A:G              70                    0.0                   0.0
# 1:723918:A:G              71                    0.0                   0.0
#
#               B2_AllRep_Total  B2_Dedup_Total  Between_AllRep_Concordance  \
# 1:54676:A:G             205.0             124                         0.0
# 1:108310:A:G            212.0             124                         0.0
# 1:256586:A:C            207.0             124                         0.0
# 1:534247:A:G            213.0             125                         0.0
# 1:723918:A:G            214.0             126                         0.0
#
#               Between_Dedup_Concordance  Between_AllRep_Total  \
# 1:54676:A:G                         0.0                  66.0
# 1:108310:A:G                        0.0                  62.0
# 1:256586:A:C                        0.0                  65.0
# 1:534247:A:G                        0.0                  65.0
# 1:723918:A:G                        0.0                  66.0
#
#               Between_Dedup_Total
# 1:54676:A:G                    49
# 1:108310:A:G                   45
# 1:256586:A:C                   48
# 1:534247:A:G                   48
# 1:723918:A:G                   49

# %%
a = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy'

# %% [markdown]
# ## Check missingness

# %%
cmd = 'plink --missing --bfile {a} --out {a}'.format(a=a)
print(cmd)
# !{cmd}
# Out:
# plink --missing --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#   --missing
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2841 people (1453 males, 1388 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2841 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 99597 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995301.
# --missing: Sample missing data report written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.imiss,
# and variant-based missing data report written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.lmiss.

# %%
varmiss = pd.read_csv('{a}.lmiss'.format(a=a), sep='\s+')
vc = varmiss['N_MISS'].value_counts()
vc.loc[vc.index>500].head()
# Out:
# 1319    190
# 1318    164
# 1320    154
# 1322    149
# 1323    148
# Name: N_MISS, dtype: int64

# %%
_ = plt.hist(varmiss.loc[varmiss['F_MISS']>.05, 'F_MISS'], bins=100)

# %% [markdown]
# ## Allele frequency association approach

# %%
a
# Out:
# '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy'

# %%
dupstofilter = list(postpost.loc[postpost['IID'] != postpost['Duplicate_To_Use'], 'IID'])
idfile = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_dupstofilter.txt'

fam = pd.read_csv(a+'.fam', sep='\t', header=None)
fam.index = fam[1]
dupstofilter = list(set(dupstofilter).intersection(fam[1]))
fam.loc[dupstofilter, [0,1]].to_csv(idfile, sep='\t', index=None, header=None)

# %%
phenofn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/preANDpost2016_Merged_Complete_Metadata_WithAge_20210818.tsv'
phenoinfo = pd.read_csv(phenofn, sep='\t')
phenoinfo.index = phenoinfo['Full_IID']

group_fn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/OmniH3Merged_PrePost2016_AggregatedLASVPhenotypes_20210829.tsv'
groups = pd.read_csv(group_fn, sep='\t')
groups.index = groups['#IID']
ind = groups.index[groups['Post2016_NG_LASV_qPCR2xPosOrSeqPos'] | groups['Post2016_NG_LASV_SeqPos'] | groups['Pre2016_NG_LASV_SeqPos'] | groups['Pre2016_SL_LASV_AgORSeqPos'] | groups['Post2016_SL_LASV_AgPos']]
phenoinfo['LASV_Case'] = 0
phenoinfo.loc[ind, 'LASV_Case'] = 1


phenoinfo.head().T
# Out:
# Full_IID                July2014NG_SM-6C4M9  July2014NG_SM-4XBS9  \
# Full_IID                July2014NG_SM-6C4M9  July2014NG_SM-4XBS9
# Genotype_Sex                              1                    2
# ID_Reformat                        SM-6C4M9             SM-4XBS9
# SampleType                 SuspectedLassaNG     Pre2016ControlNG
# sex                                       1                    2
# Disease                               Lassa                Lassa
# ISTH_SandR_Key                          NaN                  NaN
# KGH_Survivor_Key                        NaN                  NaN
# KGH_AcuteLassa_Key                      NaN                  NaN
# KGH_AcuteEbola_Key                      NaN                  NaN
# Pre2016_Diagnostic_Key             SM-6C4M9             SM-4XBS9
# Pre2016_GP_Key                     SM-6C4M9             SM-51X5Q
# ISTH_closecontact_Key                   NaN                  NaN
# Regenotyped                           False                False
# Batch                            July2014NG           July2014NG
# Country                                  NG                   NG
# Sex_Discrepant                        False                False
# Sex_Discrepant_Notes                    NaN                  NaN
# Status                            Passes QC            Passes QC
# Clean_HLA_ID                            NaN                  NaN
# Epoch                               Pre2016              Pre2016
# Array                            Omni_25M_B           Omni_25M_B
# CollectionEpoch                     Pre2016              Pre2016
# Age                                      30                   26
# LASV_Case                                 0                    0
#
# Full_IID                July2014NG_SM-6C4MA  July2014NG_SM-6C4MB  \
# Full_IID                July2014NG_SM-6C4MA  July2014NG_SM-6C4MB
# Genotype_Sex                              1                    2
# ID_Reformat                        SM-6C4MA             SM-6C4MB
# SampleType                 SuspectedLassaNG     SuspectedLassaNG
# sex                                       1                    2
# Disease                               Lassa                Lassa
# ISTH_SandR_Key                          NaN                  NaN
# KGH_Survivor_Key                        NaN                  NaN
# KGH_AcuteLassa_Key                      NaN                  NaN
# KGH_AcuteEbola_Key                      NaN                  NaN
# Pre2016_Diagnostic_Key             SM-6C4MA             SM-6C4MB
# Pre2016_GP_Key                     SM-6C4MA             SM-6C4MB
# ISTH_closecontact_Key                   NaN                  NaN
# Regenotyped                           False                False
# Batch                            July2014NG           July2014NG
# Country                                  NG                   NG
# Sex_Discrepant                        False                False
# Sex_Discrepant_Notes                    NaN                  NaN
# Status                            Passes QC            Passes QC
# Clean_HLA_ID                            NaN                  NaN
# Epoch                               Pre2016              Pre2016
# Array                            Omni_25M_B           Omni_25M_B
# CollectionEpoch                     Pre2016              Pre2016
# Age                                      32                   65
# LASV_Case                                 0                    0
#
# Full_IID                July2014NG_SM-4XBSM
# Full_IID                July2014NG_SM-4XBSM
# Genotype_Sex                              2
# ID_Reformat                        SM-4XBSM
# SampleType                 Pre2016ControlNG
# sex                                       2
# Disease                               Lassa
# ISTH_SandR_Key                          NaN
# KGH_Survivor_Key                        NaN
# KGH_AcuteLassa_Key                      NaN
# KGH_AcuteEbola_Key                      NaN
# Pre2016_Diagnostic_Key             SM-4XBSM
# Pre2016_GP_Key                     SM-51X5I
# ISTH_closecontact_Key                   NaN
# Regenotyped                           False
# Batch                            July2014NG
# Country                                  NG
# Sex_Discrepant                        False
# Sex_Discrepant_Notes                    NaN
# Status                            Passes QC
# Clean_HLA_ID                            NaN
# Epoch                               Pre2016
# Array                            Omni_25M_B
# CollectionEpoch                     Pre2016
# Age                                      47
# LASV_Case                                 0

# %%
groups.columns
# Out:
# Index(['#IID', 'SEX', 'Batch', 'SampleType', 'CollectionEpoch', 'Disease',
#        'Epoch', 'Epoch_Bin', 'Country', 'Age', 'Post2016_NG_LASV_SeqPos',
#        'Post2016_NG_LASV_qPCR2xPos', 'Post2016_NG_LASV_qPCR1xPosOrSeqPos',
#        'Post2016_NG_LASV_qPCR2xPosOrSeqPos', 'Post2016_NG_LASV_qPCR1xNeg',
#        'Post2016_NG_LASV_qPCR2xNeg', 'Post2016_NG_LASV_rtpcrNeg',
#        'Post2016_NG_LASV_PopControl', 'S&R_NG_LASV_Died', 'S&R_NG_LASV_DC',
#        'Post2016_NG_LASV_qPCR2xPosOrSeqPos_Died',
#        'Post2016_NG_LASV_qPCR2xPosOrSeqPos_DC', 'Pre2016_NG_LASV_qPCR1xPos',
#        'Pre2016_NG_LASV_SeqPos', 'Pre2016_NG_LASV_Died', 'Pre2016_NG_LASV_DC',
#        'Pre2016_NG_LASV_qPCRorSeq+_Died', 'Pre2016_NG_LASV_qPCRorSeq+_DC',
#        'Pre2016_NG_LASV_PopControl', 'Pre2016_SL_LASV_qPCR1xPos',
#        'Pre2016_SL_LASV_SeqPos', 'Pre2016_SL_LASV_AgPos',
#        'Pre2016_SL_LASV_AgORSeqPos', 'Pre2016_SL_LASV_PopControl',
#        'SL_LASV_Died', 'SL_LASV_DC', 'Post2016_SL_LASV_AgPos',
#        'Pre2016_SL_LASV_AgORSeqPos_Died', 'Pre2016_SL_LASV_AgORSeqPos_DC',
#        'Post2016_SL_LASV_AgPos_Died', 'Post2016_SL_LASV_AgPos_DC',
#        'Post2016_SL_EVD_CloseContact'],
#       dtype='object')

# %%
p = 'batch'
outfn = a+'.{p}'.format(p=p)
outfn
# Out:
# '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch'

# %%
filt_cmd = 'plink --make-bed --bfile {inv} --out {ofn} --keep-allele-order --remove {filtfn}'.format(inv=a, ofn=outfn, filtfn=idfile)
print(filt_cmd)
# !{filt_cmd}

#produce a pruned subset of markers that are in approximate linkage equilibrium with each other
prunefn = outfn + 'prune.ld_3e-1.maf_1e-1'
prune_cmd = 'plink --bfile {adat} --out {adatout} --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1'.format(adat=outfn, adatout=prunefn)
print(prune_cmd)
# !{prune_cmd}

#do PCA
pca_cmd = 'plink --bfile {adat} --out {adatout} --pca 20 --extract {adatout}.prune.in'.format(adat=outfn, adatout=prunefn)
print(pca_cmd)
# !{pca_cmd}

#make square relationship matrix 
relbase = outfn + '.prune.ld_3e-1.maf_1e-1'
rel_cmd = 'plink --make-rel square --bfile {adat} --out {adatout} --extract {prune}.prune.in'.format(adat=outfn, adatout=relbase, prune=prunefn)
print(rel_cmd)
# !{rel_cmd}

relid = pd.read_csv(relbase+'.rel.id', header=None, sep ='\t')[1].iloc[0:]
rel = pd.read_csv(relbase+'.rel', header=None, sep='\t')
print(relid)
rel.index = relid
rel.columns = relid
rel.to_csv(relbase+'.rel.withids.tsv', sep='\t')
del(rel)
# Out:
# plink --make-bed --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch --keep-allele-order --remove ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_dupstofilter.txt
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch
#   --remove ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_dupstofilter.txt
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2841 people (1453 males, 1388 females) loaded from .fam.
# --remove: 2518 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2518 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 87677 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995443.
# 1993285 variants and 2518 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bed
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bim
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.fam
# ... .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2518 people (1286 males, 1232 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2518 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 87677 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995443.
# 12436 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%, due to the X
# chromosome.  You may want to use a less stringent --hwe p-value threshold for X
# chromosome variants.
# --hwe: 6793 variants removed due to Hardy-Weinberg exact test.
# 758683 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1215373 variants and 2518 people pass filters and QC.
# Note: No phenotypes present.
# Pruned 63710 variants from chromosome 1, leaving 27783.
# Pruned 72318 variants from chromosome 2, leaving 28903.
# Pruned 59750 variants from chromosome 3, leaving 24092.
# Pruned 55369 variants from chromosome 4, leaving 23051.
# Pruned 52987 variants from chromosome 5, leaving 21990.
# Pruned 56720 variants from chromosome 6, leaving 20971.
# Pruned 47068 variants from chromosome 7, leaving 20011.
# Pruned 46547 variants from chromosome 8, leaving 19412.
# Pruned 37539 variants from chromosome 9, leaving 16750.
# Pruned 42051 variants from chromosome 10, leaving 18060.
# Pruned 40665 variants from chromosome 11, leaving 17294.
# Pruned 39572 variants from chromosome 12, leaving 17164.
# Pruned 29869 variants from chromosome 13, leaving 13180.
# Pruned 26966 variants from chromosome 14, leaving 12277.
# Pruned 25756 variants from chromosome 15, leaving 12803.
# Pruned 28367 variants from chromosome 16, leaving 13635.
# Pruned 22783 variants from chromosome 17, leaving 11956.
# Pruned 24342 variants from chromosome 18, leaving 12061.
# Pruned 15536 variants from chromosome 19, leaving 8890.
# Pruned 19542 variants from chromosome 20, leaving 10009.
# Pruned 11487 variants from chromosome 21, leaving 5927.
# Pruned 11474 variants from chromosome 22, leaving 6565.
# Pruned 13875 variants from chromosome 23, leaving 8238.
# Pruned 27 variants from chromosome 24, leaving 19.
# Pruned 7 variants from chromosome 26, leaving 5.
# Pruning complete.  844327 of 1215373 variants removed.
# Marker lists written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2518 people (1286 males, 1232 females) loaded from .fam.
# --extract: 371046 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 2518 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 2792 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997624.
# 371046 variants and 2518 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 8262 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batchprune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2518 people (1286 males, 1232 females) loaded from .fam.
# --extract: 371046 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 2518 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 2792 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997624.
# 371046 variants and 2518 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 8262 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0           WG0284565-DNA_A03_G-5686
# 1       WG0341167-DNA_A03_1079-LV-18
# 2           WG0284565-DNA_B02_G-5585
# 3       WG0341167-DNA_A05_0029-LV-18
# 4           WG0284565-DNA_B12_G-7174
#                     ...
# 2513         WG0284584-DNA_F03_S-356
# 2514        WG0284584-DNA_H01_G-5959
# 2515       WG0284586-DNA_A08_C-085-3
# 2516       WG0284586-DNA_A09_C-078-1
# 2517       WG0284587-DNA_C02_C-159-1
# Name: 1, Length: 2518, dtype: object

# %%
print(outfn)
cov = pd.read_csv(outfn+'.fam', sep=' ', header=None)
cov = cov[[0,1,5]]
cov.columns = ['FID', 'IID', 'Batch']
cov.index = cov['IID']
cov['Country'] = phenoinfo.loc[cov['IID'], 'Country'].replace({'NG':0, 'SL':1}).values
cov['Batch'] = phenoinfo.loc[cov['IID'], 'Batch'].replace({'2':1, '1':0}).values
cov['LASV_Case'] = phenoinfo.loc[cov['IID'], 'LASV_Case'].values
covfn = outfn + '.cov'
cov.to_csv(covfn, sep='\t', index=False)
cov.head()
# Out:
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch
#                               FID                           IID  Batch  \
# IID
# WG0284565-DNA_A03_G-5686        0      WG0284565-DNA_A03_G-5686      0
# WG0341167-DNA_A03_1079-LV-18    0  WG0341167-DNA_A03_1079-LV-18      1
# WG0284565-DNA_B02_G-5585        0      WG0284565-DNA_B02_G-5585      0
# WG0341167-DNA_A05_0029-LV-18    0  WG0341167-DNA_A05_0029-LV-18      1
# WG0284565-DNA_B12_G-7174        0      WG0284565-DNA_B12_G-7174      0
#
#                               Country  LASV_Case
# IID
# WG0284565-DNA_A03_G-5686            1          0
# WG0341167-DNA_A03_1079-LV-18        0          1
# WG0284565-DNA_B02_G-5585            1          0
# WG0341167-DNA_A05_0029-LV-18        0          0
# WG0284565-DNA_B12_G-7174            1          0

# %%
gcsdir = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/'
outfn = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch'

# %%
cmd = 'gsutil -m cp %s.* %s' % (outfn, gcsdir)
print(cmd)
# !{cmd}
# Out:
# gsutil -m cp ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.* gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.Tokeep.txt [Content-Type=text/plain]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bed [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.Tokeep.txt [Content-Type=text/plain]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.maf_1e-2.hwe_1e-12.geno_1e-1prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# | [102/102 files][  6.7 GiB/  6.7 GiB] 100% Done  92.6 MiB/s ETA 00:00:00
# Operation completed over 102 objects/6.7 GiB.

# %%
scriptfn = 'gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R'
container = 'quay.io/dkotliar/gmmat_mkl:0.4'
    
subcmdbase = '''dsub --project sabeti-ebola-gwas \
--name %s --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" \
--logging %s \
--image %s --ssh \
--input SCRIPT=%s \
--input BEDFILE=%s.bed \
--input FAMFILE=%s.fam \
--input BIMFILE=%s.bim \
--input COVFILE=%s.cov \
--input RELATFILE=%s \
--output NULLFILE=%s \
--output OUTFINAL=%s \
--env FORMULA='Batch ~ Country + LASV_Case + 1\' \
--env NCORES=7 \
--script submit.sh'''   

workingdir = gcsdir
localdir = '../../data/tmp/plink/H3/'

name = 'H3_BothCountries_CovCC'
logbase = os.path.join(workingdir, 'log', "{job-name}-{job-id}.log")    

bedbase = outfn.replace(localdir, workingdir)
relfile = bedbase + '.prune.ld_3e-1.maf_1e-1.rel.withids.tsv'
nulloutfile = bedbase + ".nullmodelCovCC.rds"
outfinal = bedbase + ".resultsCovCC.tsv"

fullcmd = subcmdbase % (name,logbase,container,scriptfn, bedbase, bedbase, bedbase, bedbase, relfile, nulloutfile, outfinal)        
fullcmd
# Out:
# 'dsub --project sabeti-ebola-gwas --name H3_BothCountries_CovCC --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.resultsCovCC.tsv --env FORMULA=\'Batch ~ Country + LASV_Case + 1\' --env NCORES=7 --script submit.sh'

# %%
# !{fullcmd}
# Out:
# Job properties:
#   job-id: h3-bothcou--dkotliar--220107-164534-03
#   job-name: h3-bothcountries-covcc
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/11630733945095150928
# Launched job-id: h3-bothcou--dkotliar--220107-164534-03
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-bothcou--dkotliar--220107-164534-03' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-bothcou--dkotliar--220107-164534-03' --users 'dkotliar'
# h3-bothcou--dkotliar--220107-164534-03

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-bothcou--dkotliar--220107-164534-03' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# h3-bothcount...  Success   01-07 17:44:59

# %%
        
for fn in [nulloutfile, outfinal]:
    cmd = 'gsutil -m cp %s %s' % (fn, localdir)
    print(cmd)
    # !{cmd}
# Out:
# gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.nullmodelCovCC.rds ../../data/tmp/plink/H3/
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.nullmodelCovCC.rds...
# - [1/1 files][ 46.6 MiB/ 46.6 MiB] 100% Done
# Operation completed over 1 objects/46.6 MiB.
# gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.resultsCovCC.tsv ../../data/tmp/plink/H3/
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.resultsCovCC.tsv...
# / [1/1 files][222.8 MiB/222.8 MiB] 100% Done
# Operation completed over 1 objects/222.8 MiB.

# %%
outfile = "../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.resultsCovCC.tsv"
mlmares = pd.read_csv(outfile, sep='\t')
#mlmares.columns = ['SNP', 'CHR', 'POS', 'REF', 'ALT', 'N', 'MISSRATE', 'AF', 'SCORE', 'VAR', 'PVAL']
mlmares.head()
# Out:
# /opt/miniconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             SNP CHR     POS REF ALT     N  MISSRATE        AF     SCORE  \
# 0  1:108310:A:G   1  108310   T   C  2466  0.020651  0.000406 -0.148493
# 1  1:256586:A:C   1  256586   T   G  2499  0.007546  0.054022  1.501415
# 2  1:534247:A:G   1  534247   C   T  2507  0.004369  0.045074 -6.229748
# 3  1:723918:A:G   1  723918   G   A  2509  0.003574  0.095257  1.606138
# 4  1:728951:A:G   1  728951   C   T  2506  0.004766  0.136872  3.705760
#
#          VAR      PVAL
# 0   0.130754  0.681324
# 1  14.094425  0.689213
# 2  13.018543  0.084241
# 3  23.523179  0.740525
# 4  32.920256  0.518363

# %%
mlmares.index = mlmares['SNP']
mlmares.head()
# Out:
#                        SNP CHR     POS REF ALT     N  MISSRATE        AF  \
# SNP
# 1:108310:A:G  1:108310:A:G   1  108310   T   C  2466  0.020651  0.000406
# 1:256586:A:C  1:256586:A:C   1  256586   T   G  2499  0.007546  0.054022
# 1:534247:A:G  1:534247:A:G   1  534247   C   T  2507  0.004369  0.045074
# 1:723918:A:G  1:723918:A:G   1  723918   G   A  2509  0.003574  0.095257
# 1:728951:A:G  1:728951:A:G   1  728951   C   T  2506  0.004766  0.136872
#
#                  SCORE        VAR      PVAL
# SNP
# 1:108310:A:G -0.148493   0.130754  0.681324
# 1:256586:A:C  1.501415  14.094425  0.689213
# 1:534247:A:G -6.229748  13.018543  0.084241
# 1:723918:A:G  1.606138  23.523179  0.740525
# 1:728951:A:G  3.705760  32.920256  0.518363

# %%
_ = plt.hist(mlmares['PVAL'], bins=100)

# %%
results['MLMA_P'] = np.nan
overlap = list(set(results.index).intersection(set(mlmares.index)))
results.loc[overlap, 'MLMA_P'] = mlmares.loc[overlap, 'PVAL'].values

# %%
ind = ~results['MLMA_P'].isnull()
results.loc[:, 'MLMA_Q'] = np.nan
results.loc[ind, 'MLMA_Q'] =fdrcorrection(results.loc[ind, 'MLMA_P'], method='indep')[1]

# %%
results.loc[:, 'MLMA_logP'] = results.loc[:, 'MLMA_P'].apply(np.log10)*-1
results.loc[:, 'MLMA_logQ'] = results.loc[:, 'MLMA_Q'].apply(np.log10)*-1

ind = results['MLMA_logP']>20
results.loc[ind, 'MLMA_logP']=20

ind = results['MLMA_logQ']>20
results.loc[ind, 'MLMA_logQ']=20

# %%
results['Between_AllRep_FracConcordant'] = results['Between_AllRep_Concordance'] / results['Between_AllRep_Total']
results['Within_AllRep_FracConcordant']  = (results['B1_AllRep_Concordance'] + results['B2_AllRep_Concordance']) / (results['B1_AllRep_Total'] + results['B2_AllRep_Total'])

# %%
x = results['MLMA_logP']
y = results['Between_AllRep_FracConcordant']
ind = ~x.isnull()
iswithindisc = (results['Within_AllRep_FracConcordant']>0.1)

plt.scatter(x.loc[ind & ~iswithindisc], y.loc[ind & ~iswithindisc], s=3, color='b', label='Not within discordant')
plt.scatter(x.loc[ind & iswithindisc], y.loc[ind & iswithindisc], s=3, color='r', label='Within discordant')
plt.legend(loc='upper left', markerscale=4)
plt.xlabel('-Log10 AF Association P')
plt.ylabel('Between batch fraction discordant')
plt.title('All replicates')
plt.hlines(y=.1, xmin=0, xmax=21, linestyle='--')
plt.vlines(x=-1*np.log10(5*(10**-8)), ymin=0, ymax=1, linestyle='--')

# %%
pd.crosstab(x.loc[ind]>-1*np.log10(5*(10**-8)), y.loc[ind]>.1)
# Out:
# Between_AllRep_FracConcordant    False  True
# MLMA_logP
# False                          1991877    309
# True                                45     75

# %%
x = results['MLMA_logQ']
y = results['Between_AllRep_FracConcordant']
ind = ~x.isnull()

iswithindisc = (results['Within_AllRep_FracConcordant']>0.1)
plt.scatter(x.loc[ind & ~iswithindisc], y.loc[ind & ~iswithindisc], s=3, color='b', label='Not within discordant')
plt.scatter(x.loc[ind & iswithindisc], y.loc[ind & iswithindisc], s=3, color='r', label='Within discordant')
plt.legend(loc='upper left', markerscale=4)
plt.xlabel('-Log10 AF Association P')
plt.ylabel('Between batch fraction discordant')
plt.title('All replicates')
# Out:
# Text(0.5, 1.0, 'All replicates')

# %%
z = results.sort_values(by='Within_AllRep_FracConcordant', ascending=True)
x = z['MLMA_logQ']
y = z['Between_AllRep_FracConcordant']
ind = ~x.isnull()



iswithindisc = z['Within_AllRep_FracConcordant']
plt.scatter(x.loc[ind], y.loc[ind], s=3, c=iswithindisc.loc[ind])
plt.xlabel('-Log10 AF Association Q')
plt.ylabel('Between batch fraction discordant')
plt.title('All replicates')
plt.xlim([-1,10])
# Out:
# (-1, 10)

# %%
x = results['MLMA_logP']
y = results['Within_AllRep_FracConcordant']
ind = ~x.isnull()
plt.scatter(x.loc[ind], y.loc[ind], s=3)

plt.xlabel('-Log10 AF Association P')
plt.ylabel('Within batch fraction discordant')
plt.title('All replicates')
# Out:
# Text(0.5, 1.0, 'All replicates')

# %%
ind = (results['Between_AllRep_FracConcordant']>0.05) & (results['Between_AllRep_FracConcordant']<.1)  & (results['MLMA_logP']<.1)
results.loc[ind, :].sort_values(by='Within_AllRep_FracConcordant', ascending=True).head(10)
# Out:
#                   B1_AllRep_Concordance  B1_Dedup_Concordance  \
# 10:102697376:A:C                    0.0                   0.0
# 16:75045187:A:G                     0.0                   0.0
# 16:54164887:A:T                     0.0                   0.0
# 16:85982246:A:G                     0.0                   0.0
# 6:62712234:A:G                      0.0                   0.0
# 23:54572804:A:G                     0.0                   0.0
# 17:80272873:A:G                     0.0                   0.0
# 3:184135845:A:C                     0.0                   0.0
# 3:169380240:A:G                     0.0                   0.0
# 3:116483775:A:G                     0.0                   0.0
#
#                   B1_AllRep_Total  B1_Dedup_Total  B2_AllRep_Concordance  \
# 10:102697376:A:C             86.0              63                    0.0
# 16:75045187:A:G              95.0              66                    0.0
# 16:54164887:A:T              82.0              58                    0.0
# 16:85982246:A:G              86.0              63                    0.0
# 6:62712234:A:G               82.0              59                    0.0
# 23:54572804:A:G              88.0              65                    0.0
# 17:80272873:A:G              93.0              64                    0.0
# 3:184135845:A:C              74.0              55                    0.0
# 3:169380240:A:G              88.0              63                    0.0
# 3:116483775:A:G              94.0              65                    0.0
#
#                   B2_Dedup_Concordance  B2_AllRep_Total  B2_Dedup_Total  \
# 10:102697376:A:C                   0.0            151.0             102
# 16:75045187:A:G                    0.0            186.0             115
# 16:54164887:A:T                    0.0            184.0             109
# 16:85982246:A:G                    0.0            186.0             112
# 6:62712234:A:G                     0.0            188.0             104
# 23:54572804:A:G                    0.0            168.0             100
# 17:80272873:A:G                    0.0            199.0             117
# 3:184135845:A:C                    0.0            179.0             108
# 3:169380240:A:G                    0.0            177.0             105
# 3:116483775:A:G                    0.0            186.0             113
#
#                   Between_AllRep_Concordance  Between_Dedup_Concordance  \
# 10:102697376:A:C                         3.0                        2.0
# 16:75045187:A:G                          3.0                        1.0
# 16:54164887:A:T                          4.0                        3.0
# 16:85982246:A:G                          3.0                        2.0
# 6:62712234:A:G                           3.0                        3.0
# 23:54572804:A:G                          5.0                        3.0
# 17:80272873:A:G                          3.0                        1.0
# 3:184135845:A:C                          4.0                        3.0
# 3:169380240:A:G                          3.0                        1.0
# 3:116483775:A:G                          3.0                        1.0
#
#                   Between_AllRep_Total  Between_Dedup_Total    MLMA_P  \
# 10:102697376:A:C                  54.0                   40  0.897492
# 16:75045187:A:G                   59.0                   44  0.971131
# 16:54164887:A:T                   54.0                   43  0.818203
# 16:85982246:A:G                   55.0                   45  0.837293
# 6:62712234:A:G                    59.0                   43  0.999041
# 23:54572804:A:G                   56.0                   43  0.899246
# 17:80272873:A:G                   59.0                   42  0.950651
# 3:184135845:A:C                   45.0                   38  0.856901
# 3:169380240:A:G                   41.0                   35  0.802607
# 3:116483775:A:G                   54.0                   43  0.935935
#
#                     MLMA_Q  MLMA_logP  MLMA_logQ  \
# 10:102697376:A:C  0.999712   0.046969   0.000125
# 16:75045187:A:G   0.999762   0.012722   0.000103
# 16:54164887:A:T   0.999660   0.087139   0.000148
# 16:85982246:A:G   0.999660   0.077122   0.000148
# 6:62712234:A:G    0.999979   0.000417   0.000009
# 23:54572804:A:G   0.999712   0.046122   0.000125
# 17:80272873:A:G   0.999712   0.021979   0.000125
# 3:184135845:A:C   0.999660   0.067069   0.000148
# 3:169380240:A:G   0.999660   0.095497   0.000148
# 3:116483775:A:G   0.999712   0.028754   0.000125
#
#                   Between_AllRep_FracConcordant  Within_AllRep_FracConcordant
# 10:102697376:A:C                       0.055556                           0.0
# 16:75045187:A:G                        0.050847                           0.0
# 16:54164887:A:T                        0.074074                           0.0
# 16:85982246:A:G                        0.054545                           0.0
# 6:62712234:A:G                         0.050847                           0.0
# 23:54572804:A:G                        0.089286                           0.0
# 17:80272873:A:G                        0.050847                           0.0
# 3:184135845:A:C                        0.088889                           0.0
# 3:169380240:A:G                        0.073171                           0.0
# 3:116483775:A:G                        0.055556                           0.0

# %% [markdown]
# ## Repeat for Nigeria and Sierra Leone separately

# %%
dupstofilter = list(postpost.loc[postpost['IID'] != postpost['Duplicate_To_Use'], 'IID'])

# %%
raw_adat = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy'
p = 'batch'

# %%
for country in ['NG', 'SL']:
    a = raw_adat+'.{p}.{c}'.format(p=p, c=country)
    fam = pd.read_csv(raw_adat+'.fam', sep='\t', header=None)
    fam.index = fam[1]
    keep = (phenoinfo.loc[fam.index, 'Country']==country) & ~fam.index.isin(dupstofilter)    
    fam = fam.loc[keep,:]
    keepfn = '{a}.Tokeep.txt'.format(a=a)
    print(keepfn)
    fam.to_csv(keepfn, sep='\t', index=False)
    filt_cmd = 'plink --make-bed --bfile {inv} --out {ofn} --keep-allele-order --keep {keep}'.format(inv=raw_adat, ofn = a, keep=keepfn)
    print(filt_cmd)
    # !{filt_cmd}    
    
    #produce a pruned subset of markers that are in approximate linkage equilibrium with each other
    prunefn = a + '.prune.ld_3e-1.maf_1e-1'
    prune_cmd = 'plink --bfile {a} --out {prune} --indep-pairwise 1000kb 1 .3 --maf .1  --hwe 1e-12 --geno .1'.format(a=a, prune=prunefn)
    print(prune_cmd)
    # !{prune_cmd}

    #do PCA
    pca_cmd = 'plink --bfile {a} --out {prune} --pca 20 --extract {prune}.prune.in'.format(a=a, prune=prunefn)
    print(pca_cmd)
    # !{pca_cmd}
    
    #make square relationship matrix 
    relbase = prunefn
    rel_cmd = 'plink --make-rel square --bfile {a} --out {rel} --extract {prune}.prune.in'.format(a=a, rel=relbase, prune=prunefn)
    print(rel_cmd)
    # !{rel_cmd}

    relid = pd.read_csv(relbase+'.rel.id', header=None, sep ='\t')[1].iloc[0:]
    rel = pd.read_csv(relbase+'.rel', header=None, sep='\t')
    print(relid)
    rel.index = relid
    rel.columns = relid
    relfn = relbase+'.rel.withids.tsv'
    rel.to_csv(relfn, sep='\t')    
    cov = pd.read_csv(a+'.fam', sep=' ', header=None)
    cov = cov[[0,1,5]]
    cov.columns = ['FID', 'IID', 'Batch']
    cov.index = cov['IID']
    cov['Country'] = phenoinfo.loc[cov['IID'], 'Country'].replace({'NG':0, 'SL':1}).values
    cov['Batch'] = phenoinfo.loc[cov['IID'], 'Batch'].replace({'2':1, '1':0}).values
    cov['LASV_Case'] = phenoinfo.loc[cov['IID'], 'LASV_Case'].values
    covfn = a + '.cov'
    cov.to_csv(covfn, sep='\t', index=False)
    
    '''
    ncores = 6
    bedbase = a+'.bed'
    formula = '"Batch ~ 1"'
    nulloutfile = "{a}.nullmodel.rds".format(a=a)
    outfile = "{a}.results.tsv".format(a=a)
    cmd = 'Rscript --vanilla ../../code/gwas_analysis/run_GMMAT_fromPLINK.R %s %s %s %s %s %s %d' % (covfn, bedbase, relfn, formula, nulloutfile, outfile, ncores)
    print(cmd)
    # !{cmd}
    '''
# Out:
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.Tokeep.txt
# plink --make-bed --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG --keep-allele-order --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.Tokeep.txt
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#   --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.Tokeep.txt
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2841 people (1453 males, 1388 females) loaded from .fam.
# --keep: 1023 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1023 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 41990 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.993255.
# 1993285 variants and 1023 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bed
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bim
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.fam
# ... .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1  --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1023 people (557 males, 466 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1023 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 41990 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.993255.
# 13875 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%, due to the X
# chromosome.  You may want to use a less stringent --hwe p-value threshold for X
# chromosome variants.
# --hwe: 3039 variants removed due to Hardy-Weinberg exact test.
# 761859 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1214512 variants and 1023 people pass filters and QC.
# Note: No phenotypes present.
# Pruned 64954 variants from chromosome 1, leaving 26470.
# Pruned 73830 variants from chromosome 2, leaving 27705.
# Pruned 60798 variants from chromosome 3, leaving 22992.
# Pruned 56324 variants from chromosome 4, leaving 22033.
# Pruned 53748 variants from chromosome 5, leaving 21135.
# Pruned 57661 variants from chromosome 6, leaving 19956.
# Pruned 48085 variants from chromosome 7, leaving 18877.
# Pruned 47405 variants from chromosome 8, leaving 18371.
# Pruned 38454 variants from chromosome 9, leaving 15934.
# Pruned 42748 variants from chromosome 10, leaving 17179.
# Pruned 41516 variants from chromosome 11, leaving 16371.
# Pruned 40443 variants from chromosome 12, leaving 16291.
# Pruned 30414 variants from chromosome 13, leaving 12736.
# Pruned 27600 variants from chromosome 14, leaving 11597.
# Pruned 26459 variants from chromosome 15, leaving 12105.
# Pruned 28850 variants from chromosome 16, leaving 13091.
# Pruned 23262 variants from chromosome 17, leaving 11495.
# Pruned 24709 variants from chromosome 18, leaving 11592.
# Pruned 15843 variants from chromosome 19, leaving 8554.
# Pruned 19811 variants from chromosome 20, leaving 9660.
# Pruned 11724 variants from chromosome 21, leaving 5654.
# Pruned 11730 variants from chromosome 22, leaving 6253.
# Pruned 14120 variants from chromosome 23, leaving 7941.
# Pruned 11 variants from chromosome 24, leaving 10.
# Pruned 6 variants from chromosome 26, leaving 5.
# Pruning complete.  860505 of 1214512 variants removed.
# Marker lists written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1023 people (557 males, 466 females) loaded from .fam.
# --extract: 354007 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 1023 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1329 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997415.
# 354007 variants and 1023 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 7956 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1023 people (557 males, 466 females) loaded from .fam.
# --extract: 354007 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 1023 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1329 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997415.
# 354007 variants and 1023 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 7956 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0           WG0341167-DNA_A03_1079-LV-18
# 1           WG0341167-DNA_A05_0029-LV-18
# 2           WG0341167-DNA_A08_1140-LV-18
# 3           WG0341167-DNA_A09_0661-LV-18
# 4           WG0341167-DNA_A10_0205-LV-18
#                       ...
# 1018        WG0341185-DNA_H04_0091-LV-17
# 1019        WG0341185-DNA_H05_0309-LV-17
# 1020        WG0341185-DNA_H06_0056-LV-18
# 1021        WG0341185-DNA_H08_1992-LV-17
# 1022    WG0284584-DNA_E11_ISTH-CASE-2806
# Name: 1, Length: 1023, dtype: object
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.Tokeep.txt
# plink --make-bed --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL --keep-allele-order --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.Tokeep.txt
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy
#   --keep ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.Tokeep.txt
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 2841 people (1453 males, 1388 females) loaded from .fam.
# --keep: 1495 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1495 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 45687 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.99694.
# 1993285 variants and 1495 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bed
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bim
# +
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.fam
# ... .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1  --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1495 people (729 males, 766 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1495 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 45687 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99694.
# 9462 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%, due to the X
# chromosome.  You may want to use a less stringent --hwe p-value threshold for X
# chromosome variants.
# --hwe: 4531 variants removed due to Hardy-Weinberg exact test.
# 761095 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1218197 variants and 1495 people pass filters and QC.
# Note: No phenotypes present.
# Pruned 63697 variants from chromosome 1, leaving 28007.
# Pruned 72383 variants from chromosome 2, leaving 29025.
# Pruned 59525 variants from chromosome 3, leaving 24342.
# Pruned 55576 variants from chromosome 4, leaving 23133.
# Pruned 53114 variants from chromosome 5, leaving 22103.
# Pruned 56606 variants from chromosome 6, leaving 21179.
# Pruned 47077 variants from chromosome 7, leaving 20155.
# Pruned 46495 variants from chromosome 8, leaving 19621.
# Pruned 37407 variants from chromosome 9, leaving 16905.
# Pruned 42036 variants from chromosome 10, leaving 18193.
# Pruned 40865 variants from chromosome 11, leaving 17420.
# Pruned 39526 variants from chromosome 12, leaving 17356.
# Pruned 29901 variants from chromosome 13, leaving 13273.
# Pruned 27005 variants from chromosome 14, leaving 12391.
# Pruned 25791 variants from chromosome 15, leaving 12908.
# Pruned 28328 variants from chromosome 16, leaving 13668.
# Pruned 22860 variants from chromosome 17, leaving 11980.
# Pruned 24439 variants from chromosome 18, leaving 12117.
# Pruned 15585 variants from chromosome 19, leaving 8931.
# Pruned 19539 variants from chromosome 20, leaving 10045.
# Pruned 11527 variants from chromosome 21, leaving 5966.
# Pruned 11482 variants from chromosome 22, leaving 6627.
# Pruned 13807 variants from chromosome 23, leaving 8223.
# Pruned 23 variants from chromosome 24, leaving 23.
# Pruned 7 variants from chromosome 26, leaving 5.
# Pruning complete.  844601 of 1218197 variants removed.
# Marker lists written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1495 people (729 males, 766 females) loaded from .fam.
# --extract: 373596 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 1495 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1463 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997732.
# 373596 variants and 1495 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 8251 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL
#   --extract ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 1993285 variants loaded from .bim file.
# 1495 people (729 males, 766 females) loaded from .fam.
# --extract: 373596 variants remaining.
# Using up to 15 threads (change this with --threads).
# Before main variant filters, 1495 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1463 het. haploid genotypes present (see
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997732.
# 373596 variants and 1495 people pass filters and QC.
# Note: No phenotypes present.
# Excluding 8251 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0        WG0284565-DNA_A03_G-5686
# 1        WG0284565-DNA_B02_G-5585
# 2        WG0284565-DNA_B12_G-7174
# 3        WG0284565-DNA_C02_G-3205
# 4        WG0284565-DNA_C03_G-5546
#                   ...
# 1490      WG0284584-DNA_F03_S-356
# 1491     WG0284584-DNA_H01_G-5959
# 1492    WG0284586-DNA_A08_C-085-3
# 1493    WG0284586-DNA_A09_C-078-1
# 1494    WG0284587-DNA_C02_C-159-1
# Name: 1, Length: 1495, dtype: object

# %%
gcsdir = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/'
for country in ['NG', 'SL']:
    outfn = raw_adat+'.{p}.{c}'.format(p=p, c=country)
    print(outfn)
    cmd = 'gsutil -m cp %s.* %s' % (outfn, gcsdir)
    print(cmd)
    # !{cmd}
# Out:
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG
# gsutil -m cp ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.* gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.Tokeep.txt [Content-Type=text/plain]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.hh [Content-Type=text/x-c++hdr]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# - [35/35 files][  1.6 GiB/  1.6 GiB] 100% Done
# Operation completed over 35 objects/1.6 GiB.
# ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL
# gsutil -m cp ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.* gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.Tokeep.txt [Content-Type=text/plain]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bed [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.maf_1e-2.hwe_1e-12.geno_1e-1.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# / [35/35 files][  2.1 GiB/  2.1 GiB] 100% Done 112.9 MiB/s ETA 00:00:00
# Operation completed over 35 objects/2.1 GiB.

# %%
scriptfn = 'gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R'
container = 'quay.io/dkotliar/gmmat_mkl:0.4'
    
subcmdbase = '''dsub --project sabeti-ebola-gwas \
--name %s --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" \
--logging %s \
--image %s --ssh \
--input SCRIPT=%s \
--input BEDFILE=%s.bed \
--input FAMFILE=%s.fam \
--input BIMFILE=%s.bim \
--input COVFILE=%s.cov \
--input RELATFILE=%s \
--output NULLFILE=%s \
--output OUTFINAL=%s \
--env FORMULA='Batch ~ LASV_Case + 1\' \
--env NCORES=7 \
--script submit.sh'''   

workingdir = gcsdir
localdir = '../../data/tmp/plink/H3/'

logbase = os.path.join(workingdir, 'log', "{job-name}-{job-id}.log")    
fullcmds = []
for country in ['NG', 'SL']:
    name = 'H3_%s_CovCC_minfilt' % country
    outfn = raw_adat+'.{p}.{c}'.format(p=p, c=country)
    bedbase = outfn.replace(localdir, workingdir)
    relfile = bedbase + '.prune.ld_3e-1.maf_1e-1.rel.withids.tsv'
    nulloutfile = bedbase + ".nullmodelCovCC.rds"
    outfinal = bedbase + ".resultsCovCC.tsv"

    fullcmd = subcmdbase % (name,logbase,container,scriptfn, bedbase, bedbase, bedbase, bedbase, relfile, nulloutfile, outfinal)        
    print(fullcmd)
    fullcmds.append(fullcmd)
# Out:
# dsub --project sabeti-ebola-gwas --name H3_NG_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# dsub --project sabeti-ebola-gwas --name H3_SL_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh

# %%
for cmd in fullcmds:
    # !{cmd}
# Out:
# Job properties:
#   job-id: h3-ng-covc--dkotliar--220107-183419-46
#   job-name: h3-ng-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/6147818264664771862
# Launched job-id: h3-ng-covc--dkotliar--220107-183419-46
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-ng-covc--dkotliar--220107-183419-46' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-ng-covc--dkotliar--220107-183419-46' --users 'dkotliar'
# h3-ng-covc--dkotliar--220107-183419-46
# Job properties:
#   job-id: h3-sl-covc--dkotliar--220107-183420-36
#   job-name: h3-sl-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/8930313513792098573
# Launched job-id: h3-sl-covc--dkotliar--220107-183420-36
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-sl-covc--dkotliar--220107-183420-36' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-sl-covc--dkotliar--220107-183420-36' --users 'dkotliar'
# h3-sl-covc--dkotliar--220107-183420-36

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-ng-covc--dkotliar--220107-183419-46' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# h3-ng-covcc-...  Success   01-07 19:15:12

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'h3-sl-covc--dkotliar--220107-183420-36' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# h3-sl-covcc-...  Success   01-07 19:21:15

# %%
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.resultsCovCC.tsv ../../data/tmp/plink/H3/
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.nullmodelCovCC.rds  ../../data/tmp/plink/H3/
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.resultsCovCC.tsv ../../data/tmp/plink/H3/
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.nullmodelCovCC.rds  ../../data/tmp/plink/H3/
# Out:
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.resultsCovCC.tsv...
# / [1/1 files][217.9 MiB/217.9 MiB] 100% Done
# Operation completed over 1 objects/217.9 MiB.
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.NG.nullmodelCovCC.rds...
# / [1/1 files][  7.6 MiB/  7.6 MiB] 100% Done
# Operation completed over 1 objects/7.6 MiB.
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.resultsCovCC.tsv...
# / [1/1 files][218.3 MiB/218.3 MiB] 100% Done
# Operation completed over 1 objects/218.3 MiB.
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.SL.nullmodelCovCC.rds...
# - [1/1 files][ 16.1 MiB/ 16.1 MiB] 100% Done
# Operation completed over 1 objects/16.1 MiB.

# %%
import sys
sys.path.append('../../code/gwas_analysis')
from gwas_plotting import manhattan, qqplot

# %%
percountry_mlmares = {}
for country in ['NG', 'SL']:
    outfile = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.renamesexchr.sorted.fixPloidy.batch.{c}.resultsCovCC.tsv'.format(c=country)
    percountry_mlmares[country] = pd.read_csv(outfile, sep='\t')
    
    (fig,ax) = plt.subplots(1,1, figsize=(2,2), dpi=200)
    _ = ax.hist(percountry_mlmares[country]['PVAL'], bins=100)
    ax.set_title('%s only H3 B1 vs B2' % country, fontsize=7)
    
    ax = qqplot(percountry_mlmares[country]['PVAL'], title='%s only H3 B1 vs B2' % country)
    ax.set_xlim([0,10])
    ax.set_ylim([0,40])
# Out:
# /opt/miniconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
results.head()
# Out:
#               B1_AllRep_Concordance  B1_Dedup_Concordance  B1_AllRep_Total  \
# 1:54676:A:G                     0.0                   0.0            100.0
# 1:108310:A:G                    0.0                   0.0             95.0
# 1:256586:A:C                    0.0                   0.0            100.0
# 1:534247:A:G                    0.0                   0.0             99.0
# 1:723918:A:G                    0.0                   0.0            100.0
#
#               B1_Dedup_Total  B2_AllRep_Concordance  B2_Dedup_Concordance  \
# 1:54676:A:G               71                    0.0                   0.0
# 1:108310:A:G              68                    0.0                   0.0
# 1:256586:A:C              71                    0.0                   0.0
# 1:534247:A:G              70                    0.0                   0.0
# 1:723918:A:G              71                    0.0                   0.0
#
#               B2_AllRep_Total  B2_Dedup_Total  Between_AllRep_Concordance  \
# 1:54676:A:G             205.0             124                         0.0
# 1:108310:A:G            212.0             124                         0.0
# 1:256586:A:C            207.0             124                         0.0
# 1:534247:A:G            213.0             125                         0.0
# 1:723918:A:G            214.0             126                         0.0
#
#               Between_Dedup_Concordance  Between_AllRep_Total  \
# 1:54676:A:G                         0.0                  66.0
# 1:108310:A:G                        0.0                  62.0
# 1:256586:A:C                        0.0                  65.0
# 1:534247:A:G                        0.0                  65.0
# 1:723918:A:G                        0.0                  66.0
#
#               Between_Dedup_Total    MLMA_P    MLMA_Q  MLMA_logP  MLMA_logQ  \
# 1:54676:A:G                    49       NaN       NaN        NaN        NaN
# 1:108310:A:G                   45  0.681324  0.999660   0.166646   0.000148
# 1:256586:A:C                   48  0.689213  0.999660   0.161647   0.000148
# 1:534247:A:G                   48  0.084241  0.999501   1.074475   0.000217
# 1:723918:A:G                   49  0.740525  0.999660   0.130460   0.000148
#
#               Between_AllRep_FracConcordant  Within_AllRep_FracConcordant
# 1:54676:A:G                             0.0                           0.0
# 1:108310:A:G                            0.0                           0.0
# 1:256586:A:C                            0.0                           0.0
# 1:534247:A:G                            0.0                           0.0
# 1:723918:A:G                            0.0                           0.0

# %%
for country in ['NG', 'SL']:
    ind = percountry_mlmares[country]['SNP']
    percountry_mlmares[country].index = ind
    # Excludes chr25 variants
    overlap = list(set(ind).intersection(results.index))
    results['%s_MLMA_P' % country] = np.nan
    results.loc[overlap, '%s_MLMA_P' % country] = percountry_mlmares[country].loc[overlap, 'PVAL']
    print(country)
    display(pd.crosstab(results['MLMA_P']< 5e-8, results['%s_MLMA_P' % country]< 5e-8))
    display(pd.crosstab(results['MLMA_P']< 5e-6, results['%s_MLMA_P' % country]< 5e-6))
# Out:
# NG
# NG_MLMA_P    False  True
# MLMA_P
# False      1992921    244
# True            46     74
# NG_MLMA_P    False  True
# MLMA_P
# False      1992652    372
# True           142    119
# SL
# SL_MLMA_P    False  True
# MLMA_P
# False      1993132     33
# True            56     64
# SL_MLMA_P    False  True
# MLMA_P
# False      1992949     75
# True           148    113

# %%
for v in ['MLMA_P', 'NG_MLMA_P', 'SL_MLMA_P']:
    ind = ~results[v].isnull()
    p = results.loc[ind, v].values
    (r,q) = fdrcorrection(p)  
    v2 = v.replace('_P', '_Q')
    results.loc[:,v2] = np.nan
    results.loc[ind,v2] = q

# %%
for v in ['MLMA_P', 'NG_MLMA_P', 'SL_MLMA_P']:
    ind = ~results[v].isnull()
    p = results.loc[ind, v].values
    (r,q) = fdrcorrection(p)  
    v2 = v.replace('_P', '_Q')
    results.loc[:,v2] = np.nan
    results.loc[ind,v2] = q

# %%
q_thresh = .5
discthresh = .1
tofilter = results.index[(results['MLMA_Q']<q_thresh) | (results['NG_MLMA_Q']<q_thresh) | (results['SL_MLMA_Q']<q_thresh) | (results['Between_AllRep_FracConcordant']>discthresh)]
len(tofilter)
# Out:
# 5297

# %%
resx = []
for t in np.linspace(0, 1, 100):
    n = (results['MLMA_Q']<t).sum()
    fp = n*t
    tp = n - fp
    resx.append([t, n,fp, tp])
    
resx = pd.DataFrame(resx)

plt.plot(resx[0], resx[3], label='True positives')
plt.plot(resx[0], resx[2], label='False positives')
plt.plot(resx[0], resx[1], label='Total')

plt.xlim([0,.9])
plt.ylim([0,1000])
plt.legend()
plt.ylabel('# Called significant')
plt.xlabel('q-value threshold')
# Out:
# Text(0.5, 0, 'q-value threshold')

# %%
resx = []
for t in np.linspace(0, 1, 100):
    n = (results['NG_MLMA_Q']<t).sum()
    fp = n*t
    tp = n - fp
    resx.append([t, n,fp, tp])
    
resx = pd.DataFrame(resx)

plt.plot(resx[0], resx[3], label='True positives')
plt.plot(resx[0], resx[2], label='False positives')
plt.plot(resx[0], resx[1], label='Total')

plt.xlim([0,.9])
plt.ylim([0,3000])
plt.legend()
plt.ylabel('# Called significant')
plt.xlabel('q-value threshold')
# Out:
# Text(0.5, 0, 'q-value threshold')

# %%
resx = []
for t in np.linspace(0, 1, 100):
    n = (results['SL_MLMA_Q']<t).sum()
    fp = n*t
    tp = n - fp
    resx.append([t, n,fp, tp])
    
resx = pd.DataFrame(resx)

plt.plot(resx[0], resx[3], label='True positives')
plt.plot(resx[0], resx[2], label='False positives')
plt.plot(resx[0], resx[1], label='Total')

plt.xlim([0,.9])
plt.ylim([0,1000])
plt.legend()
plt.ylabel('# Called significant')
plt.xlabel('q-value threshold')
# Out:
# Text(0.5, 0, 'q-value threshold')

# %% [markdown]
# ## Output batch-effected variants to filter and filter

# %%
q_thresh = .25
discthresh = .1
tofilter = (results['MLMA_Q']<q_thresh) | (results['NG_MLMA_Q']<q_thresh) | (results['SL_MLMA_Q']<q_thresh) | (results['Between_AllRep_FracConcordant']>discthresh)
tofilterlist = list(results.index[tofilter])
print(len(tofilterlist))
# Out:
# 2510

# %%
results['Filtered'] = tofilter

# %%
results.head()
# Out:
#               B1_AllRep_Concordance  B1_Dedup_Concordance  B1_AllRep_Total  \
# 1:54676:A:G                     0.0                   0.0            100.0
# 1:108310:A:G                    0.0                   0.0             95.0
# 1:256586:A:C                    0.0                   0.0            100.0
# 1:534247:A:G                    0.0                   0.0             99.0
# 1:723918:A:G                    0.0                   0.0            100.0
#
#               B1_Dedup_Total  B2_AllRep_Concordance  B2_Dedup_Concordance  \
# 1:54676:A:G               71                    0.0                   0.0
# 1:108310:A:G              68                    0.0                   0.0
# 1:256586:A:C              71                    0.0                   0.0
# 1:534247:A:G              70                    0.0                   0.0
# 1:723918:A:G              71                    0.0                   0.0
#
#               B2_AllRep_Total  B2_Dedup_Total  Between_AllRep_Concordance  \
# 1:54676:A:G             205.0             124                         0.0
# 1:108310:A:G            212.0             124                         0.0
# 1:256586:A:C            207.0             124                         0.0
# 1:534247:A:G            213.0             125                         0.0
# 1:723918:A:G            214.0             126                         0.0
#
#               Between_Dedup_Concordance  ...    MLMA_Q  MLMA_logP  MLMA_logQ  \
# 1:54676:A:G                         0.0  ...       NaN        NaN        NaN
# 1:108310:A:G                        0.0  ...  0.999660   0.166646   0.000148
# 1:256586:A:C                        0.0  ...  0.999660   0.161647   0.000148
# 1:534247:A:G                        0.0  ...  0.999501   1.074475   0.000217
# 1:723918:A:G                        0.0  ...  0.999660   0.130460   0.000148
#
#               Between_AllRep_FracConcordant  Within_AllRep_FracConcordant  \
# 1:54676:A:G                             0.0                           0.0
# 1:108310:A:G                            0.0                           0.0
# 1:256586:A:C                            0.0                           0.0
# 1:534247:A:G                            0.0                           0.0
# 1:723918:A:G                            0.0                           0.0
#
#               NG_MLMA_P  SL_MLMA_P  NG_MLMA_Q  SL_MLMA_Q  Filtered
# 1:54676:A:G         NaN        NaN        NaN        NaN     False
# 1:108310:A:G        NaN   0.687995        NaN   0.998716     False
# 1:256586:A:C   0.405739   0.960823   0.996992   0.999996     False
# 1:534247:A:G   0.099889   0.187960   0.996992   0.998716     False
# 1:723918:A:G   0.517731   0.970380   0.996992   0.999996     False
#
# [5 rows x 23 columns]

# %%
local = '../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210804.CovCC.minfilt.tsv'
results.to_csv(local, sep='\t')

# %%
remote = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/'
cmd = 'gsutil -m cp {local} {remote}'.format(local=local, remote=remote)
print(cmd)
# !{cmd}
# Out:
# gsutil -m cp ../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210804.CovCC.minfilt.tsv gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/
# Copying file://../../data/tmp/plink/H3/BroadPost2016_H3_B1and2_UpdateSexandID.Coord.RefAllele.NoMulti.NoSexDisc.mDupVars.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210804.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# - [1/1 files][445.9 MiB/445.9 MiB] 100% Done
# Operation completed over 1 objects/445.9 MiB.
