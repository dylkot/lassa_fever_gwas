# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rcParams, font_manager
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42

figuredir = '../../figures'
if not os.path.exists(figuredir):
    os.mkdir(figuredir)

# %%
tmpdir = '../../data/tmp'
if not os.path.exists(tmpdir):
    os.mkdir(tmpdir)
    
hladir = os.path.join(tmpdir, 'HLA')
if not os.path.exists(hladir):
    os.mkdir(hladir)

# %%
! ls ../../data/tmp/
# Out:
# 1KG  funcchar  GWAS  HLA  LARGE  misc  plink

# %% [raw]
# gcsfn = 'gs://popgen-gwas/data/HLA/Stanford_Collaboration/Stanford_HLA.tar.gz'
# cmd = 'gsutil -m cp {gcs} {local}/'.format(gcs=gcsfn, local=hladir)
# print(cmd)
# !{cmd}

# %% [raw]
# stanfordfn = os.path.join(hladir, gcsfn.split('/')[-1])
# cmd = 'tar -xzf {fn}'.format(fn=stanfordfn)
# print(cmd)
# !{cmd}

# %% [raw]
# stanforddir = os.path.join(hladir, 'Stanford')
# cmd = 'mv ./Data_to_broad %s' % stanforddir
# print(cmd)
# !{cmd}

# %% [markdown]
# ## Process popgen data to prepare variant set for imputation

# %%
chr6dat = 'gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.*'
popgendir = '../../data/tmp/HLA/popgen/'
if not os.path.exists(popgendir):
    os.mkdir(popgendir)

# %%
cmd = 'gsutil -m cp {chrdat} {outdir}'.format(chrdat=chr6dat, outdir=popgendir)
# !{cmd}
# Out:
# Copying gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.log...
# Copying gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.pgen...
# Copying gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.psam...
# Copying gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.pvar...
# / [4/4 files][  1.3 GiB/  1.3 GiB] 100% Done  76.6 MiB/s ETA 00:00:00
# Operation completed over 4 objects/1.3 GiB.

# %%
cmd
# Out:
# 'gsutil -m cp gs://popgen-gwas/data/genotype/merge/Imputed_Plink2/OmniH3Merged_PrePost2016_20220113.INFO_8e-1.Deduped.chr6.* ../../data/tmp/HLA/popgen/'

# %%
b = '../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6'

# %%
buffer = 1500000
start = 29691116
fin = 33054976
start_buff = start-buffer
fin_buff = fin+buffer

# %%
cmd = 'plink2 --pfile {b} --make-pgen --keep-allele-order --out {b}.{fromv}-{to} --mac 1 --from-bp {fromv} --to-bp {to} --chr 6 --set-all-var-ids @:#[b37]\$r,\$a --new-id-max-allele-len 280'.format(b=b, fromv=start_buff, to=fin_buff)
print(cmd)
# !{cmd}
# Out:
# plink2 --pfile ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6 --make-pgen --keep-allele-order --out ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976 --mac 1 --from-bp 28191116 --to-bp 34554976 --chr 6 --set-all-var-ids @:#[b37]\$r,\$a --new-id-max-allele-len 280
# PLINK v2.00a3LM 64-bit Intel (1 Jul 2021)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.log.
# Options in effect:
#   --chr 6
#   --from-bp 28191116
#   --keep-allele-order
#   --mac 1
#   --make-pgen
#   --new-id-max-allele-len 280
#   --out ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976
#   --pfile ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6
#   --set-all-var-ids @:#[b37]$r,$a
#   --to-bp 34554976
#
# Start time: Sat Feb  5 23:11:14 2022
# Note: --keep-allele-order no longer has any effect.
# 64422 MiB RAM detected; reserving 32211 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 4914 samples (2614 females, 2300 males; 4914 founders) loaded from
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.psam.
# 2088484 variants loaded from
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.pvar.
# 1 quantitative phenotype loaded (4914 values).
# Calculating allele frequencies... 60done.
# 19096 variants removed due to allele frequency threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 56645 variants remaining after main filters.
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.psam
# ... done.
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.pvar
# ... .
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.pgen
# ... done.
# End time: Sat Feb  5 23:11:19 2022

# %%
b = '{b}.{fromv}-{to}'.format(b=b, fromv=start_buff, to=fin_buff)
print(b)
# Out:
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976

# %%
cmd = 'plink2 --pfile {b} --make-bed --keep-allele-order --out {b}'.format(b=b)
print(cmd)
# !{cmd}
# Out:
# plink2 --pfile ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976 --make-bed --keep-allele-order --out ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976
# PLINK v2.00a3LM 64-bit Intel (1 Jul 2021)      www.cog-genomics.org/plink/2.0/
# (C) 2005-2021 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.log.
# Options in effect:
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976
#   --pfile ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976
#
# Start time: Sat Feb  5 23:11:24 2022
# Note: --keep-allele-order no longer has any effect.
# 64422 MiB RAM detected; reserving 32211 MiB for main workspace.
# Using up to 16 threads (change this with --threads).
# 4914 samples (2614 females, 2300 males; 4914 founders) loaded from
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.psam.
# 56645 variants loaded from
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.pvar.
# 1 quantitative phenotype loaded (4914 values).
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.fam
# ... done.
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.bim
# ... done.
# Writing
# ../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976.bed
# ... done.
# End time: Sat Feb  5 23:11:25 2022

# %%
genotyped_pvar = pd.read_csv(b+'.pvar', sep='\t', skiprows=16)
genotyped_pvar.head()
# Out:
#    #CHROM       POS                  ID REF ALT FILTER  \
# 0       6  28191288  6:28191288[b37]G,T   G   T   PASS
# 1       6  28191336  6:28191336[b37]C,T   C   T   PASS
# 2       6  28191613  6:28191613[b37]G,T   G   T   PASS
# 3       6  28191718  6:28191718[b37]T,C   T   C   PASS
# 4       6  28191859  6:28191859[b37]T,C   T   C   PASS
#
#                                                 INFO
# 0  RefPanelAF=0.0103914;AN=11110;AC=30;INFO=0.990976
# 1  RefPanelAF=0.0646691;AN=11110;AC=856;INFO=0.99...
# 2  RefPanelAF=0.00272397;AN=11110;AC=62;INFO=0.96...
# 3  RefPanelAF=0.0336965;AN=11110;AC=777;INFO=0.99...
# 4   RefPanelAF=0.0133172;AN=11110;AC=71;INFO=0.97087

# %%
genotyped_variants_fn = '../../data/tmp/HLA/Stanford/genotyped_variants.txt'
with open(genotyped_variants_fn, 'w') as F:
    F.write('\n'.join(list(genotyped_pvar['ID'])))

# %% [markdown]
# ## Merge affy and omni arrays

# %%
a_affy = '../../data/tmp/HLA/Stanford/Affy6_AGRPanel.vcf.gz'
a_omni = '../../data/tmp/HLA/Stanford/Omni25AFRPanel.vcf.gz'
out_affy = a_affy.replace('.vcf.gz', '')

# %%
cmd = 'plink2 --vcf {a} --out {out} --require-no-info MULTI_ALLELIC --make-bed --keep-allele-order --chr 6 --set-all-var-ids @:#[b37]\$r,\$a --new-id-max-allele-len 280 --from-bp {fromv} --to-bp {to}'.format(a=a_affy, out=out_affy, fromv=start_buff, to=fin_buff)
print(cmd)
# !{cmd}

# %%
a_affy = out_affy
out_omni = a_omni.replace('.vcf.gz', '')

# %%
cmd = 'plink2 --vcf {a} --out {out} --require-no-info MULTI_ALLELIC --make-bed --keep-allele-order --chr 6 --set-all-var-ids @:#[b37]\$r,\$a --new-id-max-allele-len 280 --from-bp {fromv} --to-bp {to}'.format(a=a_omni, out=out_omni, fromv=start_buff, to=fin_buff)
print(cmd)
# !{cmd}

# %%
a_omni = out_omni

# %%
merged = '../../data/tmp/HLA/Stanford/Omni25AffyMerged.AGR.chr6_{fromv}_{to}'.format(fromv=start_buff, to=fin_buff)

# %%
cmd = 'plink --bfile {batch1} --bmerge {batch2} --out {merged} --keep-allele-order'.format(batch1=a_omni, batch2=a_affy, merged=merged)
print(cmd)
# !{cmd}

# %%
a = merged
a

# %%
fam = pd.read_csv(a+'.fam', sep='\t', header=None)
fam.head()
# Out:
#    0                  1  2  3  4  5
# 0  0  09C81137_09C81137  0  0  0 -9
# 1  0  09C81823_09C81823  0  0  0 -9
# 2  0  09C82443_09C82443  0  0  0 -9
# 3  0  09C82628_09C82628  0  0  0 -9
# 4  0  09C85658_09C85658  0  0  0 -9

# %%
affy_hla = pd.read_csv('../../data/tmp/HLA/Stanford/Affy6_AGRPanel.Genotyped.HLAs.tsv', sep='\t', index_col=0)
omni_hla = pd.read_csv('../../data/tmp/HLA/Stanford/Omni25AFRPanel.Genotyped.HLAs.tsv', sep='\t', index_col=0)
merged_hla = pd.concat([omni_hla, affy_hla], axis=0)

# %%
pd.Series(merged_hla.index).isin(fam[1]).value_counts()
# Out:
# True    3608
# dtype: int64

# %%
merged_hla = merged_hla.loc[fam[1], :]

# %%
numnull = merged_hla.isnull().sum(axis=1)
numnull.value_counts()
# Out:
# 0     2541
# 16     595
# 1      300
# 2      110
# 4       34
# 3       11
# 6        7
# 8        6
# 5        2
# 12       1
# 10       1
# dtype: int64

# %%
tofilt = fam.loc[fam[1].isin(numnull.index[numnull==16]),:]
filtfn = '{a}.NoHLAToFilt.tsv'.format(a=a)
print(filtfn)
tofilt.to_csv(filtfn, sep='\t', index=False, header=False)

# %%
cmd = 'plink --bfile {a} --make-bed --keep-allele-order --remove {remove} --extract {extract} --out {a}.HasHLA.Genotyped --mac 1'.format(a=a, remove=filtfn, extract=genotyped_variants_fn)
print(cmd)
# !{cmd}

# %%
a = '{a}.HasHLA.Genotyped'.format(a=a)
print(a)
fam = pd.read_csv(a+'.fam', sep='\s+', header=None)

# %%
fam.head()
# Out:
#    0                  1  2  3  4  5
# 0  0  09C81137_09C81137  0  0  0 -9
# 1  0  09C82443_09C82443  0  0  0 -9
# 2  0  09C85658_09C85658  0  0  0 -9
# 3  0  09C86406_09C86406  0  0  0 -9
# 4  0  09C89080_09C89080  0  0  0 -9

# %%
merged_hla_filt = merged_hla.loc[fam[1], :]

# %%
merged_hla_filt.isnull().sum(axis=1).value_counts()
# Out:
# 0     2541
# 1      300
# 2      110
# 4       34
# 3       11
# 6        7
# 8        6
# 5        2
# 12       1
# 10       1
# dtype: int64

# %%
hlafn = a+'.HLAs.tsv'
print(hlafn)
merged_hla_filt.to_csv(hlafn, sep='\t')

# %%
merged_hla_filt_2dig = merged_hla_filt.applymap(lambda x: str(x).split(':')[0]).replace('nan', np.nan)
merged_hla_filt_2dig.head()
# Out:
#                    A_1 A_2 B_1 B_2 C_1 C_2 DRB1_1 DRB1_2 DQB1_1 DQB1_2 DQA1_1  \
# 09C81137_09C81137   01  02  08  07  07  07     03     15     02     06     05
# 09C82443_09C82443   68  23  42  15  06  02     11     11     03     03     05
# 09C85658_09C85658  NaN  02  15  53  02  04     15     03     06     02     01
# 09C86406_09C86406   68  30  44  81  07  08     13     15     06     06     01
# 09C89080_09C89080   30  23  42  15  17  02     03     07     04     02     04
#
#                   DQA1_2 DPB1_1 DPB1_2 DPA1_1 DPA1_2
# 09C81137_09C81137     01     04     01     01     02
# 09C82443_09C82443     05     01    105     01     02
# 09C85658_09C85658     05     17     04     02     01
# 09C86406_09C86406     01     01     04     02     01
# 09C89080_09C89080     02     01     11     02     02

# %%
hlafn_2dig = a+'.HLAs.2dig.tsv'
print(hlafn)
merged_hla_filt_2dig.to_csv(hlafn_2dig, sep='\t')

# %%
! gsutil -m cp ../../data/tmp/HLA/Blacks/Omni25AffyMerged* gs://popgen-gwas/data/analysis/HLA/Blacks/

# %%
sampset = 'Stanford_Merged'
base = 'gs://popgen-gwas/data/analysis/HLA/Stanford/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped'
logpath = 'gs://popgen-gwas/data/analysis/HLA/Stanford/HIBAG_Index_Merged/log/{job-name}-{job-id}.log'
nclass=7
flankstr = '500K'
flank=500000
dig = '4dig'
outbase = 'gs://popgen-gwas/data/analysis/HLA/Stanford/HIBAG_Index_Merged/Omni25AffyMerged.{g}.Nclass_{NCLASS}.Flank_{F}.{DIG}.Model.rdata'
hlafn = 'gs://popgen-gwas/data/analysis/HLA/Stanford/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv'
namebase = '20220205.Omni25AffyMerged.{g}.{NCLASS}.{DIG}'

subcmd = 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'

for g in ['A', 'B', 'C', 'DRB1', 'DQB1', 'DQA1', 'DPB1', 'DPA1']:
    out = outbase.format(g=g, SAMP=sampset, NCLASS=nclass, DIG=dig, F=flankstr)
    name =namebase.format(g=g, SAMP=sampset, NCLASS=nclass, DIG=dig)
    cmd = """dsub \
    --name {NAME} \
    --provider google-v2 \
    --machine-type e2-highcpu-8 \
    --project sabeti-ebola-gwas \
    --zones us-east1-b \
    --logging {log} \
    --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R \
    --input BED={base}.bed \
    --input BIM={base}.bim \
    --input FAM={base}.fam \
    --input HLA={HLA} \
    --env GENE={g} \
    --env CORES=7 \
    --env CLASSIFIERS={NCLASS} \
    --env FLANK={FLANK} \
    --output INDEX={OUT} \
    --timeout 2w \
    --image quay.io/dkotliar/hibag_docker:0.4 \
    --command '{subcmd}'""".format(g=g, log=logpath, base=base, NCLASS=nclass, FLANK=flank, OUT=out, NAME=name, HLA=hlafn, subcmd=subcmd)
    print(cmd)
    # !{cmd}
# Out:
# dsub     --name 20220205.Omni25AffyMerged.A.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=A     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.A.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233358-86
#   job-name: 20220205-omni25affymerged-a-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/5300586979171493828
# Launched job-id: 20220205-o--dkotliar--220205-233358-86
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233358-86' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233358-86' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233358-86
# dsub     --name 20220205.Omni25AffyMerged.B.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=B     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.B.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233359-96
#   job-name: 20220205-omni25affymerged-b-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/12800712423273329692
# Launched job-id: 20220205-o--dkotliar--220205-233359-96
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233359-96' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233359-96' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233359-96
# dsub     --name 20220205.Omni25AffyMerged.C.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=C     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.C.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233401-09
#   job-name: 20220205-omni25affymerged-c-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/10295124578365590102
# Launched job-id: 20220205-o--dkotliar--220205-233401-09
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233401-09' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233401-09' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233401-09
# dsub     --name 20220205.Omni25AffyMerged.DRB1.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=DRB1     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.DRB1.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233402-21
#   job-name: 20220205-omni25affymerged-drb1-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/8594678892520170704
# Launched job-id: 20220205-o--dkotliar--220205-233402-21
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233402-21' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233402-21' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233402-21
# dsub     --name 20220205.Omni25AffyMerged.DQB1.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=DQB1     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.DQB1.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233403-30
#   job-name: 20220205-omni25affymerged-dqb1-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/2989885140720591461
# Launched job-id: 20220205-o--dkotliar--220205-233403-30
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233403-30' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233403-30' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233403-30
# dsub     --name 20220205.Omni25AffyMerged.DQA1.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=DQA1     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.DQA1.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233404-44
#   job-name: 20220205-omni25affymerged-dqa1-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/11211905436016457657
# Launched job-id: 20220205-o--dkotliar--220205-233404-44
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233404-44' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233404-44' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233404-44
# dsub     --name 20220205.Omni25AffyMerged.DPB1.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=DPB1     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.DPB1.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233405-41
#   job-name: 20220205-omni25affymerged-dpb1-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/17486494604766078656
# Launched job-id: 20220205-o--dkotliar--220205-233405-41
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233405-41' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233405-41' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233405-41
# dsub     --name 20220205.Omni25AffyMerged.DPA1.7.4dig     --provider google-v2     --machine-type e2-highcpu-8     --project sabeti-ebola-gwas     --zones us-east1-b     --logging gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/log/{job-name}-{job-id}.log     --input SCRIPT=gs://popgen-gwas/code/HIBAG_Utils/Prepare_HIBAG_Index.R     --input BED=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bed     --input BIM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.bim     --input FAM=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.fam     --input HLA=gs://popgen-gwas/data/analysis/HLA/Blacks/Omni25AffyMerged.AGR.chr6_28191116_34554976.HasHLA.Genotyped.HLAs.tsv     --env GENE=DPA1     --env CORES=7     --env CLASSIFIERS=7     --env FLANK=500000     --output INDEX=gs://popgen-gwas/data/analysis/HLA/Blacks/HIBAG_Index_Merged/Omni25AffyMerged.DPA1.Nclass_7.Flank_500K.4dig.Model.rdata     --timeout 2w     --image quay.io/dkotliar/hibag_docker:0.4     --command 'Rscript --vanilla ${SCRIPT} --bed ${BED} --hlafile ${HLA} --nclassifier ${CLASSIFIERS} --cores ${CORES} --gene ${GENE} --out ${INDEX} --flankbp ${FLANK}'
# Job properties:
#   job-id: 20220205-o--dkotliar--220205-233406-42
#   job-name: 20220205-omni25affymerged-dpa1-7-4dig
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/15967385423506925465
# Launched job-id: 20220205-o--dkotliar--220205-233406-42
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233406-42' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233406-42' --users 'dkotliar'
# 20220205-o--dkotliar--220205-233406-42

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '20220205-o--dkotliar--220205-233406-42' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status                          Last Update
# ---------------  ------------------------------  --------------
# 20220205-omn...  Started running "user-command"  02-05 23:35:34

# %% [markdown]
# ## Look at imputation results

# %%
if not os.path.exists('../../data/tmp/HLA/Stanford/HIBAG_Index'):
    os.mkdir('../../data/tmp/HLA/Stanford/HIBAG_Index')

# %%
! gsutil -m rsync -r gs://popgen-gwas/data/analysis/HLA/Stanford/HIBAG_Index_Merged ../../data/tmp/HLA/Stanford/HIBAG_Index

# %% [markdown]
# ## Impute popgen samples

# %%
a = '../../data/tmp/HLA/popgen/OmniH3Merged_PrePost2016_20210810.INFO_9e-1.Deduped.chr6.28191116-34554976'

# %%
import os
genes = ['A', 'B', 'C', 'DRB1', 'DQB1', 'DQA1', 'DPB1', 'DPA1', 'DRB1']
#genes = ['B']
outdir = '../../data/tmp/HLA/Stanford/Predictions'
if not os.path.exists(outdir): os.mkdir(outdir)
for g in genes:
    bedfn = '{a}.bed'.format(a=a)
    indexfn = '../../data/tmp/HLA/Stanford/HIBAG_Index/Omni25AffyMerged.{g}.Nclass_7.Flank_500K.4dig.Model.rdata'.format(g=g)
    outfn = os.path.join(outdir, os.path.basename(indexfn)).replace('.rdata', '.20210728.tsv')
    if os.path.exists(indexfn) and not os.path.exists(outfn):
        cmd = 'Rscript ../../code/HIBAG_Utils/PredictHLA_HIBAG_PreformedIndex.R -b {bed} -i {ind} -o {out}'.format(bed=bedfn, ind=indexfn, out=outfn)
        print(cmd)
        # !{cmd}

# %%
import os
genes = ['A', 'B', 'C', 'DRB1', 'DQB1', 'DQA1', 'DPB1', 'DPA1', 'DRB1']
genes = ['DRB1']
outdir = '../../data/tmp/HLA/Stanford/Predictions'
if not os.path.exists(outdir): os.mkdir(outdir)
for g in genes:
    bedfn = '{a}.bed'.format(a=a)
    indexfn = '../../data/tmp/HLA/Stanford/HIBAG_Index/Omni25AffyMerged.{g}.Nclass_7.Flank_500K.4dig.Model.rdata'.format(g=g)
    outfn = os.path.join(outdir, os.path.basename(indexfn)).replace('.rdata', '.20220206.tsv')
    probout = os.path.join(outdir, os.path.basename(indexfn)).replace('.rdata', '.20220206.AllProbabilities.tsv')
    #if os.path.exists(indexfn) and not os.path.exists(outfn):
    if True:
        cmd = 'Rscript ../../code/HIBAG_Utils/PredictHLA_HIBAG_PreformedIndex_allProbs.R -b {bed} -i {ind} -o {out} -p {probout}'.format(bed=bedfn, ind=indexfn, out=outfn, probout=probout)
        print(cmd)
        # !{cmd}

# %%
import pandas as pd
stdoutfiles = ! ls ../../data/tmp/HLA/Stanford/HIBAG_Index/log/omni25affymerged-*-*stdout.log

oob_accuracy_500K = {}
for f in stdoutfiles:
    gene = f.split('/')[-1].split('-')[1].upper()
    print(gene)
    
    lines = open(f).read().split('\n')
    for l in lines:
        if 'Out-of-bag accuracy:' in l:
            accuracy = float(l.split(': ')[-1].replace('%', ''))
            oob_accuracy_500K[gene] = accuracy / 100
            print(gene, accuracy)
            
oob_accuracy_500K = pd.Series(oob_accuracy_500K)
# Out:
# A
# A 95.9
# B
# B
# B 92.6
# C
# C 96.3
# DPA1
# DPA1 97.4
# DPB1
# DPB1 93.4
# DQA1
# DQA1 95.9
# DQB1
# DQB1 95.6
# DRB1
# DRB1 93.5

# %%
def reorder_cols_alpha(c1, c2):
    c1new = c1.copy()
    c2new = c2.copy()
    ind = c1>c2
    c1new.loc[ind] = c2.loc[ind]
    c2new.loc[ind] = c1.loc[ind]
    return(c1new, c2new)

sbt = pd.read_csv('gs://popgen-gwas/data/HLA/KGH/HLA/HLAcalls_Identified_Cleaned_4dig_20190822.tsv', sep='\t')
sbt['DPA1_1'] = sbt['DPA1_1'].replace({'03:01@2':'03:01'})
sbt['DPA1_2'] = sbt['DPA1_2'].replace({'03:01@2':'03:01'})
ind = ~sbt['Post_2016_GenotIID'].isnull()
sbt_post = sbt.loc[ind, :].iloc[:, 9:]
sbt_post.index = sbt.loc[ind, 'Post_2016_GenotIID']
ind = ~sbt['Pre_2016_GenotIID'].isnull()
sbt_pre = sbt.loc[ind, :].iloc[:, 9:]
sbt_pre.index = sbt.loc[ind, 'Pre_2016_GenotIID']
genes = ['A', 'B', 'C', 'DRB1', 'DQB1', 'DQA1', 'DPB1', 'DPA1']
for g in genes:
    outfn = '../../data/tmp/HLA/Stanford/Predictions/Omni25AffyMerged.{g}.Nclass_7.Flank_500K.4dig.Model.20210728.tsv'.format(g=g)
    if not os.path.exists(outfn):
        continue
    prediction = pd.read_csv(outfn, sep='\t')
    prediction.index = prediction['sample.id']
    a1new, a2new = reorder_cols_alpha(sbt_post['%s_1' % g], sbt_post['%s_2' % g])
    sbt_post['SBT_%s_1' % g] = a1new
    sbt_post['SBT_%s_2' % g] = a2new
    a1new, a2new = reorder_cols_alpha(prediction.loc[sbt_post.index, 'allele1'], prediction.loc[sbt_post.index, 'allele2'])
    sbt_post['Predict_%s_1' % g] = a1new
    sbt_post['Predict_%s_2' % g] = a2new
    sbt_post['PredProb_%s' % g] = prediction.loc[sbt_post.index, 'prob']

    a1new, a2new = reorder_cols_alpha(sbt_pre['%s_1' % g], sbt_pre['%s_2' % g])
    sbt_pre['SBT_%s_1' % g] = a1new
    sbt_pre['SBT_%s_2' % g] = a2new
    a1new, a2new = reorder_cols_alpha(prediction.loc[sbt_pre.index, 'allele1'], prediction.loc[sbt_pre.index, 'allele2'])
    sbt_pre['Predict_%s_1' % g] = a1new
    sbt_pre['Predict_%s_2' % g] = a2new
    sbt_pre['PredProb_%s' % g] = prediction.loc[sbt_pre.index, 'prob']


sbt_comb = pd.concat([sbt_pre, sbt_post], axis=0)
sbt_comb.head()
# Out:
# /opt/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py:947: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
#                        A_1    A_2    B_1    B_2    C_1    C_2 DPA1_1 DPA1_2  \
# Winter2013_SM-39SMI  68:02  30:01  15:10  42:02  03:04  17:01  02:01  02:01
# Winter2013_SM-39SMR  03:01  02:01  07:02  49:01  07:01  07:02  02:01  03:01
# Winter2013_SM-39SMS  68:01  30:02  07:02  50:01  06:02  15:05  01:03  02:01
# Winter2013_SM-39SMT  29:02  29:02  35:01  78:01  07:18  16:01  02@28  03:01
# Winter2013_SM-39SNJ  24:02  01:01  27:05  37:01  02:02  06:02  01:03  02:02
#
#                      DPB1_1  DPB1_2  ... SBT_DPB1_1 SBT_DPB1_2 Predict_DPB1_1  \
# Winter2013_SM-39SMI   01:01   01:01  ...      01:01      01:01            NaN
# Winter2013_SM-39SMR   17:01  105:01  ...     105:01      17:01         105:01
# Winter2013_SM-39SMS   13:01   04:02  ...      04:02      13:01         105:01
# Winter2013_SM-39SMT  105:01  131:01  ...     105:01     131:01         105:01
# Winter2013_SM-39SNJ   01:01   04:02  ...      01:01      04:02          01:01
#
#                     Predict_DPB1_2 PredProb_DPB1 SBT_DPA1_1 SBT_DPA1_2  \
# Winter2013_SM-39SMI            NaN           NaN      02:01      02:01
# Winter2013_SM-39SMR          17:01      0.822039      02:01      03:01
# Winter2013_SM-39SMS          13:01      0.832108      01:03      02:01
# Winter2013_SM-39SMT         131:01      0.970407      02@28      03:01
# Winter2013_SM-39SNJ          04:02      0.957516      01:03      02:02
#
#                     Predict_DPA1_1 Predict_DPA1_2 PredProb_DPA1
# Winter2013_SM-39SMI            NaN            NaN           NaN
# Winter2013_SM-39SMR          02:01          03:01      0.745166
# Winter2013_SM-39SMS          01:03          02:01      0.996692
# Winter2013_SM-39SMT          02:01          03:01      0.908141
# Winter2013_SM-39SNJ          01:03          02:02      0.999023
#
# [5 rows x 62 columns]

# %%
res_kgh = {}
compare_inds = {}
off_inds = {}
for g in genes:
    p1 = 'Predict_%s_1' % g
    p2 = 'Predict_%s_2' % g
    s1 = 'SBT_%s_1' % g
    s2= 'SBT_%s_2' % g
    
    if p1 not in sbt_comb:
        continue
    
    ind = ~sbt_comb[p1].isnull() & ~sbt_comb[p2].isnull() & ~sbt_comb[s1].isnull() & ~sbt_comb[s2].isnull() & (sbt_comb[s1] != '-') & (sbt_comb[s2] != '-')
    compare_inds[g] = ind

    two_of_two = (sbt_comb.loc[ind, p1]==sbt_comb.loc[ind, s1]) & (sbt_comb.loc[ind, p2]==sbt_comb.loc[ind, s2])
    one_of_two = (sbt_comb.loc[ind, p1]==sbt_comb.loc[ind, s1]) | (sbt_comb.loc[ind, p2]==sbt_comb.loc[ind, s2]) 
    one_of_two = one_of_two | (sbt_comb.loc[ind, p1]==sbt_comb.loc[ind,s2]) | (sbt_comb.loc[ind, p2]==sbt_comb.loc[ind, s1])
    one_of_two = one_of_two & ~ two_of_two
    frac = float(two_of_two.sum()*2 + one_of_two.sum()) / float(ind.sum()*2)
    
    res_kgh[g] = [frac, two_of_two.sum(), one_of_two.sum(), ind.sum()]
        
    indoff = two_of_two.index[~two_of_two]
    off_inds[g] = indoff
    
res_kgh = pd.DataFrame(res_kgh).T
res_kgh.columns = ['KGH_Frac_Correct', 'KGH 2/2', 'KGH 1/2', 'KGH Total']
res_kgh
# Out:
#       KGH_Frac_Correct  KGH 2/2  KGH 1/2  KGH Total
# A             0.965398    274.0     10.0      289.0
# B             0.892361    237.0     40.0      288.0
# C             0.953287    266.0     19.0      289.0
# DRB1          0.925347    251.0     31.0      288.0
# DQB1          0.940767    256.0     28.0      287.0
# DQA1          0.975779    278.0      8.0      289.0
# DPB1          0.934028    258.0     22.0      288.0
# DPA1          0.951786    256.0     21.0      280.0

# %%
(~sbt['Post_2016_GenotIID'].isnull() | ~sbt['Pre_2016_GenotIID'].isnull()).value_counts()
# Out:
# True     297
# False     60
# dtype: int64

# %%
g = 'A'
cols = [x % g for x in ['SBT_%s_1', 'SBT_%s_2', 'Predict_%s_1', 'Predict_%s_2', 'PredProb_%s']]
sbt_comb.loc[off_inds[g], cols]
# Out:
#                           SBT_A_1 SBT_A_2 Predict_A_1 Predict_A_2  PredProb_A
# Winter2014_G3177.1         02:346   30:02       02:01       30:02    0.994305
# Winter2013_F-SL-132M        02:01   74:01       02:01       32:01    0.460406
# Winter2013_F-SL-6M          74:01   74:01       02:01       74:01    0.545873
# Winter2013_F-SL-89F         68:02   68:28       68:02       68:02    0.988715
# Winter2013_SM-3NQL3         23:17   33:01       23:01       33:01    0.760870
# Winter2013_SM-39SNA         33:03   33:03       23:01       33:01    0.997553
# WG0284572-DNA_G08_C-062-2   29:02   34:02       23:01       23:01    0.745145
# WG0284586-DNA_B07_S-023     02:02   30:01       01:01       30:01    0.997559
# WG0284565-DNA_A04_G-5690    30:01   33:03       23:01       30:01    0.994645
# WG0284568-DNA_B05_G-5684    23:01   30:01       30:01       33:03    0.983101
# WG0341181-DNA_E01_S-106     33:03   34:02       02:01       29:02    0.998892
# WG0284565-DNA_B12_G-7174    03:01   68:01       23:01       23:01    0.793247
# WG0284572-DNA_E07_S-150     23:01   23:01       03:01       68:01    0.996906
# WG0284578-DNA_F03_G-7951    23:01   23:01       02:01       23:01    0.994642
# WG0284578-DNA_H04_G-7957    02:01   23:01       23:01       23:01    0.985853

# %%
g = 'B'
cols = [x % g for x in [ 'SBT_%s_1', 'SBT_%s_2', 'Predict_%s_1', 'Predict_%s_2', 'PredProb_%s']]
sbt_comb.loc[off_inds[g], cols]
# Out:
#                           SBT_B_1 SBT_B_2 Predict_B_1 Predict_B_2  PredProb_B
# Winter2014_G3085.1          44:10   53@25       44:03       53:01    0.835166
# Winter2014_G3118.1          51:01   51:01       51:01       52:01    0.349237
# Winter2014_G3158.1          08:01   15:10       15:10       44:03    0.908286
# Winter2014_G3172.1          15:52   41:03       15:18       41:02    0.613443
# Winter2014_G3182.1          41:03   42:01       41:02       42:01    0.968502
# Winter2014_G3303.1          42@26   53:01       42:01       53:01    0.969562
# Winter2013_F-SL-34M         44:10   53:01       44:03       53:01    0.996605
# Winter2013_F-SL-135F        42:01   51:02       42:01       51:01    0.579833
# Winter2013_F-SL-66M         35:01   40:12       15:10       35:01    0.149948
# Winter2013_F-SL-23M         44:18   50:01       45:01       49:01    0.963680
# Winter2013_F-SL-70C            Winter2013_F-SL-70C  HG03469,HG03470
# WG0284565-DNA_C12_G-7167  WG0284565-DNA_C12_G-7167          HG03069
# Winter2013_F-SL-12F            Winter2013_F-SL-12F          HG03442
# Winter2013_F-NG-C-120M      Winter2013_F-NG-C-120M          HG03294
#
#                                      Relatedness_chr22      Pop  \
# IID
# Winter2013_F-NG-C-113C                          1.0061      ESN
# Winter2013_F-SL-70C       0.49924799999999997,0.509117  MSL,MSL
# WG0284565-DNA_C12_G-7167            1.0161200000000001      MSL
# Winter2013_F-SL-12F                           0.995732      MSL
# Winter2013_F-NG-C-120M                          1.0335      ESN
#
#                                 SampleType
# IID
# Winter2013_F-NG-C-113C             TriosNG
# Winter2013_F-SL-70C                TriosSL
# WG0284565-DNA_C12_G-7167  SuspectedLassaSL
# Winter2013_F-SL-12F                TriosSL
# Winter2013_F-NG-C-120M             TriosNG

# %%
ind = ~popgen_1kg['Relatedness_chr22'].apply(lambda x: ',' in x)
popgen_1kg = popgen_1kg.loc[ind, :]
popgen_1kg['Relatedness_chr22'] = popgen_1kg['Relatedness_chr22'].astype(float)
ind = popgen_1kg['Relatedness_chr22']>.95
popgen_1kg = popgen_1kg.loc[ind, :]
popgen_1kg.head()
# Out:
#                                                IID   1KG_ID  \
# IID
# Winter2013_F-NG-C-113C      Winter2013_F-NG-C-113C  HG02968
# WG0284565-DNA_C12_G-7167  WG0284565-DNA_C12_G-7167  HG03069
# Winter2013_F-SL-12F            Winter2013_F-SL-12F  HG03442
# Winter2013_F-NG-C-120M      Winter2013_F-NG-C-120M  HG03294
# Winter2013_F-SL-65F            Winter2013_F-SL-65F  HG03084
#
#                           Relatedness_chr22  Pop        SampleType
# IID
# Winter2013_F-NG-C-113C             1.006100  ESN           TriosNG
# WG0284565-DNA_C12_G-7167           1.016120  MSL  SuspectedLassaSL
# Winter2013_F-SL-12F                0.995732  MSL           TriosSL
# Winter2013_F-NG-C-120M             1.033500  ESN           TriosNG
# Winter2013_F-SL-65F                0.980388  MSL           TriosSL

# %%
hlapanel = pd.read_csv('../../data/tmp/HLA/1KG/HLA/20181129_HLA_types_full_1000_Genomes_Project_panel.txt', sep='\t')
hlapanel.index = hlapanel['Sample ID']
hlapanel.head()
# Out:
#           Region Population Sample ID HLA-A 1 HLA-A 2 HLA-B 1 HLA-B 2 HLA-C 1  \
# Sample ID
# HG01879      AFR        ACB   HG01879   23:01   68:02   13:02   42:01   08:04
# HG01880      AFR        ACB   HG01880   33:03   68:02   40:06   42:01   12:02
# HG01882      AFR        ACB   HG01882   23:01   34:02   07:02   44:50   04:01
# HG01883      AFR        ACB   HG01883   02:01   68:02   53:01   44:03   04:01
# HG01885      AFR        ACB   HG01885   03:01   33:03   35:01   35:01   04:01
#
#           HLA-C 2 HLA-DQB1 1 HLA-DQB1 2 HLA-DRB1 1 HLA-DRB1 2
# Sample ID
# HG01879     17:01      02:02      04:02      03:02      09:01
# HG01880     17:01      02:01      03:04      03:01      11:06
# HG01882     07:02      06:02      06:02      15:03      15:03
# HG01883     04:01      02:02      06:02      13:03      15:03
# HG01885     07:18      02:02      03:19      13:04      07:01

# %%
sbt_comb.head()
# Out:
#                        A_1    A_2    B_1    B_2    C_1    C_2 DPA1_1 DPA1_2  \
# Winter2013_SM-39SMI  68:02  30:01  15:10  42:02  03:04  17:01  02:01  02:01
# Winter2013_SM-39SMR  03:01  02:01  07:02  49:01  07:01  07:02  02:01  03:01
# Winter2013_SM-39SMS  68:01  30:02  07:02  50:01  06:02  15:05  01:03  02:01
# Winter2013_SM-39SMT  29:02  29:02  35:01  78:01  07:18  16:01  02@28  03:01
# Winter2013_SM-39SNJ  24:02  01:01  27:05  37:01  02:02  06:02  01:03  02:02
#
#                      DPB1_1  DPB1_2  ... SBT_DPB1_1 SBT_DPB1_2 Predict_DPB1_1  \
# Winter2013_SM-39SMI   01:01   01:01  ...      01:01      01:01            NaN
# Winter2013_SM-39SMR   17:01  105:01  ...     105:01      17:01         105:01
# Winter2013_SM-39SMS   13:01   04:02  ...      04:02      13:01         105:01
# Winter2013_SM-39SMT  105:01  131:01  ...     105:01     131:01         105:01
# Winter2013_SM-39SNJ   01:01   04:02  ...      01:01      04:02          01:01
#
#                     Predict_DPB1_2 PredProb_DPB1 SBT_DPA1_1 SBT_DPA1_2  \
# Winter2013_SM-39SMI            NaN           NaN      02:01      02:01
# Winter2013_SM-39SMR          17:01      0.822039      02:01      03:01
# Winter2013_SM-39SMS          13:01      0.832108      01:03      02:01
# Winter2013_SM-39SMT         131:01      0.970407      02@28      03:01
# Winter2013_SM-39SNJ          04:02      0.957516      01:03      02:02
#
#                     Predict_DPA1_1 Predict_DPA1_2 PredProb_DPA1
# Winter2013_SM-39SMI            NaN            NaN           NaN
# Winter2013_SM-39SMR          02:01          03:01      0.745166
# Winter2013_SM-39SMS          01:03          02:01      0.996692
# Winter2013_SM-39SMT          02:01          03:01      0.908141
# Winter2013_SM-39SNJ          01:03          02:02      0.999023
#
# [5 rows x 62 columns]

# %%
genes = ['A', 'B', 'C', 'DRB1', 'DQB1', 'DQA1', 'DPB1', 'DPA1']

allprediction = []
for g in genes:
    outfn = '../../data/tmp/HLA/Stanford/Predictions/Omni25AffyMerged.{g}.Nclass_7.Flank_500K.4dig.Model.20210728.tsv'.format(g=g)
    if not os.path.exists(outfn):
        continue
    
    dat = pd.read_csv(outfn, sep='\t')
    dat.index = dat['sample.id']
    dat = dat[['allele1', 'allele2', 'prob']]
    dat.columns = ['Predict_%s_1' % g, 'Predict_%s_2' % g, 'PredProb_%s' % g]
    allprediction.append(dat)

allprediction = pd.concat(allprediction, axis=1)   
allprediction.head()
# Out:
#                          Predict_A_1 Predict_A_2  PredProb_A Predict_B_1  \
# sample.id
# WG0284565-DNA_A02_G-5231       30:01       66:01    0.998222       42:01
# WG0284565-DNA_A03_G-5686       02:02       30:01    0.997561       53:01
# WG0284565-DNA_A04_G-5690       23:01       30:01    0.994645       07:02
# WG0284565-DNA_A05_G-5135       30:01       33:03    0.963070       42:01
# WG0284565-DNA_A06_G-5045       29:02       74:01    0.649784       07:02
#
#                          Predict_B_2  PredProb_B Predict_C_1 Predict_C_2  \
# sample.id
# WG0284565-DNA_A02_G-5231       57:03    0.478479       04:01       17:01
# WG0284565-DNA_A03_G-5686       78:01    0.531951       06:02       16:01
# WG0284565-DNA_A04_G-5690       42:01    0.892517       15:05       17:01
# WG0284565-DNA_A05_G-5135       58:01    0.921473       03:02       17:01
# WG0284565-DNA_A06_G-5045       35:01    0.817903       07:18       15:05
#
#                           PredProb_C Predict_DRB1_1  ... PredProb_DQB1  \
# sample.id                                            ...
# WG0284565-DNA_A02_G-5231    0.570498          01:01  ...      0.989911
# WG0284565-DNA_A03_G-5686    0.981965          03:02  ...      0.973634
# WG0284565-DNA_A04_G-5690    1.000000          04:05  ...      0.971555
# WG0284565-DNA_A05_G-5135    0.989839          03:02  ...      0.998512
# WG0284565-DNA_A06_G-5045    0.713611          11:01  ...      0.709065
#
#                           Predict_DQA1_1 Predict_DQA1_2 PredProb_DQA1  \
# sample.id
# WG0284565-DNA_A02_G-5231           01:01          04:01      0.991259
# WG0284565-DNA_A03_G-5686           01:02          04:01      0.855207
# WG0284565-DNA_A04_G-5690           02:01          03:03      0.652521
# WG0284565-DNA_A05_G-5135           01:02          04:01      0.999105
# WG0284565-DNA_A06_G-5045           01:02          01:02      0.960938
#
#                           Predict_DPB1_1 Predict_DPB1_2 PredProb_DPB1  \
# sample.id
# WG0284565-DNA_A02_G-5231           01:01          17:01      0.815374
# WG0284565-DNA_A03_G-5686           01:01          01:01      0.982890
# WG0284565-DNA_A04_G-5690           11:01          40:01      0.976616
# WG0284565-DNA_A05_G-5135           01:01          02:01      0.843378
# WG0284565-DNA_A06_G-5045           40:01          85:01      0.870925
#
#                           Predict_DPA1_1 Predict_DPA1_2 PredProb_DPA1
# sample.id
# WG0284565-DNA_A02_G-5231           02:01          02:02      0.977745
# WG0284565-DNA_A03_G-5686           02:01          02:02      0.982284
# WG0284565-DNA_A04_G-5690           02:01          03:01      0.865605
# WG0284565-DNA_A05_G-5135           01:03          02:02      0.982749
# WG0284565-DNA_A06_G-5045           02:02          03:01      0.999984
#
# [5 rows x 24 columns]

# %%
allprediction.to_csv('../../data/tmp/HLA/Stanford/Predictions/StanfordAffyArrays_Predictions_AllPopgen_Samples_20210827.tsv', sep='\t')

# %%
! gsutil -m rsync -r ../../data/tmp/HLA/Stanford/Predictions gs://popgen-gwas/data/analysis/HLA/Stanford/Predictions

# %%
import numpy as np
esn_samps = popgen_1kg.loc[popgen_1kg['Pop']=='ESN', 'IID']
msl_samples = popgen_1kg.loc[popgen_1kg['Pop']=='MSL', 'IID']

prediction_esn = allprediction.loc[esn_samps, :]
prediction_esn['1KG_ID'] = popgen_1kg.loc[esn_samps, '1KG_ID']
prediction_msl = allprediction.loc[msl_samples, :]
prediction_msl['1KG_ID'] = popgen_1kg.loc[msl_samples, '1KG_ID']

gdata = []
for g in ['A', 'B', 'C', 'DRB1', 'DQB1']:
    gdata.append('HLA-%s 1' % g)
    gdata.append('HLA-%s 2' % g)

prediction_esn = pd.merge(left=prediction_esn, right=hlapanel[gdata], how='left', left_on='1KG_ID', right_index=True)
prediction_msl = pd.merge(left=prediction_msl, right=hlapanel[gdata], how='left', left_on='1KG_ID', right_index=True)


for g in ['A', 'B', 'C', 'DRB1', 'DQB1']:
    a1new, a2new = reorder_cols_alpha(prediction_esn['HLA-%s 1' % g], prediction_esn['HLA-%s 2' % g])
    prediction_esn['SBT_%s_1' % g] = a1new
    prediction_esn['SBT_%s_2' % g] = a2new
    
    a1new, a2new = reorder_cols_alpha(prediction_msl['HLA-%s 1' % g], prediction_msl['HLA-%s 2' % g])
    prediction_msl['SBT_%s_1' % g] = a1new
    prediction_msl['SBT_%s_2' % g] = a2new


prediction_esn = prediction_esn.replace('None', np.nan)
prediction_msl = prediction_msl.replace('None', np.nan)

prediction_esn.head()
# Out:
# /opt/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py:1404: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                         Predict_A_1 Predict_A_2  PredProb_A Predict_B_1  \
# sample.id
# Winter2013_F-NG-C-113C        02:05       23:01    0.995104       53:01
# Winter2013_F-NG-C-120M        02:01       23:01    0.963433       07:02
# Winter2013_F-NG-C-58F         33:03       74:01    0.985408       15:10
# Winter2013_F-NG-NC-224C       30:02       68:02    0.854792       15:10
# Winter2013_F-NG-C-48C         36:01       68:02    0.994226       07:02
#
#                         Predict_B_2  PredProb_B Predict_C_1 Predict_C_2  \
# sample.id
# Winter2013_F-NG-C-113C        58:01    1.000000       06:02       07:18
# Winter2013_F-NG-C-120M        45:01    0.625075       02:02       16:01
# Winter2013_F-NG-C-58F         53:01    0.996833       04:01       08:04
# Winter2013_F-NG-NC-224C       57:03    0.243950       03:04       18:02
# Winter2013_F-NG-C-48C         15:03    0.907216       04:01       07:02
#
#                          PredProb_C Predict_DRB1_1  ... SBT_A_1  SBT_A_2  \
# sample.id                                           ...
# Winter2013_F-NG-C-113C     1.000000          11:01  ...   02:05    23:01
# Winter2013_F-NG-C-120M     0.547247          11:01  ...   02:01    23:01
# Winter2013_F-NG-C-58F      0.653589          03:01  ...   33:03    74:01
# Winter2013_F-NG-NC-224C    0.985906          03:01  ...   30:02    68:02
# Winter2013_F-NG-C-48C      0.838053          03:01  ...   36:01    68:02
#
#                         SBT_B_1 SBT_B_2  SBT_C_1 SBT_C_2 SBT_DRB1_1  \
# sample.id
# Winter2013_F-NG-C-113C    53:01   53:01    06:02   07:18      11:01
# Winter2013_F-NG-C-120M    07:02   45:01    02:02   16:01      11:01
# Winter2013_F-NG-C-58F     15:10   53:01    04:01   08:04      03:01
# Winter2013_F-NG-NC-224C   15:10   18:01    03:04   18:02      03:01
# Winter2013_F-NG-C-48C     07:02   15:03    04:01   07:02      03:01
#
#                          SBT_DRB1_2 SBT_DQB1_1 SBT_DQB1_2
# sample.id
# Winter2013_F-NG-C-113C        15:03      06:02      06:02
# Winter2013_F-NG-C-120M        15:03      06:02      06:02
# Winter2013_F-NG-C-58F         13:01      02:01      06:09
# Winter2013_F-NG-NC-224C       09:01      02:01      02:02
# Winter2013_F-NG-C-48C         11:01      02:01      03:19
#
# [5 rows x 45 columns]

# %%
off_inds_kg_esn = {}
res_kg_esn = {}
for g in ['A', 'B', 'C', 'DRB1', 'DQB1']:
    p1 = 'Predict_%s_1' % g
    p2 = 'Predict_%s_2' % g
    s1 = 'SBT_%s_1' % g
    s2= 'SBT_%s_2' % g
    
    if p1 not in prediction_esn:
        continue
    
    ind = ~prediction_esn[p1].isnull() & ~prediction_esn[p2].isnull() & ~prediction_esn[s1].isnull() & ~prediction_esn[s2].isnull() & (prediction_esn[s1] != '-') & (prediction_esn[s2] != '-')
    compare_inds[g] = ind

    two_of_two = (prediction_esn.loc[ind, p1]==prediction_esn.loc[ind, s1]) & (prediction_esn.loc[ind, p2]==prediction_esn.loc[ind, s2])
    one_of_two = (prediction_esn.loc[ind, p1]==prediction_esn.loc[ind, s1]) | (prediction_esn.loc[ind, p2]==prediction_esn.loc[ind, s2]) 
    one_of_two = one_of_two | (prediction_esn.loc[ind, p1]==prediction_esn.loc[ind,s2]) | (prediction_esn.loc[ind, p2]==prediction_esn.loc[ind, s1])
    one_of_two = one_of_two & ~ two_of_two
    frac = float(two_of_two.sum()*2 + one_of_two.sum()) / float(ind.sum()*2)
    
    
    res_kg_esn[g] = [frac, two_of_two.sum(), one_of_two.sum(), ind.sum()]
        
    indoff = two_of_two.index[~two_of_two]
    off_inds_kg_esn[g] = indoff
    
res_kg_esn = pd.DataFrame(res_kg_esn).T
res_kg_esn.columns = ['ESN_Frac_Correct', 'ESN 2/2', 'ESN 1/2', 'ESN Total']
res_kg_esn
# Out:
#       ESN_Frac_Correct  ESN 2/2  ESN 1/2  ESN Total
# A             0.956250     73.0      7.0       80.0
# B             0.942308     69.0      9.0       78.0
# C             0.987500     78.0      2.0       80.0
# DRB1          0.987500     78.0      2.0       80.0
# DQB1          0.987500     78.0      2.0       80.0

# %%
off_inds_kg_msl = {}
res_kg_msl = {}
for g in ['A', 'B', 'C', 'DRB1', 'DQB1']:
    p1 = 'Predict_%s_1' % g
    p2 = 'Predict_%s_2' % g
    s1 = 'SBT_%s_1' % g
    s2= 'SBT_%s_2' % g
    
    if p1 not in prediction_msl:
        continue
    
    ind = ~prediction_msl[p1].isnull() & ~prediction_msl[p2].isnull() & ~prediction_msl[s1].isnull() & ~prediction_msl[s2].isnull() & (prediction_msl[s1] != '-') & (prediction_msl[s2] != '-')
    compare_inds[g] = ind

    two_of_two = (prediction_msl.loc[ind, p1]==prediction_msl.loc[ind, s1]) & (prediction_msl.loc[ind, p2]==prediction_msl.loc[ind, s2])
    one_of_two = (prediction_msl.loc[ind, p1]==prediction_msl.loc[ind, s1]) | (prediction_msl.loc[ind, p2]==prediction_msl.loc[ind, s2]) 
    one_of_two = one_of_two | (prediction_msl.loc[ind, p1]==prediction_msl.loc[ind,s2]) | (prediction_msl.loc[ind, p2]==prediction_msl.loc[ind, s1])
    one_of_two = one_of_two & ~ two_of_two
    frac = float(two_of_two.sum()*2 + one_of_two.sum()) / float(ind.sum()*2)
    
    
    res_kg_msl[g] = [frac, two_of_two.sum(), one_of_two.sum(), ind.sum()]
        
    indoff = two_of_two.index[~two_of_two]
    off_inds_kg_msl[g] = indoff
    
res_kg_msl = pd.DataFrame(res_kg_msl).T
res_kg_msl.columns = ['MSL_Frac_Correct', 'MSL 2/2', 'MSL 1/2', 'MSL Total']
res_kg_msl
# Out:
#       MSL_Frac_Correct  MSL 2/2  MSL 1/2  MSL Total
# A             0.992857     69.0      1.0       70.0
# B             0.914286     58.0     12.0       70.0
# C             0.985714     69.0      0.0       70.0
# DRB1          0.971429     66.0      4.0       70.0
# DQB1          0.985714     68.0      2.0       70.0

# %%
prediction_msl.shape[0], prediction_esn.shape[0]
# Out:
# (76, 84)

# %%
from matplotlib import rcParams, font_manager
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

# %%
import seaborn as sns
sns.set_style("whitegrid")

(fig,ax) = plt.subplots(1,1, figsize=(3,2), dpi=200)
res_combined = pd.concat([res_kgh, res_kg_esn, res_kg_msl, pd.DataFrame(oob_accuracy_500K, columns=['OOB_Frac_Correct'])], axis=1).unstack().reset_index()
res_combined.columns = ['Group', 'Gene', 'Val']
res_combined['Cohort'] = res_combined['Group'].apply(lambda x: x.split('_')[0])
ind = res_combined['Group'].apply(lambda x: 'Frac' in x)
res_combined = res_combined.loc[ind, :]
order = res_combined['Gene'].unique()
res_combined = res_combined.loc[res_combined['Cohort'] != 'OOB', :]
res_combined['Cohort'] = res_combined['Cohort'].replace({'KGH':'Sierra Leone', 'ESN':'1000G Esan', 'MSL':'1000G Mende'})
ax.set_ylim([.6, 1])

ax = sns.barplot(x='Gene', y='Val', hue='Cohort', data=res_combined,
                 hue_order=['Sierra Leone', '1000G Esan', '1000G Mende'], 
                 order=order, ax=ax)

ax.set_ylabel('Imputation Accuracy', fontsize=10)
ax.set_xlabel('HLA Gene', fontsize=10)
ax.set_yticklabels(['0.6', '0.7', '0.8', '0.9', '1.0'], fontsize=8)
ax.set_xticks([0,1,2,3,4,5,6,7])
ax.set_xticklabels(order, fontsize=8, rotation=45)

ax.vlines(-.5, ymin=.6, ymax=1, linestyle='--', linewidth=.1)
ax.vlines(6.5, ymin=.6, ymax=1, linestyle='--', linewidth=.1)

for i in range(0, 8):
    if (i % 2) == 0:
        pass
        #ax.axvspan(i-.5, i+.5, facecolor='0.7', alpha=0.3)
    ax.vlines(i+.5, ymin=.6, ymax=1, linestyle='--', linewidth=.2)

    #else:
    #    #pass
    #    ax.axvspan(i-.5, i+.5, facecolor='0.6', alpha=0.1)        
ax.set_xlim(-.5, 7.5)

ax.legend(bbox_to_anchor=(1,.71), title='Sample set', fontsize=8,
         title_fontsize=9)

outfn = os.path.join(figuredir, 'HLA_Imputation_Accuracy.pdf')
fig.savefig(outfn, bbox_inches='tight')

outfn = os.path.join(figuredir, 'HLA_Imputation_Accuracy.png')
fig.savefig(outfn, bbox_inches='tight')
# Out:
# /opt/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
order
# Out:
# array(['A', 'B', 'C', 'DPA1', 'DPB1', 'DQA1', 'DQB1', 'DRB1'],
#       dtype=object)

# %%
res_combined
# Out:
#                Group  Gene       Val        Cohort
# 0   KGH_Frac_Correct     A  0.965398  Sierra Leone
# 1   KGH_Frac_Correct     B  0.892361  Sierra Leone
# 2   KGH_Frac_Correct     C  0.953287  Sierra Leone
# 3   KGH_Frac_Correct  DPA1  0.951786  Sierra Leone
# 4   KGH_Frac_Correct  DPB1  0.934028  Sierra Leone
# 5   KGH_Frac_Correct  DQA1  0.975779  Sierra Leone
# 6   KGH_Frac_Correct  DQB1  0.940767  Sierra Leone
# 7   KGH_Frac_Correct  DRB1  0.925347  Sierra Leone
# 32  ESN_Frac_Correct     A  0.956250    1000G Esan
# 33  ESN_Frac_Correct     B  0.942308    1000G Esan
# 34  ESN_Frac_Correct     C  0.987500    1000G Esan
# 35  ESN_Frac_Correct  DPA1       NaN    1000G Esan
# 36  ESN_Frac_Correct  DPB1       NaN    1000G Esan
# 37  ESN_Frac_Correct  DQA1       NaN    1000G Esan
# 38  ESN_Frac_Correct  DQB1  0.987500    1000G Esan
# 39  ESN_Frac_Correct  DRB1  0.987500    1000G Esan
# 64  MSL_Frac_Correct     A  0.992857   1000G Mende
# 65  MSL_Frac_Correct     B  0.914286   1000G Mende
# 66  MSL_Frac_Correct     C  0.985714   1000G Mende
# 67  MSL_Frac_Correct  DPA1       NaN   1000G Mende
# 68  MSL_Frac_Correct  DPB1       NaN   1000G Mende
# 69  MSL_Frac_Correct  DQA1       NaN   1000G Mende
# 70  MSL_Frac_Correct  DQB1  0.985714   1000G Mende
# 71  MSL_Frac_Correct  DRB1  0.971429   1000G Mende

# %%
res_combined
# Out:
#                Group  Gene       Val        Cohort
# 0   KGH_Frac_Correct     A  0.965398  Sierra Leone
# 1   KGH_Frac_Correct     B  0.892361  Sierra Leone
# 2   KGH_Frac_Correct     C  0.953287  Sierra Leone
# 3   KGH_Frac_Correct  DPA1  0.951786  Sierra Leone
# 4   KGH_Frac_Correct  DPB1  0.934028  Sierra Leone
# 5   KGH_Frac_Correct  DQA1  0.975779  Sierra Leone
# 6   KGH_Frac_Correct  DQB1  0.940767  Sierra Leone
# 7   KGH_Frac_Correct  DRB1  0.925347  Sierra Leone
# 32  ESN_Frac_Correct     A  0.956250    1000G Esan
# 33  ESN_Frac_Correct     B  0.942308    1000G Esan
# 34  ESN_Frac_Correct     C  0.987500    1000G Esan
# 35  ESN_Frac_Correct  DPA1       NaN    1000G Esan
# 36  ESN_Frac_Correct  DPB1       NaN    1000G Esan
# 37  ESN_Frac_Correct  DQA1       NaN    1000G Esan
# 38  ESN_Frac_Correct  DQB1  0.987500    1000G Esan
# 39  ESN_Frac_Correct  DRB1  0.987500    1000G Esan
# 64  MSL_Frac_Correct     A  0.992857   1000G Mende
# 65  MSL_Frac_Correct     B  0.914286   1000G Mende
# 66  MSL_Frac_Correct     C  0.985714   1000G Mende
# 67  MSL_Frac_Correct  DPA1       NaN   1000G Mende
# 68  MSL_Frac_Correct  DPB1       NaN   1000G Mende
# 69  MSL_Frac_Correct  DQA1       NaN   1000G Mende
# 70  MSL_Frac_Correct  DQB1  0.985714   1000G Mende
# 71  MSL_Frac_Correct  DRB1  0.971429   1000G Mende
