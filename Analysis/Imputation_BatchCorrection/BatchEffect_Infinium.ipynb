# %%
# %matplotlib inline
import os
import pandas as pd
import seaborn as sns
import numpy as np
import subprocess as sp
import matplotlib.pyplot as plt
from IPython.display import display
from statsmodels.stats.multitest import fdrcorrection

def save_df_to_npz(obj, filename):
    np.savez_compressed(filename, data=obj.values, index=obj.index.values, columns=obj.columns.values)

def load_df_from_npz(filename):
    with np.load(filename, allow_pickle=True) as f:
        obj = pd.DataFrame(**f)
    return obj

# %% [markdown]
# ## Make tempdir for intermediate files

# %%
outdir = '../../data/tmp'
if not os.path.exists(outdir):
    os.mkdir(outdir)
    
miscdir = '../../data/tmp/misc'
if not os.path.exists(miscdir):
    os.mkdir(miscdir)

# %% [markdown]
# ## Prepare data matrices

# %%
phenofn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/preANDpost2016_Merged_Complete_Metadata_WithAge_20210818.tsv'
phenoinfo = pd.read_csv(phenofn, sep='\t')
phenoinfo.index = phenoinfo['Full_IID']
phenoinfo.head()
# Out:
#                                 Full_IID Genotype_Sex ID_Reformat  \
# Full_IID
# July2014NG_SM-6C4M9  July2014NG_SM-6C4M9            1    SM-6C4M9
# July2014NG_SM-4XBS9  July2014NG_SM-4XBS9            2    SM-4XBS9
# July2014NG_SM-6C4MA  July2014NG_SM-6C4MA            1    SM-6C4MA
# July2014NG_SM-6C4MB  July2014NG_SM-6C4MB            2    SM-6C4MB
# July2014NG_SM-4XBSM  July2014NG_SM-4XBSM            2    SM-4XBSM
#
#                            SampleType sex Disease ISTH_SandR_Key  \
# Full_IID
# July2014NG_SM-6C4M9  SuspectedLassaNG   1   Lassa            NaN
# July2014NG_SM-4XBS9  Pre2016ControlNG   2   Lassa            NaN
# July2014NG_SM-6C4MA  SuspectedLassaNG   1   Lassa            NaN
# July2014NG_SM-6C4MB  SuspectedLassaNG   2   Lassa            NaN
# July2014NG_SM-4XBSM  Pre2016ControlNG   2   Lassa            NaN
#
#                     KGH_Survivor_Key KGH_AcuteLassa_Key KGH_AcuteEbola_Key  \
# Full_IID
# July2014NG_SM-6C4M9              NaN                NaN                NaN
# July2014NG_SM-4XBS9              NaN                NaN                NaN
# July2014NG_SM-6C4MA              NaN                NaN                NaN
# July2014NG_SM-6C4MB              NaN                NaN                NaN
# July2014NG_SM-4XBSM              NaN                NaN                NaN
#
#                      ...       Batch Country Sex_Discrepant  \
# Full_IID             ...
# July2014NG_SM-6C4M9  ...  July2014NG      NG          False
# July2014NG_SM-4XBS9  ...  July2014NG      NG          False
# July2014NG_SM-6C4MA  ...  July2014NG      NG          False
# July2014NG_SM-6C4MB  ...  July2014NG      NG          False
# July2014NG_SM-4XBSM  ...  July2014NG      NG          False
#
#                      Sex_Discrepant_Notes     Status Clean_HLA_ID    Epoch  \
# Full_IID
# July2014NG_SM-6C4M9                   NaN  Passes QC          NaN  Pre2016
# July2014NG_SM-4XBS9                   NaN  Passes QC          NaN  Pre2016
# July2014NG_SM-6C4MA                   NaN  Passes QC          NaN  Pre2016
# July2014NG_SM-6C4MB                   NaN  Passes QC          NaN  Pre2016
# July2014NG_SM-4XBSM                   NaN  Passes QC          NaN  Pre2016
#
#                           Array CollectionEpoch   Age
# Full_IID
# July2014NG_SM-6C4M9  Omni_25M_B         Pre2016  30.0
# July2014NG_SM-4XBS9  Omni_25M_B         Pre2016  26.0
# July2014NG_SM-6C4MA  Omni_25M_B         Pre2016  32.0
# July2014NG_SM-6C4MB  Omni_25M_B         Pre2016  65.0
# July2014NG_SM-4XBSM  Omni_25M_B         Pre2016  47.0
#
# [5 rows x 24 columns]

# %%
group_fn = 'gs://popgen-gwas/data/metadata/Annotated_GenotypedData/OmniH3Merged_PrePost2016_AggregatedLASVPhenotypes_20210829.tsv'
groups = pd.read_csv(group_fn, sep='\t')
groups.index = groups['#IID']
ind = groups.index[groups['Post2016_NG_LASV_qPCR2xPos'] | groups['Post2016_NG_LASV_SeqPos'] | groups['Pre2016_NG_LASV_SeqPos'] | groups['Pre2016_SL_LASV_AgORSeqPos'] | groups['Post2016_SL_LASV_AgPos']]
phenoinfo['LASV_Case'] = 0
phenoinfo.loc[ind, 'LASV_Case'] = 1

# %%
pd.crosstab(phenoinfo['Country'], phenoinfo['Array'])
# Out:
# Array      H3  Omni_25M_A  Omni_25M_B  Omni_5M
# Country
# NG       1291         953         129      419
# SL       1747         805         418       66

# %%
preprereps = pd.read_csv('gs://popgen-gwas/data/metadata/Annotated_GenotypedData/ExpectedDuplicates/Pre2016_DuplicateSelection_Complete_20210724.tsv', sep='\t')
preprereps.head()
# Out:
#                               Duplicate_Pair                  IID  \
# 0    Fall2013_SM-2986Y---July2014NG_SM-4XBSM  July2014NG_SM-4XBSM
# 1    Fall2013_SM-2986Y---July2014NG_SM-4XBSM    Fall2013_SM-2986Y
# 2     Fall2013_SM-4CY2L---March2012_SM-297Z2    Fall2013_SM-4CY2L
# 3     Fall2013_SM-4CY2L---March2012_SM-297Z2   March2012_SM-297Z2
# 4  July2014SL_SM-5W5QG---July2014SL_SM-5W5R2  July2014SL_SM-5W5R2
#
#       Duplicate_To_Use  Relatedness   F_MISS  Expected  \
# 0  July2014NG_SM-4XBSM     0.998971  0.03793     False
# 1  July2014NG_SM-4XBSM     0.998971  0.03857     False
# 2    Fall2013_SM-4CY2L     0.992573  0.03201     False
# 3    Fall2013_SM-4CY2L     0.992573  0.03310     False
# 4  July2014SL_SM-5W5R2     1.035760  0.03945     False
#
#                                                Notes
# 0  Discrepant age and 1 IgG but doesn't change ph...
# 1  Discrepant age and 1 IgG but doesn't change ph...
# 2                                                NaN
# 3                                                NaN
# 4                        Discrepant age but same phe

# %%
prepostreps = pd.read_csv('gs://popgen-gwas/data/metadata/Annotated_GenotypedData/ExpectedDuplicates/Pre_To_Post_Duplicate_Mapping_20190822.tsv', sep='\t')
prepostreps['Pre_ID'].head()
# Out:
# 0     Winter2013_F-SL-149F
# 1      Winter2013_SM-3NQA5
# 2       Winter2013_F-SL-6C
# 3      Winter2013_F-SL-71C
# 4    Winter2013_F-NG-C-84F
# Name: Pre_ID, dtype: object

# %%
prerepsamples = list(set(preprereps['IID']).union(prepostreps['Pre_ID']))

# %%
a = '../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1'

# %%
fam = pd.read_csv(a+'.fam', sep=' ', header=None)
fam[4].replace(np.nan, -1).value_counts()
# Out:
# 2    1599
# 1    1181
# Name: 4, dtype: int64

# %%
fam[1].isin(prerepsamples).value_counts()
# Out:
# False    2331
# True      449
# Name: 1, dtype: int64

# %%
repsamplesfn = a+'.HasReplicateSamples.tsv'
print(repsamplesfn)
fam.loc[fam[1].isin(prerepsamples), [0,1]].to_csv(repsamplesfn, sep='\t', header=None, index=False)
# Out:
# ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.tsv

# %%
cmd = 'plink --bfile {a} --recode vcf-iid --out {a}.HasReplicateSamples --keep-allele-order --keep {a}.HasReplicateSamples.tsv'.format(a=a)
print(cmd)
# !{cmd}
# Out:
# plink --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --recode vcf-iid --out ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples --keep-allele-order --keep ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.tsv
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.tsv
#   --keep-allele-order
#   --out ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples
#   --recode vcf-iid
#
# 128934 MB RAM detected; reserving 64467 MB for main workspace.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 449 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 428 founders and 21 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 195030 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.996268.
# 2308998 variants and 449 people pass filters and QC.
# Among remaining phenotypes, 31 are cases and 101 are controls.  (317 phenotypes
# are missing.)
# --recode vcf-iid to
# ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.vcf
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
3
# Out:
# 3

# %%
repvcffn = '{a}.HasReplicateSamples.vcf'.format(a=a)
repvcf = pd.read_csv(repvcffn, sep='\t', skiprows=29)
print('a')
repvcf.index = repvcf['ID']
repvcf = repvcf.iloc[:,9:]
print('b')
repvcf = repvcf.replace({'1/1':2, '0/0':0, '0/1':1, './.':-1})
print('c')
repvcf.head()
# Out:
# a
# b
# c
#               March2012_SM-298BJ  March2012_SM-2983J  March2012_SM-2983S  \
# ID
# 1:82154:A:G                    0                   0                   0
# 1:564768:T:C                   0                   0                   0
# 1:565196:T:C                   0                   0                   0
# 1:565374:A:G                   0                   0                   0
# 1:566206:A:G                   0                   0                   0
#
#               March2012_SM-297Z2  March2012_SM-298BM  March2012_SM-297XZ  \
# ID
# 1:82154:A:G                    0                   0                   0
# 1:564768:T:C                   0                   0                   0
# 1:565196:T:C                   0                   0                   0
# 1:565374:A:G                   0                   0                   0
# 1:566206:A:G                   0                   0                   0
#
#               reGenotypedNov2013_0131_1  Fall2013_SM-2986Y  \
# ID
# 1:82154:A:G                           0                  0
# 1:564768:T:C                          0                  0
# 1:565196:T:C                          0                  0
# 1:565374:A:G                          0                  0
# 1:566206:A:G                          0                  0
#
#               March2012_SM-2985X  March2012_SM-2F38S  ...  \
# ID                                                    ...
# 1:82154:A:G                    0                   0  ...
# 1:564768:T:C                   0                   2  ...
# 1:565196:T:C                   0                   0  ...
# 1:565374:A:G                   0                   0  ...
# 1:566206:A:G                   0                   0  ...
#
#               Winter2013_SM-3NQ87  Winter2013_SM-3NQ8E  Fall2013_SM-SORX  \
# ID
# 1:82154:A:G                     0                    0                 0
# 1:564768:T:C                    0                    0                 0
# 1:565196:T:C                    0                    0                 0
# 1:565374:A:G                    0                    0                 0
# 1:566206:A:G                    0                    0                 0
#
#               Fall2013_SM-SORZ  March2012_SM-2F38W  \
# ID
# 1:82154:A:G                  0                   0
# 1:564768:T:C                 0                   0
# 1:565196:T:C                 0                   0
# 1:565374:A:G                 0                   0
# 1:566206:A:G                 0                   0
#
#               reGenotypedNov2013_SM-8750J_1  March2012_SM-2F38T  \
# ID
# 1:82154:A:G                               0                   0
# 1:564768:T:C                              0                   0
# 1:565196:T:C                              0                   0
# 1:565374:A:G                              0                   0
# 1:566206:A:G                              0                   0
#
#               reGenotypedNov2013_SM-GRN85_1  reGenotypedNov2013_SM-LW4CG_1  \
# ID
# 1:82154:A:G                               0                              0
# 1:564768:T:C                              0                              0
# 1:565196:T:C                              0                              0
# 1:565374:A:G                              0                              0
# 1:566206:A:G                              0                              0
#
#               Winter2013_SM-298CL
# ID
# 1:82154:A:G                     0
# 1:564768:T:C                    0
# 1:565196:T:C                    0
# 1:565374:A:G                    0
# 1:566206:A:G                    0
#
# [5 rows x 449 columns]

# %%
npzvcffn = repvcffn.replace('.vcf', '.vcf.npz')

# %%
save_df_to_npz(repvcf, npzvcffn)

# %%
npzvcffn = '../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.vcf.npz'

# %%
repvcf = load_df_from_npz(npzvcffn)

# %% [markdown]
# ## Now organize into matrices for comparisons of re-genotyped samples

# %%
set25A = '../../data/tmp/plink/var25a/HumanOmni2.5-8v1_A_Merged.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'
set25B = '../../data/tmp/plink/var25b/HumanOmni2.5-8v1-1_B_Merged.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'
set5 = '../../data/tmp/plink/var5/HumanOmni5-4v1_B.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'

a25a_samps = list(pd.read_csv(set25A, header=None, sep='\t')[1])
a25b_samps = list(pd.read_csv(set25B, header=None, sep='\t')[1])
a5_samps = list(pd.read_csv(set5, header=None, sep='\t')[1])

# %% [markdown]
# ### Exclude 66 SL omni 5Msamples from the set

# %%
sltoexclude = list(phenoinfo.loc[(phenoinfo['Array'] == 'Omni_5M') & (phenoinfo['Country'] == 'SL'), 'Full_IID'])
a5_samps = set(a5_samps) - set(sltoexclude)

# %%
preprereps = pd.read_csv('gs://popgen-gwas/data/metadata/Annotated_GenotypedData/ExpectedDuplicates/Pre2016_DuplicateSelection_Complete_20190822.tsv', sep='\t')
preprereps.head()
# Out:
#                               Duplicate_Pair                  IID  \
# 0    Fall2013_SM-2986Y---July2014NG_SM-4XBSM  July2014NG_SM-4XBSM
# 1    Fall2013_SM-2986Y---July2014NG_SM-4XBSM    Fall2013_SM-2986Y
# 2     Fall2013_SM-4CY2L---March2012_SM-297Z2    Fall2013_SM-4CY2L
# 3     Fall2013_SM-4CY2L---March2012_SM-297Z2   March2012_SM-297Z2
# 4  July2014SL_SM-5W5QG---July2014SL_SM-5W5R2  July2014SL_SM-5W5R2
#
#       Duplicate_To_Use  Relatedness   F_MISS  Expected  \
# 0  July2014NG_SM-4XBSM     0.998971  0.03793     False
# 1  July2014NG_SM-4XBSM     0.998971  0.03857     False
# 2    Fall2013_SM-4CY2L     0.992573  0.03201     False
# 3    Fall2013_SM-4CY2L     0.992573  0.03310     False
# 4  July2014SL_SM-5W5R2     1.035760  0.03945     False
#
#                                                Notes
# 0  Discrepant age and 1 IgG but doesn't change ph...
# 1  Discrepant age and 1 IgG but doesn't change ph...
# 2                                                NaN
# 3                                                NaN
# 4                        Discrepant age but same phe

# %%
pd.crosstab(phenoinfo.loc[[x for x in preprereps['Duplicate_To_Use'].unique() if x != '-1'], 'Array'], phenoinfo.loc[[x for x in preprereps['Duplicate_To_Use'].unique() if x != '-1'], 'Country'])
# Out:
# Country     NG  SL
# Array
# Omni_25M_A  22   4
# Omni_25M_B   1  11
# Omni_5M     14  65

# %%
dupgroups_a25a_a25b = []
dupgroups_a25a_a5 = []
dupgroups_a25b_a5 = []
dupgroups_a25_a5 = []
for dp in preprereps['Duplicate_Pair'].unique():
    items = dp.split('---')
    a25a_list = []
    a25b_list = []
    a5_list = []
    a25ab_list = []

    for i in items:
        if i in a25a_samps:
            a25a_list.append(i)
        elif i in a25b_samps:
            a25b_list.append(i)
        elif i in a5_samps:
            a5_list.append(i)
    
        if (i in a25a_samps) or (i in a25b_samps):
            a25ab_list.append(i)
    
    
    if (len(a25a_list)>0) or (len(a25b_list)>0):
        dupgroups_a25a_a25b.append([a25a_list, a25b_list])

    if (len(a25a_list)>0) or (len(a5_list)>0):
        dupgroups_a25a_a5.append([a25a_list, a5_list])    
            
    if (len(a25b_list)>0) or (len(a5_list)>0):
        dupgroups_a25b_a5.append([a25b_list, a5_list])    

    if (len(a25ab_list)>0) or (len(a5_list)>0):
        dupgroups_a25_a5.append([a25ab_list, a5_list])

# %%
len([x for x in dupgroups_a25a_a25b if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25a_a5 if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25b_a5 if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25_a5 if (len(x[0])>0) and (len(x[1])>0)])
# Out:
# (19, 26, 0, 26)

# %%
len([x for x in dupgroups_a25a_a25b if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25a_a5 if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25b_a5 if (len(x[0])>0) and (len(x[1])>0)]), len([x for x in dupgroups_a25_a5 if (len(x[0])>0) and (len(x[1])>0)])
# Out:
# (19, 26, 0, 26)

# %%
def get_concordance(a1dat, a2dat, dupgroups):
    cols = ['B1_AllRep_Concordance', 'B1_Dedup_Concordance', 'B1_AllRep_Total', 'B1_Dedup_Total',
        'B2_AllRep_Concordance', 'B2_Dedup_Concordance', 'B2_AllRep_Total', 'B2_Dedup_Total',
        'Between_AllRep_Concordance', 'Between_Dedup_Concordance', 'Between_AllRep_Total', 'Between_Dedup_Total']
    results = pd.DataFrame(0, index=a1dat.index, columns=cols)
    results.head()

    disc = np.zeros(results.shape[0])
    counter = pd.Series(disc, index=results.index)
    discrepancy = pd.Series(disc, index=results.index)
    for (b1, b2) in dupgroups:
        if len(b1) > 1:
            counter_new = counter.copy()
            discrepancy_new = discrepancy.copy()
            for i in range(len(b1)-1):
                for j in range(i+1, len(b1)):
                    nonnull = (a1dat[b1[i]] != -1) & (a1dat[b1[j]] != -1)
                    counter_new += nonnull
                    discrepancy_new += ((a1dat[b1[i]] != a1dat[b1[j]]) & nonnull)
            results['B1_AllRep_Total'] += counter_new
            results['B1_AllRep_Concordance'] += discrepancy_new
            ind = counter_new > 0
            results.loc[ind, 'B1_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
            results.loc[ind, 'B1_Dedup_Total'] += 1
        
        if len(b2) > 1:
            counter_new = counter.copy()
            discrepancy_new = discrepancy.copy()
            for i in range(len(b2)-1):
                for j in range(i+1, len(b2)):
                    nonnull = (a2dat[b2[i]] != -1) & (a2dat[b2[j]] != -1)
                    counter_new += nonnull
                    discrepancy_new += ((a2dat[b2[i]] != a2dat[b2[j]]) & nonnull)
            results['B2_AllRep_Total'] += counter_new
            results['B2_AllRep_Concordance'] += discrepancy_new
            ind = counter_new > 0
            results.loc[ind, 'B2_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
            results.loc[ind, 'B2_Dedup_Total'] += 1        
        
        if (len(b1) > 0) and (len(b2) > 0) :
            counter_new = counter.copy()
            discrepancy_new = discrepancy.copy()
            for i in range(len(b1)):
                for j in range(len(b2)):
                    nonnull = (a1dat[b1[i]] != -1) & (a2dat[b2[j]] != -1)
                    counter_new += nonnull
                    discrepancy_new += ((a1dat[b1[i]] != a2dat[b2[j]]) & nonnull)
            results['Between_AllRep_Total'] += counter_new
            results['Between_AllRep_Concordance'] += discrepancy_new
            ind = counter_new > 0
            results.loc[ind, 'Between_Dedup_Concordance'] += (discrepancy_new.loc[ind] / counter_new.loc[ind])
            results.loc[ind, 'Between_Dedup_Total'] += 1
            
    return(results)

# %%
a25a_samps_overlap = list(set(a25a_samps).intersection(repvcf.columns))
a25b_samps_overlap = list(set(a25b_samps).intersection(repvcf.columns))
a25_samps_overlap = a25a_samps_overlap + a25b_samps_overlap
a5_samps_overlap = list(set(a5_samps).intersection(repvcf.columns))

# %%
repvcf[a25a_samps_overlap].head()
# Out:
#               Winter2013_SM-299PT  Winter2013_SM-39NA9  Winter2013_SM-3NQK4  \
# 1:82154:A:G                     0                    0                    0
# 1:564768:T:C                    0                    0                    0
# 1:565196:T:C                    0                    0                    0
# 1:565374:A:G                    0                    0                    0
# 1:566206:A:G                    0                    0                    0
#
#               reGenotypedNov2013_C-0104_1  Winter2013_SM-3MFLL  \
# 1:82154:A:G                             0                    0
# 1:564768:T:C                            0                    0
# 1:565196:T:C                            0                    0
# 1:565374:A:G                            0                    0
# 1:566206:A:G                            0                    0
#
#               Winter2013_SM-3NQKK  Winter2013_SM-39SMF  Winter2013_SM-39SMN  \
# 1:82154:A:G                     0                    0                    0
# 1:564768:T:C                    0                    0                    0
# 1:565196:T:C                    0                    0                    0
# 1:565374:A:G                    0                    0                    0
# 1:566206:A:G                    0                    0                    0
#
#               Winter2013_F-NG-C-106F  Winter2013_F-SL-12C  ...  \
# 1:82154:A:G                        0                    0  ...
# 1:564768:T:C                       0                    0  ...
# 1:565196:T:C                       0                    0  ...
# 1:565374:A:G                       0                    0  ...
# 1:566206:A:G                       0                    0  ...
#
#               Fall2013_SM-3KQFV  Winter2013_SM-39SMX  Winter2013_SM-3NQK5  \
# 1:82154:A:G                   0                    0                    0
# 1:564768:T:C                  0                    0                    0
# 1:565196:T:C                  0                    0                    0
# 1:565374:A:G                  0                    0                    0
# 1:566206:A:G                  0                    0                    0
#
#               Winter2013_SM-39NBF  Fall2013_SM-2989W  Winter2013_F-NG-C-49F  \
# 1:82154:A:G                     0                  0                      0
# 1:564768:T:C                    0                  0                      0
# 1:565196:T:C                    0                  0                      0
# 1:565374:A:G                    0                  0                      0
# 1:566206:A:G                    0                  0                      0
#
#               Winter2013_F-SL-48C  Fall2013_SM-4CDLT  Winter2013_F-NG-NC-140F  \
# 1:82154:A:G                     0                  0                        0
# 1:564768:T:C                    0                  0                        0
# 1:565196:T:C                    0                  0                        0
# 1:565374:A:G                    0                  0                        0
# 1:566206:A:G                    0                  0                        0
#
#               Fall2013_SM-29898
# 1:82154:A:G                   0
# 1:564768:T:C                  0
# 1:565196:T:C                  0
# 1:565374:A:G                  0
# 1:566206:A:G                  0
#
# [5 rows x 224 columns]

# %%
conc_a25a_a25b = get_concordance(repvcf[a25a_samps_overlap], repvcf[a25b_samps_overlap], dupgroups_a25a_a25b)
save_df_to_npz(conc_a25a_a25b, '../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a25b_20210715.npz')

# %%
totest = conc_a25a_a25b
x = (totest['B1_AllRep_Concordance'] + totest['B2_AllRep_Concordance']) / (totest['B1_AllRep_Total'] + totest['B2_AllRep_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = totest['Between_AllRep_Concordance'] / totest['Between_AllRep_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind], s=3)
plt.plot([0,.6], [0,.6], color='r')

plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('25a vs 25b - All replicates')
# Out:
# Text(0.5, 1.0, '25a vs 25b - All replicates')

# %%
conc_a25a_a25b['Between_AllRep_Total'].value_counts().head()
# Out:
# 22.0    2116910
# 21.0     133342
# 20.0      37705
# 19.0      12517
# 18.0       4769
# Name: Between_AllRep_Total, dtype: int64

# %%
((conc_a25a_a25b['B1_AllRep_Total'] + conc_a25a_a25b['B2_AllRep_Total'])).value_counts().head()
# Out:
# 17.0    2060235
# 16.0     183659
# 15.0      41928
# 14.0      14241
# 13.0       5352
# dtype: int64

# %%
conc_a25a_a5 = get_concordance(repvcf[a25a_samps_overlap], repvcf[a5_samps_overlap], dupgroups_a25a_a5)
save_df_to_npz(conc_a25a_a5, '../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a5_20210715.npz')

# %%
totest = conc_a25a_a5
x = (totest['B1_AllRep_Concordance'] + totest['B2_AllRep_Concordance']) / (totest['B1_AllRep_Total'] + totest['B2_AllRep_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = totest['Between_AllRep_Concordance'] / totest['Between_AllRep_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind], s=3)
plt.plot([0,.6], [0,.6], color='r')

plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('25a vs 5 - All replicates')
# Out:
# Text(0.5, 1.0, '25a vs 5 - All replicates')

# %%
conc_a25b_a5 = get_concordance(repvcf[a25b_samps_overlap], repvcf[a5_samps_overlap], dupgroups_a25b_a5)
save_df_to_npz(conc_a25b_a5, '../../data/tmp/plink/merged_pre2016/replicate_concordance_a25b_vs_a5_20210715.npz')

# %%
conc_a25b_a5['B1_AllRep_Total'].max(), conc_a25b_a5['B2_AllRep_Total'].max()
# Out:
# (3.0, 2.0)

# %%
totest = conc_a25b_a5
x = (totest['B1_AllRep_Concordance'] + totest['B2_AllRep_Concordance']) / (totest['B1_AllRep_Total'] + totest['B2_AllRep_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = totest['Between_AllRep_Concordance'] / totest['Between_AllRep_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind], s=3)
plt.plot([0,.6], [0,.6], color='r')

plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('25b vs 5 - All replicates')
# Out:
# Text(0.5, 1.0, '25b vs 5 - All replicates')

# %%
conc_a25_a5 = get_concordance(repvcf[a25_samps_overlap], repvcf[a5_samps_overlap], dupgroups_a25_a5)
save_df_to_npz(conc_a25_a5, '../../data/tmp/plink/merged_pre2016/replicate_concordance_a25_vs_a5_20210715.npz')

# %%
totest = conc_a25_a5
x = (totest['B1_AllRep_Concordance'] + totest['B2_AllRep_Concordance']) / (totest['B1_AllRep_Total'] + totest['B2_AllRep_Total'])
#x = results['B1_AllRep_Concordance'] / results['B1_AllRep_Total']
y = totest['Between_AllRep_Concordance'] / totest['Between_AllRep_Total']
ind = (x>0) | (y>0)
plt.scatter(x.loc[ind], y.loc[ind], s=3)
plt.plot([0,.6], [0,.6], color='r')

plt.xlabel('Within batch fraction discordant')
plt.ylabel('Between batch fraction discordant')
plt.title('25combined vs 5 - All replicates')
# Out:
# Text(0.5, 1.0, '25combined vs 5 - All replicates')

# %% [markdown]
# ## Compare to GWAS association approach

# %%
dupres = {}
dupres['25a_vs_25b'] = load_df_from_npz('../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a25b_20210715.npz')
dupres['25a_vs_5'] = load_df_from_npz('../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a5_20210715.npz')
dupres['25b_vs_5'] = load_df_from_npz('../../data/tmp/plink/merged_pre2016/replicate_concordance_a25b_vs_a5_20210715.npz')
dupres['25_vs_5'] = load_df_from_npz('../../data/tmp/plink/merged_pre2016/replicate_concordance_a25_vs_a5_20210715.npz')

# %%
a25a_fn = '../../data/tmp/plink/var25a/HumanOmni2.5-8v1_A_Merged.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'
a25a_fam = pd.read_csv(a25a_fn, sep='\t', header=None)

a25b_fn = '../../data/tmp/plink/var25b/HumanOmni2.5-8v1-1_B_Merged.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'
a25b_fam = pd.read_csv(a25b_fn, sep='\t', header=None)

a5_fn = '../../data/tmp/plink/var5/HumanOmni5-4v1_B.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.fam'
a5_fam = pd.read_csv(a5_fn, sep='\t', header=None)

# %%
sltoexclude = list(phenoinfo.loc[(phenoinfo['Array'] == 'Omni_5M') & (phenoinfo['Country'] == 'SL'), 'Full_IID'])
a5_samps_tokeep = set(a5_fam[1]) - set(sltoexclude)
a5_fam[1].isin(a5_samps).value_counts()
# Out:
# True     419
# False     66
# Name: 1, dtype: int64

# %%
a5_fam = a5_fam.loc[a5_fam[1].isin(a5_samps_tokeep), :]

# %%
a5_fam.shape
# Out:
# (419, 6)

# %%
a25_fam = pd.concat([a25a_fam, a25b_fam], axis=0)

# %%
fullbase = '../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1'

# %%
comparisons = [
[a25a_fam, a25b_fam, '25a_vs_25b'],
[a25a_fam, a5_fam, '25a_vs_5'],
[a25b_fam, a5_fam, '25b_vs_5'],
[a25_fam, a5_fam, '25_vs_5'],
]

# %%
for c in comparisons:
    z = pd.concat([c[0], c[1]], axis=0)
    z.loc[z[1].isin(c[1][1]), 5] = 1
    z.loc[z[1].isin(c[0][1]), 5] = 0
    z['Country'] = phenoinfo.loc[z[1], 'Country'].values
    print(c[2])
    display(pd.crosstab(z[5].replace(np.nan, -1), z['Country'].replace(np.nan, 'null')))
# Out:
# 25a_vs_25b
# Country   NG   SL
# 5
# 0        950  805
# 1        124  416
# 25a_vs_5
# Country   NG   SL
# 5
# 0        950  805
# 1        419    0
# 25b_vs_5
# Country   NG   SL
# 5
# 0        124  416
# 1        419    0
# 25_vs_5
# Country    NG    SL
# 5
# 0        1074  1221
# 1         419     0

# %%
workingdir = '../../data/tmp/plink/merged_pre2016/'
for c in comparisons:
    keep_list_fn = workingdir + c[2] + '_SamplesToKeep.tsv'
    outbase = workingdir + c[2] + '.NoDups.20210804'
    merged_keep_list = pd.concat([c[0], c[1]], axis=0)
    dupstofilt = list(preprereps.loc[preprereps['IID']!=preprereps['Duplicate_To_Use'], 'IID'])
    merged_keep_list = merged_keep_list.loc[~merged_keep_list[1].isin(dupstofilt), :]
    merged_keep_list.iloc[:,:2].to_csv(keep_list_fn, sep='\t', index=False, header=False)
    cmd = 'plink --make-bed --bfile {a} --keep {keepfn} --keep-allele-order --out {out}'.format(a=fullbase, keepfn=keep_list_fn, out=outbase)
    print(cmd)
    # !{cmd}

    fam = pd.read_csv(outbase+'.fam', sep=' ', header=None)
    fam.loc[fam[1].isin(c[1][1]),5] = 1
    fam.loc[fam[1].isin(c[0][1]),5] = 0
    print(fam[5].value_counts())
    fam.to_csv(outbase+'.fam', sep=' ', header=False, index=False)    
    
    print(c[2])
    fam_fordisplay = fam.copy()
    fam_fordisplay['Country'] = phenoinfo.loc[fam_fordisplay[1], 'Country'].values
    display(pd.crosstab(fam_fordisplay[5].replace(np.nan, -1), fam_fordisplay['Country'].replace(np.nan, 'null')))
    
    #produce a pruned subset of markers that are in approximate linkage equilibrium with each other
    prunefn = outbase + '.prune.ld_3e-1.maf_1e-1'
    prune_cmd = 'plink --bfile {adat} --out {adatout} --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1'.format(adat=outbase, adatout=prunefn)
    print(prune_cmd)
    # !{prune_cmd}

    #do PCA
    pca_cmd = 'plink --bfile {adat} --out {adatout} --pca 20 --extract {adatout}.prune.in'.format(adat=outbase, adatout=prunefn)
    print(pca_cmd)
    # !{pca_cmd}

    #make square relationship matrix 
    relfn = outbase + '.prune.ld_3e-1.maf_1e-1'
    rel_cmd = 'plink --make-rel square --bfile {adat} --out {adatout} --extract {prune}.prune.in'.format(adat=outbase, adatout=relfn, prune=prunefn)
    print(rel_cmd)
    # !{rel_cmd}

    
    #excludes one member of each pair of samples with observed genomic relatedness greater than the given cutoff value
    #unrelatedsfn = outbase + 'unrelated.individuals.5e-2.txt'
    #get_unrelateds_cmd = 'plink --rel-cutoff 0.05 --grm-bin {rel} --out {out}'.format(rel=relfn, out=unrelatedsfn)
    #print(get_unrelateds_cmd)
    #!{get_unrelateds_cmd}
    
    relid = pd.read_csv(relfn+'.rel.id', header=None, sep ='\t')[1].iloc[0:]
    rel = pd.read_csv(relfn+'.rel', header=None, sep='\t')
    rel.index = relid
    rel.columns = relid
    rel.to_csv(relfn+'.rel.withids.tsv', sep='\t')
    
    phenofn = outbase + '.cov'
    cov = pd.read_csv(outbase+'.fam', sep=' ', header=None)
    cov = cov[[0,1,5]]
    cov.columns = ['FID', 'IID', 'Batch']
    cov.index = cov['IID']
        
    cov['Country'] = phenoinfo.loc[cov['IID'], 'Country'].replace({'NG':'0', 'SL':'1'}).replace(np.nan, '-9').values
    #cov['Batch'] = phenoinfo.loc[cov['IID'], 'Array'].replace({'Omni_25M_B':0, 'Omni_25M_A':0, 'Omni_5M':0, 'H3':1}).values
    cov['LASV_Case'] = phenoinfo.loc[cov['IID'], 'LASV_Case'].replace(np.nan, 0).values    
    
    print(cov['Batch'].value_counts())
    print(cov['Country'].value_counts())    
    cov.to_csv(phenofn, sep='\t', index=False)
# Out:
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b_SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b_SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 2181 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1956 founders and 225 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 959476 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995628.
# 2308998 variants and 2181 people pass filters and QC.
# Among remaining phenotypes, 197 are cases and 182 are controls.  (1802
# phenotypes are missing.)
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.bed +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.bim +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    1711
# 1     470
# Name: 5, dtype: int64
# 25a_vs_25b
# Country   NG   SL
# 5
# 0        931  780
# 1        124  346
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2181 people (955 males, 1226 females) loaded from .fam.
# 470 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1956 founders and 225 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 959476 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995628.
# 2595 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 280 variants removed due to Hardy-Weinberg exact test.
# 1189774 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1116349 variants and 2181 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 470 are controls.  (1711 phenotypes
# are missing.)
# Pruned 57274 variants from chromosome 1, leaving 26963.
# Pruned 62620 variants from chromosome 2, leaving 27903.
# Pruned 53059 variants from chromosome 3, leaving 23563.
# Pruned 49479 variants from chromosome 4, leaving 22206.
# Pruned 45965 variants from chromosome 5, leaving 21224.
# Pruned 51126 variants from chromosome 6, leaving 20436.
# Pruned 41254 variants from chromosome 7, leaving 19170.
# Pruned 40819 variants from chromosome 8, leaving 18659.
# Pruned 33234 variants from chromosome 9, leaving 16141.
# Pruned 38337 variants from chromosome 10, leaving 17677.
# Pruned 37250 variants from chromosome 11, leaving 16575.
# Pruned 35289 variants from chromosome 12, leaving 16826.
# Pruned 27109 variants from chromosome 13, leaving 12804.
# Pruned 24448 variants from chromosome 14, leaving 11773.
# Pruned 22809 variants from chromosome 15, leaving 12155.
# Pruned 24076 variants from chromosome 16, leaving 12893.
# Pruned 19877 variants from chromosome 17, leaving 11411.
# Pruned 22054 variants from chromosome 18, leaving 11720.
# Pruned 14195 variants from chromosome 19, leaving 8451.
# Pruned 17897 variants from chromosome 20, leaving 9802.
# Pruned 10324 variants from chromosome 21, leaving 5658.
# Pruned 10588 variants from chromosome 22, leaving 6060.
# Pruned 17886 variants from chromosome 23, leaving 9272.
# Pruned 15 variants from chromosome 24, leaving 23.
# Pruning complete.  756984 of 1116349 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2181 people (955 males, 1226 females) loaded from .fam.
# 470 phenotype values loaded from .fam.
# --extract: 359365 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1956 founders and 225 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 288400 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994502.
# 359365 variants and 2181 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 470 are controls.  (1711 phenotypes
# are missing.)
# Excluding 9295 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2181 people (955 males, 1226 females) loaded from .fam.
# 470 phenotype values loaded from .fam.
# --extract: 359365 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1956 founders and 225 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 288400 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994502.
# 359365 variants and 2181 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 470 are controls.  (1711 phenotypes
# are missing.)
# Excluding 9295 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    1711
# 1     470
# Name: Batch, dtype: int64
# 1    1126
# 0    1055
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25a_vs_5_SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25a_vs_5_SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 2113 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1865 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 935553 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995629.
# 2308998 variants and 2113 people pass filters and QC.
# Among remaining phenotypes, 145 are cases and 182 are controls.  (1786
# phenotypes are missing.)
# --make-bed to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.bed
# + ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.bim +
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    1711
# 1     402
# Name: 5, dtype: int64
# 25a_vs_5
# Country   NG   SL
# 5
# 0        931  780
# 1        402    0
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2113 people (907 males, 1206 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1865 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 935553 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995629.
# 3936 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 197 variants removed due to Hardy-Weinberg exact test.
# 1183792 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1121073 variants and 2113 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1711 phenotypes
# are missing.)
# Pruned 57572 variants from chromosome 1, leaving 27077.
# Pruned 62909 variants from chromosome 2, leaving 28035.
# Pruned 53406 variants from chromosome 3, leaving 23555.
# Pruned 49698 variants from chromosome 4, leaving 22310.
# Pruned 46110 variants from chromosome 5, leaving 21376.
# Pruned 51362 variants from chromosome 6, leaving 20451.
# Pruned 41458 variants from chromosome 7, leaving 19183.
# Pruned 41108 variants from chromosome 8, leaving 18634.
# Pruned 33438 variants from chromosome 9, leaving 16130.
# Pruned 38535 variants from chromosome 10, leaving 17678.
# Pruned 37448 variants from chromosome 11, leaving 16612.
# Pruned 35488 variants from chromosome 12, leaving 16805.
# Pruned 27265 variants from chromosome 13, leaving 12896.
# Pruned 24599 variants from chromosome 14, leaving 11715.
# Pruned 22947 variants from chromosome 15, leaving 12136.
# Pruned 24164 variants from chromosome 16, leaving 13001.
# Pruned 20000 variants from chromosome 17, leaving 11436.
# Pruned 22077 variants from chromosome 18, leaving 11817.
# Pruned 14276 variants from chromosome 19, leaving 8458.
# Pruned 17971 variants from chromosome 20, leaving 9817.
# Pruned 10365 variants from chromosome 21, leaving 5661.
# Pruned 10572 variants from chromosome 22, leaving 6089.
# Pruned 17930 variants from chromosome 23, leaving 9317.
# Pruned 169 variants from chromosome 24, leaving 17.
# Pruning complete.  760867 of 1121073 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2113 people (907 males, 1206 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 360206 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1865 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 265622 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994615.
# 360206 variants and 2113 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1711 phenotypes
# are missing.)
# Excluding 9334 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2113 people (907 males, 1206 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 360206 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1865 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 265622 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994615.
# 360206 variants and 2113 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1711 phenotypes
# are missing.)
# Excluding 9334 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    1711
# 1     402
# Name: Batch, dtype: int64
# 0    1333
# 1     780
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25b_vs_5_SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25b_vs_5_SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 872 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 849 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 334895 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.997263.
# 2308998 variants and 872 people pass filters and QC.
# Among remaining phenotypes, 52 are cases and 0 are controls.  (820 phenotypes
# are missing.)
# --make-bed to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.bed
# + ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.bim +
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    470
# 1    402
# Name: 5, dtype: int64
# 25b_vs_5
# Country   NG   SL
# 5
# 0        124  346
# 1        402    0
# plink --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 872 people (350 males, 522 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 849 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 334895 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997263.
# 868 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 195 variants removed due to Hardy-Weinberg exact test.
# 1184511 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1123424 variants and 872 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (470 phenotypes
# are missing.)
# Pruned 57829 variants from chromosome 1, leaving 27050.
# Pruned 63164 variants from chromosome 2, leaving 27932.
# Pruned 53595 variants from chromosome 3, leaving 23588.
# Pruned 49903 variants from chromosome 4, leaving 22233.
# Pruned 46447 variants from chromosome 5, leaving 21221.
# Pruned 51615 variants from chromosome 6, leaving 20390.
# Pruned 41668 variants from chromosome 7, leaving 19103.
# Pruned 41197 variants from chromosome 8, leaving 18659.
# Pruned 33524 variants from chromosome 9, leaving 16124.
# Pruned 38704 variants from chromosome 10, leaving 17611.
# Pruned 37576 variants from chromosome 11, leaving 16540.
# Pruned 35561 variants from chromosome 12, leaving 16804.
# Pruned 27357 variants from chromosome 13, leaving 12911.
# Pruned 24699 variants from chromosome 14, leaving 11670.
# Pruned 23012 variants from chromosome 15, leaving 12155.
# Pruned 24373 variants from chromosome 16, leaving 12911.
# Pruned 20050 variants from chromosome 17, leaving 11443.
# Pruned 22134 variants from chromosome 18, leaving 11731.
# Pruned 14388 variants from chromosome 19, leaving 8385.
# Pruned 18084 variants from chromosome 20, leaving 9776.
# Pruned 10435 variants from chromosome 21, leaving 5646.
# Pruned 10703 variants from chromosome 22, leaving 6047.
# Pruned 18138 variants from chromosome 23, leaving 9301.
# Pruned 15 variants from chromosome 24, leaving 22.
# Pruning complete.  764171 of 1123424 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 872 people (350 males, 522 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 359253 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 849 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 106677 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99643.
# 359253 variants and 872 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (470 phenotypes
# are missing.)
# Excluding 9323 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 872 people (350 males, 522 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 359253 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 849 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 106677 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99643.
# 359253 variants and 872 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (470 phenotypes
# are missing.)
# Excluding 9323 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    470
# 1    402
# Name: Batch, dtype: int64
# 0    526
# 1    346
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25_vs_5_SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25_vs_5_SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 2583 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2335 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1114962 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.hh ); many commands
# treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995904.
# 2308998 variants and 2583 people pass filters and QC.
# Among remaining phenotypes, 197 are cases and 182 are controls.  (2204
# phenotypes are missing.)
# --make-bed to ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.bed +
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.bim +
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    2181
# 1     402
# Name: 5, dtype: int64
# 25_vs_5
# Country    NG    SL
# 5
# 0        1055  1126
# 1         402     0
# plink --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2583 people (1106 males, 1477 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2335 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 1114962 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995904.
# 515 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 205 variants removed due to Hardy-Weinberg exact test.
# 1184853 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1123425 variants and 2583 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (2181 phenotypes
# are missing.)
# Pruned 57564 variants from chromosome 1, leaving 27284.
# Pruned 62889 variants from chromosome 2, leaving 28169.
# Pruned 53353 variants from chromosome 3, leaving 23756.
# Pruned 49720 variants from chromosome 4, leaving 22437.
# Pruned 46197 variants from chromosome 5, leaving 21459.
# Pruned 51383 variants from chromosome 6, leaving 20561.
# Pruned 41447 variants from chromosome 7, leaving 19311.
# Pruned 41067 variants from chromosome 8, leaving 18820.
# Pruned 33433 variants from chromosome 9, leaving 16238.
# Pruned 38493 variants from chromosome 10, leaving 17844.
# Pruned 37478 variants from chromosome 11, leaving 16697.
# Pruned 35447 variants from chromosome 12, leaving 16946.
# Pruned 27262 variants from chromosome 13, leaving 12992.
# Pruned 24590 variants from chromosome 14, leaving 11796.
# Pruned 22934 variants from chromosome 15, leaving 12247.
# Pruned 24174 variants from chromosome 16, leaving 13087.
# Pruned 19997 variants from chromosome 17, leaving 11516.
# Pruned 22068 variants from chromosome 18, leaving 11855.
# Pruned 14298 variants from chromosome 19, leaving 8514.
# Pruned 17988 variants from chromosome 20, leaving 9876.
# Pruned 10371 variants from chromosome 21, leaving 5697.
# Pruned 10617 variants from chromosome 22, leaving 6120.
# Pruned 18038 variants from chromosome 23, leaving 9360.
# Pruned 15 variants from chromosome 24, leaving 20.
# Pruning complete.  760823 of 1123425 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2583 people (1106 males, 1477 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 362602 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 2335 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 334362 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99471.
# 362602 variants and 2583 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (2181 phenotypes
# are missing.)
# Excluding 9380 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804
#   --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 12062 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2583 people (1106 males, 1477 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 362602 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 2335 founders and 248 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 334362 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99471.
# 362602 variants and 2583 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (2181 phenotypes
# are missing.)
# Excluding 9380 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    2181
# 1     402
# Name: Batch, dtype: int64
# 0    1457
# 1    1126
# Name: Country, dtype: int64

# %%
! gsutil -m rsync -r ../../data/tmp/plink/merged_pre2016 gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016
# Out:
# Building synchronization state...
# Starting synchronization...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bed...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bim...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.bed
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.bim
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.hh...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.cov
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.fam
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.hh
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.nullmodelCovCC.rds...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.resultsCovCC.tsv
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.hh [Content-Type=text/x-c++hdr]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.nullmodelCovCC.rds
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bed...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NoDups.20210804.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bim...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5_SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bed
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bim
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.hh...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.cov
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.fam
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.hh
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.nullmodelCovCC.rds
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.resultsCovCC.tsv
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.nullmodelCovCC.rds...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.hh [Content-Type=text/x-c++hdr]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NoDups.20210804.nullmodelCovCC.rds
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.log [Content-Type=application/octet-stream]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.resultsCovCC.tsv...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bed...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bim...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NoDups.20210804.resultsCovCC.tsv
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bed
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bim
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.hh...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.cov
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.fam
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.hh
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.nullmodelCovCC.rds
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.resultsCovCC.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bed...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.resultsCovCC.tsv
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bim...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b_SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bed
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bim
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.hh...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.cov
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.fam
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.hh
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.resultsCovCC.tsv
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.nullmodelCovCC.rds...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.log [Content-Type=application/octet-stream]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NoDups.20210804.nullmodelCovCC.rds
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.resultsCovCC.tsv...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bed...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NoDups.20210804.resultsCovCC.tsv
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bim...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5_SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bed
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bim
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.cov
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.fam
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.hh
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.resultsCovCC.tsv
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.hh [Content-Type=text/x-c++hdr]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NoDups.20210804.nullmodelCovCC.rds
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.log [Content-Type=application/octet-stream]...
# Computing MD5 for file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.resultsCovCC.tsv...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying mtime from src to dst for gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NoDups.20210804.resultsCovCC.tsv
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5_SamplesToKeep.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_25b.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25b_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.vcf [Content-Type=text/vcard]...
# Copying file://../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1.HasReplicateSamples.vcf.npz [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/replicate_concordance_a25_vs_a5_20210715.npz [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a5_20210715.npz [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/replicate_concordance_a25b_vs_a5_20210715.npz [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/replicate_concordance_a25a_vs_a25b_20210715.npz [Content-Type=application/octet-stream]...
# \ [83/175 files][ 11.1 GiB/ 16.4 GiB]  67% Done 115.4 MiB/s ETA 00:00:47

# %%
comparison_strs = ['25a_vs_25b', '25a_vs_5', '25b_vs_5', '25_vs_5']

# %%
scriptfn = 'gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R'
container = 'quay.io/dkotliar/gmmat_mkl:0.4'
ncores = 7
    
subcmdbase = '''dsub --project sabeti-ebola-gwas \
--name %s --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" \
--logging %s \
--image %s --ssh \
--input SCRIPT=%s \
--input BEDFILE=%s.bed \
--input FAMFILE=%s.fam \
--input BIMFILE=%s.bim \
--input COVFILE=%s.cov \
--input RELATFILE=%s \
--output NULLFILE=%s \
--output OUTFINAL=%s \
--env FORMULA='Batch ~ Country + LASV_Case + 1\' \
--env NCORES=7 \
--script submit.sh'''   

workingdir = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/'
dsub_cmds = []

for c in comparison_strs:
    name = '%s_CovCC_minfilt' % c
    logbase = os.path.join(workingdir, 'log', "{job-name}-{job-id}.log")    

    bedbase = workingdir + c + '.NoDups.20210804'
    relfile = bedbase + '.prune.ld_3e-1.maf_1e-1.rel.withids.tsv'

    nulloutfile = bedbase + ".nullmodelCovCC.rds"
    outfinal = bedbase + ".resultsCovCC.tsv"

    fullcmd = subcmdbase % (name,logbase,container,scriptfn, bedbase, bedbase, bedbase, bedbase, relfile, nulloutfile, outfinal) 
    dsub_cmds.append(fullcmd)

# %%
! {dsub_cmds[0]}
# Out:
# Job properties:
#   job-id: 25a-vs-25b--dkotliar--220109-004120-97
#   job-name: 25a-vs-25b-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/6253864269701721372
# Launched job-id: 25a-vs-25b--dkotliar--220109-004120-97
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-25b--dkotliar--220109-004120-97' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-25b--dkotliar--220109-004120-97' --users 'dkotliar'
# 25a-vs-25b--dkotliar--220109-004120-97

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-25b--dkotliar--220109-004120-97' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# 25a-vs-25b-c...  Success   01-09 01:42:13

# %%
! {dsub_cmds[1]}
# Out:
# Job properties:
#   job-id: 25a-vs-5-c--dkotliar--220109-191934-88
#   job-name: 25a-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/1690340037008585611
# Launched job-id: 25a-vs-5-c--dkotliar--220109-191934-88
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-5-c--dkotliar--220109-191934-88' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-5-c--dkotliar--220109-191934-88' --users 'dkotliar'
# 25a-vs-5-c--dkotliar--220109-191934-88

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25a-vs-5-c--dkotliar--220109-191934-88' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# 25a-vs-5-cov...  Success   01-09 20:29:09

# %%
! {dsub_cmds[2]}
# Out:
# Job properties:
#   job-id: 25b-vs-5-c--dkotliar--220109-191950-95
#   job-name: 25b-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/7205520904997400553
# Launched job-id: 25b-vs-5-c--dkotliar--220109-191950-95
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25b-vs-5-c--dkotliar--220109-191950-95' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '25b-vs-5-c--dkotliar--220109-191950-95' --users 'dkotliar'
# 25b-vs-5-c--dkotliar--220109-191950-95

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25b-vs-5-c--dkotliar--220109-191950-95' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# 25b-vs-5-cov...  Success   01-09 20:03:28

# %%
repcmd = dsub_cmds[-1].replace('--min-ram 8', '--min-ram 16')
print(repcmd)
# !{repcmd}
# Out:
# dsub --project sabeti-ebola-gwas --name 25_vs_5_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.resultsCovCC.tsv --env FORMULA='Batch ~ Country + LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: 25-vs-5-co--dkotliar--220109-002515-30
#   job-name: 25-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/14458855590110658169
# Launched job-id: 25-vs-5-co--dkotliar--220109-002515-30
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25-vs-5-co--dkotliar--220109-002515-30' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs '25-vs-5-co--dkotliar--220109-002515-30' --users 'dkotliar'
# 25-vs-5-co--dkotliar--220109-002515-30

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs '25-vs-5-co--dkotliar--220109-002515-30' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# 25-vs-5-covc...  Success   01-09 01:52:50

# %%
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/*.NoDups.20210804.resultsCovCC.tsv ../../data/tmp/plink/merged_pre2016/
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/*.NoDups.20210804.nullmodelCovCC.rds ../../data/tmp/plink/merged_pre2016/
# Out:
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NoDups.20210804.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NoDups.20210804.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NoDups.20210804.resultsCovCC.tsv...
# / [4/4 files][925.5 MiB/925.5 MiB] 100% Done
# Operation completed over 4 objects/925.5 MiB.
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NoDups.20210804.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NoDups.20210804.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NoDups.20210804.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NoDups.20210804.nullmodelCovCC.rds...
# \ [4/4 files][113.8 MiB/113.8 MiB] 100% Done
# Operation completed over 4 objects/113.8 MiB.

# %%
## workingdir = '../../data/tmp/plink/merged_pre2016/'
for c in comparisons:
    v = c[2]
    dupres[v]['Between_AllRep_FracConcordant'] = dupres[v]['Between_AllRep_Concordance'] / dupres[v]['Between_AllRep_Total']
    dupres[v]['Within_AllRep_FracConcordant']  = (dupres[v]['B1_AllRep_Concordance'] + dupres[v]['B2_AllRep_Concordance']) / (dupres[v]['B1_AllRep_Total'] + dupres[v]['B2_AllRep_Total'])

# %%
for c in comparisons:
    v = c[2]
    gwasfn = workingdir + v + '.NoDups.20210804.resultsCovCC.tsv'
    gwasres = pd.read_csv(gwasfn, sep='\t', nrows=5)
    print(v)
    display(gwasres)
# Out:
# 25a_vs_25b
#             SNP  CHR     POS REF ALT     N  MISSRATE        AF      SCORE  \
# 0  1:564768:T:C    1  564768   T   C  2174  0.003210  0.063477  -6.972617
# 1  1:565374:A:G    1  565374   A   G  2180  0.000459  0.000459   1.627407
# 2  1:568072:A:G    1  568072   A   G  2161  0.009170  0.393568  -7.964141
# 3  1:569342:T:C    1  569342   T   C  2114  0.030720  0.001892  -1.986208
# 4  1:723918:G:A    1  723918   G   A  2163  0.008253  0.084836  12.782399
#
#           VAR      PVAL
# 0   67.349466  0.395532
# 1    0.546531  0.027711
# 2  268.757666  0.627108
# 3    2.559729  0.214441
# 4   41.124431  0.046234
# 25a_vs_5
#             SNP  CHR     POS REF ALT     N  MISSRATE        AF     SCORE  \
# 0  1:564768:T:C    1  564768   T   C  2110  0.001420  0.067773  0.153085
# 1  1:568072:A:G    1  568072   A   G  2095  0.008519  0.416945  0.025952
# 2  1:569342:T:C    1  569342   T   C  2048  0.030762  0.001953  0.002560
# 3  1:723918:G:A    1  723918   G   A  2100  0.006152  0.085238  0.490065
# 4  1:752566:G:A    1  752566   G   A  2113  0.000000  0.311169 -0.102255
#
#          VAR      PVAL
# 0  13.084122  0.966243
# 1  48.741511  0.997034
# 2   0.000021  0.575003
# 3   7.744960  0.860220
# 4  20.665791  0.982054
# 25b_vs_5
#             SNP  CHR     POS REF ALT    N  MISSRATE        AF     SCORE  \
# 0  1:564768:T:C    1  564768   T   C  868  0.004587  0.061060  0.452520
# 1  1:565374:A:G    1  565374   A   G  872  0.000000  0.001147 -0.496260
# 2  1:568072:A:G    1  568072   A   G  868  0.004587  0.404378 -0.645667
# 3  1:723918:G:A    1  723918   G   A  863  0.010321  0.100232  0.153670
# 4  1:752566:G:A    1  752566   G   A  870  0.002294  0.318391 -0.293164
#
#          VAR      PVAL
# 0   9.689136  0.884413
# 1   0.482328  0.474882
# 2  37.597778  0.916138
# 3   6.102123  0.950397
# 4  16.616394  0.942666
# 25_vs_5
#             SNP  CHR     POS REF ALT     N  MISSRATE        AF     SCORE  \
# 0  1:564768:T:C    1  564768   T   C  2576  0.002710  0.064829  0.160296
# 1  1:565374:A:G    1  565374   A   G  2582  0.000387  0.000387 -0.054618
# 2  1:568072:A:G    1  568072   A   G  2562  0.008130  0.404957  0.001822
# 3  1:569342:T:C    1  569342   T   C  2500  0.032133  0.001600  0.001699
# 4  1:723918:G:A    1  723918   G   A  2563  0.007743  0.087593  0.372836
#
#          VAR      PVAL
# 0  11.817094  0.962808
# 1   0.096287  0.860281
# 2  44.070881  0.999781
# 3   0.000013  0.637657
# 4   7.025244  0.888134

# %%
workingdir = '../../data/tmp/plink/merged_pre2016/'
for c in comparisons:
    v = c[2]
    gwasfn = workingdir + v + '.NoDups.20210804.resultsCovCC.tsv'
    #gwasres = pd.read_csv(gwasfn, sep='\t', header=None)
    gwasres = pd.read_csv(gwasfn, sep='\t')
    #gwasres.columns = ['SNP','CHR','POS','REF','ALT','N','MISSRATE','AF','SCORE','VAR','PVAL']
    gwasres.index = gwasres['SNP']
    (fig,ax) = plt.subplots(1,1, figsize=(2,2), dpi=200)
    ax.hist(gwasres['PVAL'], bins=100)
    ax.set_title(v + ' MLMA')
    dupres[v]['MLMA_P'] = np.nan
    dupres[v]['MLMA_Q'] = np.nan
    overlap = list(set(dupres[v].index).intersection(set(gwasres.index)))
    dupres[v].loc[overlap, 'MLMA_P'] = gwasres.loc[overlap, 'PVAL'].values
    dupres[v].loc[overlap, 'MLMA_Q'] =fdrcorrection(dupres[v].loc[overlap, 'MLMA_P'], method='indep')[1]
    dupres[v].loc[overlap, 'MLMA_logP'] = -1*dupres[v].loc[overlap, 'MLMA_P'].apply(np.log10)
    dupres[v].loc[overlap, 'MLMA_logQ'] = -1*dupres[v].loc[overlap, 'MLMA_Q'].apply(np.log10)

# %%
s=1
for c in comparisons:
    v = c[2]
    x = dupres[v].loc[:, 'MLMA_logP']
    y = dupres[v].loc[:, 'Between_AllRep_FracConcordant']
    ind = ~x.isnull()
    iswithindisc = (dupres[v].loc[:, 'Within_AllRep_FracConcordant']>0.1)
    (fig,ax) = plt.subplots(1,1, figsize=(3,3), dpi=200)
    ax.scatter(x.loc[ind & ~iswithindisc], y.loc[ind & ~iswithindisc], s=s, color='b', label='Not within discordant')
    ax.scatter(x.loc[ind & iswithindisc], y.loc[ind & iswithindisc], s=s, color='r', label='Within discordant')
    ax.legend(loc='upper left', markerscale=2, fontsize=7, bbox_to_anchor=(1,1))
    ax.set_xlabel('-Log10 AF Association P', fontsize=7)
    ax.set_ylabel('Between batch fraction discordant', fontsize=7)
    ax.set_title(v+ ' - MLMA - All replicates', fontsize=7)

# %%
logp_thresh = -1*np.log10(5*(10**-8))
discthresh = .1
for c in comparisons:
    v = c[2]
    x = dupres[v].loc[:, 'MLMA_logP']
    y = dupres[v].loc[:, 'Between_AllRep_FracConcordant']
    print(v)
    display(pd.crosstab(x>logp_thresh, y>discthresh))
# Out:
# 25a_vs_25b
# Between_AllRep_FracConcordant    False  True
# MLMA_logP
# False                          2306201    444
# True                              1971    382
# 25a_vs_5
# Between_AllRep_FracConcordant    False  True
# MLMA_logP
# False                          2295758   3419
# True                                 0   9821
# 25b_vs_5
# Between_AllRep_FracConcordant    False
# MLMA_logP
# False                          2298938
# True                             10060
# 25_vs_5
# Between_AllRep_FracConcordant    False  True
# MLMA_logP
# False                          2295757   3679
# True                                 1   9561

# %% [markdown]
# ## Repeat analysis for 25A vs 25B but for NG and SL separately

# %%
workingdir = '../../data/tmp/plink/merged_pre2016/'
dsub_cmds = []

for country in ['NG', 'SL']:
    country_samps = phenoinfo.loc[phenoinfo['Country']==country, 'Full_IID']
    for c in comparisons:
        if (country == 'SL') and (c[2] != '25a_vs_25b'):
            continue
         
        keep_list_fn = workingdir + c[2] + '.' + country + '.SamplesToKeep.tsv'
        #print(keep_list_fn)
        outbase = workingdir + c[2] + '.' + country + '.NoDups.20210805'
        merged_keep_list = pd.concat([c[0], c[1]], axis=0)
        merged_keep_list = merged_keep_list.loc[merged_keep_list[1].isin(country_samps), :]        
        dupstofilt = list(preprereps.loc[preprereps['IID']!=preprereps['Duplicate_To_Use'], 'IID'])
        merged_keep_list = merged_keep_list.loc[~merged_keep_list[1].isin(dupstofilt), :]
        merged_keep_list.iloc[:,:2].to_csv(keep_list_fn, sep='\t', index=False, header=False)
        cmd = 'plink --make-bed --bfile {a} --keep {keepfn} --keep-allele-order --out {out}'.format(a=fullbase, keepfn=keep_list_fn, out=outbase)
        print(cmd)
        # !{cmd}
        
        fam = pd.read_csv(outbase+'.fam', sep=' ', header=None)
        fam.loc[fam[1].isin(c[1][1]),5] = 1
        fam.loc[fam[1].isin(c[0][1]),5] = 0
        print(fam[5].value_counts())
        fam.to_csv(outbase+'.fam', sep=' ', header=False, index=False)    

        print(c[2])
        fam_fordisplay = fam.copy()
        fam_fordisplay['Country'] = phenoinfo.loc[fam_fordisplay[1], 'Country'].values
        display(pd.crosstab(fam_fordisplay[5].replace(np.nan, -1), fam_fordisplay['Country'].replace(np.nan, 'null')))
        
        #produce a pruned subset of markers that are in approximate linkage equilibrium with each other
        prunefn = outbase + '.prune.ld_3e-1.maf_1e-1'
        prune_cmd = 'plink --bfile {adat} --out {adatout} --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1'.format(adat=outbase, adatout=prunefn)
        print(prune_cmd)
        # !{prune_cmd}

        #do PCA
        pca_cmd = 'plink --bfile {adat} --out {adatout} --pca 20 --extract {adatout}.prune.in'.format(adat=outbase, adatout=prunefn)
        print(pca_cmd)
        # !{pca_cmd}

        #make square relationship matrix 
        relfn = outbase + '.prune.ld_3e-1.maf_1e-1'
        rel_cmd = 'plink --make-rel square --bfile {adat} --out {adatout} --extract {prune}.prune.in'.format(adat=outbase, adatout=relfn, prune=prunefn)
        print(rel_cmd)
        # !{rel_cmd}
        
        #excludes one member of each pair of samples with observed genomic relatedness greater than the given cutoff value
        #unrelatedsfn = outbase + 'unrelated.individuals.5e-2.txt'
        #get_unrelateds_cmd = 'plink --rel-cutoff 0.05 --grm-bin {rel} --out {out}'.format(rel=relfn, out=unrelatedsfn)
        #print(get_unrelateds_cmd)
        #!{get_unrelateds_cmd}

        relid = pd.read_csv(relfn+'.rel.id', header=None, sep ='\t')[1].iloc[0:]
        rel = pd.read_csv(relfn+'.rel', header=None, sep='\t')
        rel.index = relid
        rel.columns = relid
        rel.to_csv(relfn+'.rel.withids.tsv', sep='\t')  
        
        
        phenofn = outbase + '.cov'
        cov = pd.read_csv(outbase+'.fam', sep=' ', header=None)
        cov = cov[[0,1,5]]
        cov.columns = ['FID', 'IID', 'Batch']
        cov.index = cov['IID']
        
        cov['Country'] = phenoinfo.loc[cov['IID'], 'Country'].replace({'NG':'0', 'SL':'1'}).replace(np.nan, '-9').values
        #cov['Batch'] = phenoinfo.loc[cov['IID'], 'Array'].replace({'Omni_25M_B':0, 'Omni_25M_A':0, 'Omni_5M':0, 'H3':1}).values
        cov['LASV_Case'] = phenoinfo.loc[cov['IID'], 'LASV_Case'].replace(np.nan, 0).values    
    
        print(cov['Batch'].value_counts())
        print(cov['Country'].value_counts())    
        cov.to_csv(phenofn, sep='\t', index=False)
# Out:
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 1055 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 898 founders and 157 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 513161 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995314.
# 2308998 variants and 1055 people pass filters and QC.
# Among remaining phenotypes, 145 are cases and 182 are controls.  (728
# phenotypes are missing.)
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bed +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bim +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    931
# 1    124
# Name: 5, dtype: int64
# 25a_vs_25b
# Country   NG
# 5
# 0        931
# 1        124
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1055 people (496 males, 559 females) loaded from .fam.
# 124 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 898 founders and 157 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 513161 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995314.
# 5659 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 7 variants removed due to Hardy-Weinberg exact test.
# 1191142 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1112190 variants and 1055 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 124 are controls.  (931 phenotypes
# are missing.)
# Pruned 58517 variants from chromosome 1, leaving 25556.
# Pruned 64127 variants from chromosome 2, leaving 26314.
# Pruned 54122 variants from chromosome 3, leaving 22241.
# Pruned 50328 variants from chromosome 4, leaving 21155.
# Pruned 46754 variants from chromosome 5, leaving 20256.
# Pruned 52082 variants from chromosome 6, leaving 19216.
# Pruned 42093 variants from chromosome 7, leaving 18101.
# Pruned 41654 variants from chromosome 8, leaving 17529.
# Pruned 34086 variants from chromosome 9, leaving 15149.
# Pruned 39063 variants from chromosome 10, leaving 16615.
# Pruned 37961 variants from chromosome 11, leaving 15708.
# Pruned 36031 variants from chromosome 12, leaving 15849.
# Pruned 27523 variants from chromosome 13, leaving 12196.
# Pruned 24895 variants from chromosome 14, leaving 11018.
# Pruned 23323 variants from chromosome 15, leaving 11537.
# Pruned 24605 variants from chromosome 16, leaving 12249.
# Pruned 20261 variants from chromosome 17, leaving 10920.
# Pruned 22422 variants from chromosome 18, leaving 11175.
# Pruned 14446 variants from chromosome 19, leaving 8091.
# Pruned 18228 variants from chromosome 20, leaving 9404.
# Pruned 10492 variants from chromosome 21, leaving 5398.
# Pruned 10833 variants from chromosome 22, leaving 5664.
# Pruned 18014 variants from chromosome 23, leaving 8806.
# Pruned 174 variants from chromosome 24, leaving 9.
# Pruning complete.  772034 of 1112190 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1055 people (496 males, 559 females) loaded from .fam.
# 124 phenotype values loaded from .fam.
# --extract: 340156 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 898 founders and 157 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 137485 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994365.
# 340156 variants and 1055 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 124 are controls.  (931 phenotypes
# are missing.)
# Excluding 8815 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1055 people (496 males, 559 females) loaded from .fam.
# 124 phenotype values loaded from .fam.
# --extract: 340156 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 898 founders and 157 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 137485 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994365.
# 340156 variants and 1055 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 124 are controls.  (931 phenotypes
# are missing.)
# Excluding 8815 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    931
# 1    124
# Name: Batch, dtype: int64
# 0    1055
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 1333 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1153 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 618828 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995834.
# 2308998 variants and 1333 people pass filters and QC.
# Among remaining phenotypes, 145 are cases and 182 are controls.  (1006
# phenotypes are missing.)
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bed +
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bim +
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    931
# 1    402
# Name: 5, dtype: int64
# 25a_vs_5
# Country   NG
# 5
# 0        931
# 1        402
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1333 people (598 males, 735 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1153 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 618828 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995834.
# 2542 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 192 variants removed due to Hardy-Weinberg exact test.
# 1186452 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1119812 variants and 1333 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (931 phenotypes
# are missing.)
# Pruned 58682 variants from chromosome 1, leaving 25988.
# Pruned 64218 variants from chromosome 2, leaving 26781.
# Pruned 54272 variants from chromosome 3, leaving 22614.
# Pruned 50353 variants from chromosome 4, leaving 21620.
# Pruned 46791 variants from chromosome 5, leaving 20647.
# Pruned 52209 variants from chromosome 6, leaving 19533.
# Pruned 42096 variants from chromosome 7, leaving 18388.
# Pruned 41756 variants from chromosome 8, leaving 17829.
# Pruned 34115 variants from chromosome 9, leaving 15411.
# Pruned 39151 variants from chromosome 10, leaving 16910.
# Pruned 38064 variants from chromosome 11, leaving 15954.
# Pruned 36108 variants from chromosome 12, leaving 16064.
# Pruned 27652 variants from chromosome 13, leaving 12396.
# Pruned 24960 variants from chromosome 14, leaving 11234.
# Pruned 23410 variants from chromosome 15, leaving 11710.
# Pruned 24732 variants from chromosome 16, leaving 12415.
# Pruned 20405 variants from chromosome 17, leaving 11024.
# Pruned 22466 variants from chromosome 18, leaving 11297.
# Pruned 14511 variants from chromosome 19, leaving 8213.
# Pruned 18299 variants from chromosome 20, leaving 9488.
# Pruned 10555 variants from chromosome 21, leaving 5472.
# Pruned 10835 variants from chromosome 22, leaving 5778.
# Pruned 18246 variants from chromosome 23, leaving 8987.
# Pruned 163 variants from chromosome 24, leaving 10.
# Pruning complete.  774049 of 1119812 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1333 people (598 males, 735 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 345763 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1153 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 169570 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994817.
# 345763 variants and 1333 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (931 phenotypes
# are missing.)
# Excluding 8997 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1333 people (598 males, 735 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 345763 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1153 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 169570 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994817.
# 345763 variants and 1333 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (931 phenotypes
# are missing.)
# Excluding 8997 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    931
# 1    402
# Name: Batch, dtype: int64
# 0    1333
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 526 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 503 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 205305 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.997192.
# 2308998 variants and 526 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bed +
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bim +
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 1    402
# 0    124
# Name: 5, dtype: int64
# 25b_vs_5
# Country   NG
# 5
# 0        124
# 1        402
# plink --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 526 people (200 males, 326 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 503 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 205305 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.997192.
# 2365 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 186 variants removed due to Hardy-Weinberg exact test.
# 1187180 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1119267 variants and 526 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (124 phenotypes
# are missing.)
# Pruned 58787 variants from chromosome 1, leaving 25878.
# Pruned 64181 variants from chromosome 2, leaving 26723.
# Pruned 54358 variants from chromosome 3, leaving 22540.
# Pruned 50414 variants from chromosome 4, leaving 21428.
# Pruned 47028 variants from chromosome 5, leaving 20502.
# Pruned 52316 variants from chromosome 6, leaving 19399.
# Pruned 42277 variants from chromosome 7, leaving 18232.
# Pruned 41775 variants from chromosome 8, leaving 17765.
# Pruned 34237 variants from chromosome 9, leaving 15328.
# Pruned 39175 variants from chromosome 10, leaving 16872.
# Pruned 38012 variants from chromosome 11, leaving 15855.
# Pruned 36178 variants from chromosome 12, leaving 16008.
# Pruned 27733 variants from chromosome 13, leaving 12326.
# Pruned 25011 variants from chromosome 14, leaving 11194.
# Pruned 23441 variants from chromosome 15, leaving 11631.
# Pruned 24746 variants from chromosome 16, leaving 12358.
# Pruned 20374 variants from chromosome 17, leaving 10975.
# Pruned 22426 variants from chromosome 18, leaving 11259.
# Pruned 14583 variants from chromosome 19, leaving 8123.
# Pruned 18272 variants from chromosome 20, leaving 9475.
# Pruned 10498 variants from chromosome 21, leaving 5485.
# Pruned 10833 variants from chromosome 22, leaving 5772.
# Pruned 18292 variants from chromosome 23, leaving 9021.
# Pruned 162 variants from chromosome 24, leaving 9.
# Pruning complete.  775109 of 1119267 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 526 people (200 males, 326 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 344158 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 503 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 57859 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.996553.
# 344158 variants and 526 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (124 phenotypes
# are missing.)
# Excluding 9030 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 526 people (200 males, 326 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 344158 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 503 founders and 23 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 57859 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.996553.
# 344158 variants and 526 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (124 phenotypes
# are missing.)
# Excluding 9030 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 1    402
# 0    124
# Name: Batch, dtype: int64
# 0    526
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 1457 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1277 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 668647 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995891.
# 2308998 variants and 1457 people pass filters and QC.
# Among remaining phenotypes, 145 are cases and 182 are controls.  (1130
# phenotypes are missing.)
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bed +
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bim +
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    1055
# 1     402
# Name: 5, dtype: int64
# 25_vs_5
# Country    NG
# 5
# 0        1055
# 1         402
# plink --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1457 people (647 males, 810 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1277 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 668647 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995891.
# 1829 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 193 variants removed due to Hardy-Weinberg exact test.
# 1186795 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1120181 variants and 1457 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1055 phenotypes
# are missing.)
# Pruned 58688 variants from chromosome 1, leaving 26026.
# Pruned 64200 variants from chromosome 2, leaving 26802.
# Pruned 54277 variants from chromosome 3, leaving 22633.
# Pruned 50298 variants from chromosome 4, leaving 21650.
# Pruned 46814 variants from chromosome 5, leaving 20675.
# Pruned 52215 variants from chromosome 6, leaving 19571.
# Pruned 42133 variants from chromosome 7, leaving 18372.
# Pruned 41736 variants from chromosome 8, leaving 17871.
# Pruned 34143 variants from chromosome 9, leaving 15419.
# Pruned 39167 variants from chromosome 10, leaving 16920.
# Pruned 38044 variants from chromosome 11, leaving 15976.
# Pruned 36134 variants from chromosome 12, leaving 16069.
# Pruned 27647 variants from chromosome 13, leaving 12427.
# Pruned 24971 variants from chromosome 14, leaving 11253.
# Pruned 23405 variants from chromosome 15, leaving 11722.
# Pruned 24693 variants from chromosome 16, leaving 12466.
# Pruned 20411 variants from chromosome 17, leaving 11036.
# Pruned 22457 variants from chromosome 18, leaving 11305.
# Pruned 14536 variants from chromosome 19, leaving 8208.
# Pruned 18268 variants from chromosome 20, leaving 9505.
# Pruned 10540 variants from chromosome 21, leaving 5470.
# Pruned 10850 variants from chromosome 22, leaving 5771.
# Pruned 18238 variants from chromosome 23, leaving 9002.
# Pruned 156 variants from chromosome 24, leaving 11.
# Pruning complete.  774021 of 1120181 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1457 people (647 males, 810 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 346160 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1277 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 184738 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99485.
# 346160 variants and 1457 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1055 phenotypes
# are missing.)
# Excluding 9013 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1457 people (647 males, 810 females) loaded from .fam.
# 402 phenotype values loaded from .fam.
# --extract: 346160 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1277 founders and 180 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 184738 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.99485.
# 346160 variants and 1457 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 402 are controls.  (1055 phenotypes
# are missing.)
# Excluding 9013 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    1055
# 1     402
# Name: Batch, dtype: int64
# 0    1457
# Name: Country, dtype: int64
# plink --make-bed --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1 --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.SamplesToKeep.tsv --keep-allele-order --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/HumanOmni25Mand5M.HasCoord.RefAllele.NoMulti.NoSexDisc.mDupVars.Geno_1e-1
#   --keep ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.SamplesToKeep.tsv
#   --keep-allele-order
#   --make-bed
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 2780 people (1181 males, 1599 females) loaded from .fam.
# 452 phenotype values loaded from .fam.
# --keep: 1126 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1058 founders and 68 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 446315 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.hh ); many
# commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate in remaining samples is 0.995922.
# 2308998 variants and 1126 people pass filters and QC.
# Among remaining phenotypes, 52 are cases and 0 are controls.  (1074 phenotypes
# are missing.)
# --make-bed to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bed +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bim +
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# 0    780
# 1    346
# Name: 5, dtype: int64
# 25a_vs_25b
# Country   SL
# 5
# 0        780
# 1        346
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --indep-pairwise 1000kb 1 .3 --maf .1 --hwe 1e-12 --geno .1
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805
#   --geno .1
#   --hwe 1e-12
#   --indep-pairwise 1000kb 1 .3
#   --maf .1
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1126 people (459 males, 667 females) loaded from .fam.
# 346 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1058 founders and 68 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 446315 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.995922.
# 1906 variants removed due to missing genotype data (--geno).
# Warning: --hwe observation counts vary by more than 10%.  Consider using
# --geno, and/or applying different p-value thresholds to distinct subsets of
# your data.
# --hwe: 153 variants removed due to Hardy-Weinberg exact test.
# 1190316 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 1116623 variants and 1126 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 346 are controls.  (780 phenotypes
# are missing.)
# Pruned 56938 variants from chromosome 1, leaving 27388.
# Pruned 62417 variants from chromosome 2, leaving 28110.
# Pruned 52539 variants from chromosome 3, leaving 23970.
# Pruned 49313 variants from chromosome 4, leaving 22372.
# Pruned 45845 variants from chromosome 5, leaving 21463.
# Pruned 50826 variants from chromosome 6, leaving 20581.
# Pruned 40986 variants from chromosome 7, leaving 19454.
# Pruned 40589 variants from chromosome 8, leaving 18911.
# Pruned 32979 variants from chromosome 9, leaving 16376.
# Pruned 38149 variants from chromosome 10, leaving 17838.
# Pruned 36925 variants from chromosome 11, leaving 16910.
# Pruned 35091 variants from chromosome 12, leaving 16966.
# Pruned 26980 variants from chromosome 13, leaving 12922.
# Pruned 24330 variants from chromosome 14, leaving 11929.
# Pruned 22677 variants from chromosome 15, leaving 12284.
# Pruned 24015 variants from chromosome 16, leaving 12979.
# Pruned 19900 variants from chromosome 17, leaving 11467.
# Pruned 21972 variants from chromosome 18, leaving 11774.
# Pruned 14201 variants from chromosome 19, leaving 8537.
# Pruned 17812 variants from chromosome 20, leaving 9832.
# Pruned 10285 variants from chromosome 21, leaving 5725.
# Pruned 10502 variants from chromosome 22, leaving 6179.
# Pruned 17955 variants from chromosome 23, leaving 9342.
# Pruned 58 variants from chromosome 24, leaving 30.
# Pruning complete.  753284 of 1116623 variants removed.
# Marker lists written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out
# .
# plink --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --pca 20 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#   --pca 20
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1126 people (459 males, 667 females) loaded from .fam.
# 346 phenotype values loaded from .fam.
# --extract: 363339 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1058 founders and 68 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 141511 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994779.
# 363339 variants and 1126 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 346 are controls.  (780 phenotypes
# are missing.)
# Excluding 9372 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# --pca: Results saved to and eigenvectors]
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval
# and
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec
# .
# plink --make-rel square --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805 --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1 --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
# PLINK v1.90b4 64-bit (20 Mar 2017)             www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log.
# Options in effect:
#   --bfile ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805
#   --extract ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in
#   --make-rel square
#   --out ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1
#
# 32167 MB RAM detected; reserving 16083 MB for main workspace.
# Allocated 9046 MB successfully, after larger attempt(s) failed.
# 2308998 variants loaded from .bim file.
# 1126 people (459 males, 667 females) loaded from .fam.
# 346 phenotype values loaded from .fam.
# --extract: 363339 variants remaining.
# Using up to 8 threads (change this with --threads).
# Before main variant filters, 1058 founders and 68 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Warning: 141511 het. haploid genotypes present (see
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh
# ); many commands treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Total genotyping rate is 0.994779.
# 363339 variants and 1126 people pass filters and QC.
# Among remaining phenotypes, 0 are cases and 346 are controls.  (780 phenotypes
# are missing.)
# Excluding 9372 variants on non-autosomes from relationship matrix calc.
# Relationship matrix calculation complete.
# Relationship matrix written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel
# , and IDs written to
# ../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id
# .
# 0    780
# 1    346
# Name: Batch, dtype: int64
# 1    1126
# Name: Country, dtype: int64

# %%
! gsutil -m cp ../../data/tmp/plink/merged_pre2016/*.NoDups.20210805.* gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/
# Out:
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.log [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25a_vs_5.NG.NoDups.20210805.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bed [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bim [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.cov [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.fam [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenval [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.eigenvec [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.hh [Content-Type=text/x-c++hdr]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.log [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.in [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.prune.out [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.id [Content-Type=application/octet-stream]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv [Content-Type=text/tab-separated-values]...
# Copying file://../../data/tmp/plink/merged_pre2016/25b_vs_5.NG.NoDups.20210805.resultsCovCC.tsv [Content-Type=text/tab-separated-values]...
# - [85/85 files][  4.8 GiB/  4.8 GiB] 100% Done 242.4 MiB/s ETA 00:00:00
# Operation completed over 85 objects/4.8 GiB.

# %%
comparison_strs = ['25a_vs_25b', '25a_vs_5', '25b_vs_5', '25_vs_5']

# %%
scriptfn = 'gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R'
container = 'quay.io/dkotliar/gmmat_mkl:0.4'
ncores = 7
    
subcmdbase = '''dsub --project sabeti-ebola-gwas \
--name %s --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" \
--logging %s \
--image %s --ssh \
--input SCRIPT=%s \
--input BEDFILE=%s.bed \
--input FAMFILE=%s.fam \
--input BIMFILE=%s.bim \
--input COVFILE=%s.cov \
--input RELATFILE=%s \
--output NULLFILE=%s \
--output OUTFINAL=%s \
--env FORMULA='Batch ~ LASV_Case + 1\' \
--env NCORES=7 \
--script submit.sh'''   

workingdir = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/'
dsub_cmds = []

for country in ['NG', 'SL']:
    for c in comparison_strs:
        if (country == 'SL') and (c != '25a_vs_25b'):
            continue
        name = '%s_%s_CovCC_minfilt' % (country, c)
        logbase = os.path.join(workingdir, 'log', "{job-name}-{job-id}.log")    

        bedbase = workingdir + c + '.' + country + '.NoDups.20210805'
        prunefn = bedbase + '.prune.ld_3e-1.maf_1e-1'
        relfile = bedbase + '.prune.ld_3e-1.maf_1e-1.rel.withids.tsv'

        nulloutfile = bedbase + ".nullmodelCovCC.rds"
        outfinal = bedbase + ".resultsCovCC.tsv"

        fullcmd = subcmdbase % (name,logbase,container,scriptfn, bedbase, bedbase, bedbase, bedbase, relfile, nulloutfile, outfinal)        
        dsub_cmds.append(fullcmd)

# %%
for cmd in dsub_cmds:
    print(cmd)
    # !{cmd}
# Out:
# dsub --project sabeti-ebola-gwas --name NG_25a_vs_25b_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: ng-25a-vs---dkotliar--220109-212309-36
#   job-name: ng-25a-vs-25b-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/12677239993662440046
# Launched job-id: ng-25a-vs---dkotliar--220109-212309-36
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212309-36' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212309-36' --users 'dkotliar'
# ng-25a-vs---dkotliar--220109-212309-36
# dsub --project sabeti-ebola-gwas --name NG_25a_vs_5_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: ng-25a-vs---dkotliar--220109-212310-61
#   job-name: ng-25a-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/9456984292965770289
# Launched job-id: ng-25a-vs---dkotliar--220109-212310-61
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212310-61' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212310-61' --users 'dkotliar'
# ng-25a-vs---dkotliar--220109-212310-61
# dsub --project sabeti-ebola-gwas --name NG_25b_vs_5_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: ng-25b-vs---dkotliar--220109-212311-84
#   job-name: ng-25b-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/17825940406275418251
# Launched job-id: ng-25b-vs---dkotliar--220109-212311-84
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25b-vs---dkotliar--220109-212311-84' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25b-vs---dkotliar--220109-212311-84' --users 'dkotliar'
# ng-25b-vs---dkotliar--220109-212311-84
# dsub --project sabeti-ebola-gwas --name NG_25_vs_5_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: ng-25-vs-5--dkotliar--220109-212313-37
#   job-name: ng-25-vs-5-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/18147368443860812757
# Launched job-id: ng-25-vs-5--dkotliar--220109-212313-37
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25-vs-5--dkotliar--220109-212313-37' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25-vs-5--dkotliar--220109-212313-37' --users 'dkotliar'
# ng-25-vs-5--dkotliar--220109-212313-37
# dsub --project sabeti-ebola-gwas --name SL_25a_vs_25b_CovCC_minfilt --provider google-v2 --min-ram 16 --min-cores 8 --boot-disk-size 600 --disk-size 1000 --zones "us-east1-b" --logging gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/log/{job-name}-{job-id}.log --image quay.io/dkotliar/gmmat_mkl:0.4 --ssh --input SCRIPT=gs://ebola-gwas-lbr/Code/run_GMMAT_fromPLINK_parallel.R --input BEDFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bed --input FAMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.fam --input BIMFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.bim --input COVFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.cov --input RELATFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.prune.ld_3e-1.maf_1e-1.rel.withids.tsv --output NULLFILE=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.nullmodelCovCC.rds --output OUTFINAL=gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.resultsCovCC.tsv --env FORMULA='Batch ~ LASV_Case + 1' --env NCORES=7 --script submit.sh
# Job properties:
#   job-id: sl-25a-vs---dkotliar--220109-212314-57
#   job-name: sl-25a-vs-25b-covcc-minfilt
#   user-id: dkotliar
# Provider internal-id (operation): projects/sabeti-ebola-gwas/operations/9855273656005517660
# Launched job-id: sl-25a-vs---dkotliar--220109-212314-57
# To check the status, run:
#   dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'sl-25a-vs---dkotliar--220109-212314-57' --users 'dkotliar' --status '*'
# To cancel the job, run:
#   ddel --provider google-v2 --project sabeti-ebola-gwas --jobs 'sl-25a-vs---dkotliar--220109-212314-57' --users 'dkotliar'
# sl-25a-vs---dkotliar--220109-212314-57

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212309-36' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# ng-25a-vs-25...  Success   01-09 22:09:24

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25a-vs---dkotliar--220109-212310-61' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# ng-25a-vs-5-...  Success   01-09 22:11:11

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25b-vs---dkotliar--220109-212311-84' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# ng-25b-vs-5-...  Success   01-09 22:03:07

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'ng-25-vs-5--dkotliar--220109-212313-37' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# ng-25-vs-5-c...  Success   01-09 22:13:04

# %%
! dstat --provider google-v2 --project sabeti-ebola-gwas --jobs 'sl-25a-vs---dkotliar--220109-212314-57' --users 'dkotliar' --status '*'
# Out:
# Job Name         Status    Last Update
# ---------------  --------  --------------
# sl-25a-vs-25...  Success   01-09 22:09:11

# %%
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/*.NoDups.20210805.resultsCovCC.tsv ../../data/tmp/plink/merged_pre2016/
! gsutil -m cp gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/*.NoDups.20210805.nullmodelCovCC.rds ../../data/tmp/plink/merged_pre2016/
# Out:
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.resultsCovCC.tsv...
# - [5/5 files][  1.1 GiB/  1.1 GiB] 100% Done 112.0 MiB/s ETA 00:00:00
# Operation completed over 5 objects/1.1 GiB.
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.NG.NoDups.20210805.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_25b.SL.NoDups.20210805.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25a_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds...
# Copying gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/merged_pre2016/25b_vs_5.NG.NoDups.20210805.nullmodelCovCC.rds...
# / [5/5 files][ 47.9 MiB/ 47.9 MiB] 100% Done
# Operation completed over 5 objects/47.9 MiB.

# %%
percountry_res = {}
for country in ['NG', 'SL']:
    percountry_res[country] = {}
    for c in comparison_strs:
        if (country == 'SL') and (c != '25a_vs_25b'):
            continue
        fn = '../../data/tmp/plink/merged_pre2016/{comp}.{country}.NoDups.20210805.resultsCovCC.tsv'.format(comp=c, country=country)
        percountry_res[country][c] = pd.read_csv(fn, sep='\t')
        percountry_res[country][c]['logP'] = -1*percountry_res[country][c]['PVAL'].apply(np.log10)
        (fig,ax) = plt.subplots(1,1, figsize=(3,3), dpi=200)
        _ = ax.hist(percountry_res[country][c]['PVAL'], bins=100)
        ax.set_title(country + ' ' + c)

# %%
for country in ['NG', 'SL']:
    for (i,c) in enumerate(comparison_strs):
        if (country == 'SL') and (c != '25a_vs_25b'):
            continue
        (fig,axes) = plt.subplots(1,1, figsize=(2,2), dpi=200)
        percountry_res[country][c].index = percountry_res[country][c]['SNP']
        x = dupres[c][['MLMA_P', 'MLMA_logP']]
        y = percountry_res[country][c][['PVAL', 'logP']]
        m = pd.merge(left=x, right=y, left_index=True, right_index=True).dropna()
        print(c, country)
        display(pd.crosstab(m['MLMA_P']<5e-8, m['PVAL']<5e-8))
        ind = (m['MLMA_logP']>1) | (m['logP']>1)
        axes.scatter(m.loc[ind, 'MLMA_logP'], m.loc[ind, 'logP'], s=1)
        axes.set_title(country + ' ' +c)
# Out:
# 25a_vs_25b NG
# PVAL      False  True
# MLMA_P
# False   1950413     38
# True       1618    574
# 25a_vs_5 NG
# PVAL      False  True
# MLMA_P
# False   1949996    442
# True          0   9821
# 25b_vs_5 NG
# PVAL      False  True
# MLMA_P
# False   1930536      0
# True        387   9660
# 25_vs_5 NG
# PVAL      False  True
# MLMA_P
# False   1954634    636
# True          0   9561
# 25a_vs_25b SL
# PVAL      False  True
# MLMA_P
# False   2001316     54
# True        791   1555

# %%
for c in comparison_strs:
    for country in ['NG', 'SL']:
        
        if (country == 'SL') & (c != '25a_vs_25b'):
            continue        
            
        v = 'MLMA_%s_P' % country
        dupres[c][v] = np.nan
        ind = percountry_res[country][c].index
        dupres[c].loc[ind, v] = percountry_res[country][c].loc[ind, 'PVAL']
                
        ind = ~dupres[c][v].isnull()
        p = dupres[c].loc[ind, v].values
        (r,q) = fdrcorrection(p)  
        v2 = v.replace('_P', '_Q')
        dupres[c].loc[:,v2] = np.nan
        dupres[c].loc[ind,v2] = q

# %%
p_thresh = 1e-4
q_thresh = .5
for c in comparison_strs:
    x = dupres[c].shape[0]*p_thresh
    y = (dupres[c]['MLMA_P']< p_thresh).sum()
    z = (dupres[c]['MLMA_Q']< q_thresh).sum()
    w = (dupres[c]['MLMA_NG_P']< p_thresh).sum()
    t =  (dupres[c]['MLMA_NG_Q']< q_thresh).sum()
    if (c == '25a_vs_25b'):
        a = (dupres[c]['MLMA_SL_P']< p_thresh).sum()
        b =  (dupres[c]['MLMA_SL_Q']< q_thresh).sum()
        print(c, x, y, z, w, t, a, b)
    else:
        print(c, x, y, z, w, t)
# Out:
# 25a_vs_25b 230.8998 4278 11270 1918 4876 3324 8275
# 25a_vs_5 230.8998 10779 11346 11098 11591
# 25b_vs_5 230.8998 11023 11654 10694 11303
# 25_vs_5 230.8998 10577 11175 11031 11544

# %%
c = '25_vs_5'
resx = []
for t in np.linspace(0, 1, 100):
    n = (dupres[c]['MLMA_Q']<t).sum()
    fp = n*t
    tp = n - fp
    resx.append([t, n,fp, tp])
    
resx = pd.DataFrame(resx)

plt.plot(resx[0], resx[3], label='True positives')
plt.plot(resx[0], resx[2], label='False positives')
plt.plot(resx[0], resx[1], label='Total')

plt.xlim([0,.4])
plt.ylim([0,12000])
plt.legend()
plt.ylabel('# Called significant')
plt.xlabel('q-value threshold')
# Out:
# Text(0.5, 0, 'q-value threshold')

# %%
c = '25a_vs_25b'
resx = []
for t in np.linspace(0, 1, 100):
    n = (dupres[c]['MLMA_Q']<t).sum()
    fp = n*t
    tp = n - fp
    resx.append([t, n,fp, tp])
    
resx = pd.DataFrame(resx)

plt.plot(resx[0], resx[3], label='True positives')
plt.plot(resx[0], resx[2], label='False positives')
plt.plot(resx[0], resx[1], label='Total')

plt.xlim([0,.4])
plt.ylim([0,5000])
plt.legend()
plt.ylabel('# Called significant')
plt.xlabel('q-value threshold')
# Out:
# Text(0.5, 0, 'q-value threshold')

# %% [markdown]
# ## Output batch-effected variants to filter and filter

# %%
q_thresh = .25
discthresh = .1
allfilterlist = set()

for c in comparison_strs:
    tofilterlist = set()
    tofilterlist = tofilterlist.union(set(dupres[c].index[dupres[c]['Between_AllRep_FracConcordant']>discthresh]))
    tofilterlist = tofilterlist.union(set(dupres[c].index[dupres[c]['MLMA_Q']<q_thresh]))
    tofilterlist = tofilterlist.union(set(dupres[c].index[dupres[c]['MLMA_NG_Q']<q_thresh]))

    
    print(c, 'replicates', len(dupres[c].index[dupres[c]['Between_AllRep_FracConcordant']>discthresh]))
    print(c, 'combined AF', len(dupres[c].index[dupres[c]['MLMA_Q']<q_thresh]))
    print(c, 'NG AF', len(dupres[c].index[dupres[c]['MLMA_NG_Q']<q_thresh]))
    if c == '25a_vs_25b':
        print(c, 'SL AF', len(dupres[c].index[dupres[c]['MLMA_SL_Q']<q_thresh]))
        tofilterlist = tofilterlist.union(set(dupres[c].index[dupres[c]['MLMA_SL_Q']<q_thresh]))
        
    print(c, len(tofilterlist))
    allfilterlist = allfilterlist.union(tofilterlist)
    dupres[c]['Filtered'] = dupres[c].index.isin(tofilterlist)
    print(len(allfilterlist))
    print('\n\n')
# Out:
# 25a_vs_25b replicates 826
# 25a_vs_25b combined AF 6636
# 25a_vs_25b NG AF 2884
# 25a_vs_25b SL AF 4972
# 25a_vs_25b 8814
# 8814
#
#
#
# 25a_vs_5 replicates 13240
# 25a_vs_5 combined AF 11208
# 25a_vs_5 NG AF 11492
# 25a_vs_5 13250
# 22019
#
#
#
# 25b_vs_5 replicates 0
# 25b_vs_5 combined AF 11491
# 25b_vs_5 NG AF 11153
# 25b_vs_5 11492
# 22099
#
#
#
# 25_vs_5 replicates 13240
# 25_vs_5 combined AF 11033
# 25_vs_5 NG AF 11442
# 25_vs_5 13246
# 22101

# %%
print(comparison_strs)
for v in comparison_strs:
    local = '../../data/tmp/plink/merged_pre2016/BroadPre2016.%s.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv' % v
    dupres[v].to_csv(local, sep='\t')
    remote = 'gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/'
    cmd = 'gsutil -m cp {local} {remote}'.format(local=local, remote=remote)
    print(cmd)
    # !{cmd}
# Out:
# ['25a_vs_25b', '25a_vs_5', '25b_vs_5', '25_vs_5']
# gsutil -m cp ../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_25b.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_25b.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# / [1/1 files][473.6 MiB/473.6 MiB] 100% Done
# Operation completed over 1 objects/473.6 MiB.
# gsutil -m cp ../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25a_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# \ [1/1 files][404.1 MiB/404.1 MiB] 100% Done
# Operation completed over 1 objects/404.1 MiB.
# gsutil -m cp ../../data/tmp/plink/merged_pre2016/BroadPre2016.25b_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25b_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# \ [1/1 files][384.6 MiB/384.6 MiB] 100% Done
# Operation completed over 1 objects/384.6 MiB.
# gsutil -m cp ../../data/tmp/plink/merged_pre2016/BroadPre2016.25_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv gs://popgen-gwas/data/analysis/Imputation_BatchCorrection/
# Copying file://../../data/tmp/plink/merged_pre2016/BroadPre2016.25_vs_5.DuplicateDiscrepancyCounts.WithMLMA.WithPerCountry.20210805.CovCC.minfilt.tsv [Content-Type=text/tab-separated-values]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# - [1/1 files][402.2 MiB/402.2 MiB] 100% Done
# Operation completed over 1 objects/402.2 MiB.
